# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print 'Your scores:'
print scores
print
print 'correct scores:'
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print correct_scores
print

# The difference should be very small. We get < 1e-7
print 'Difference between your scores and correct scores:'
print np.sum(np.abs(scores - correct_scores))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027207459e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1, train=False)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print 'Difference between your loss and correct loss:'
print np.sum(np.abs(loss - correct_loss))
# Out:
# Difference between your loss and correct loss:
# 1.79856129989e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1, train=False)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  print '%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name]))
# Out:
# b2 max relative error: 4.447625e-11
# W2 max relative error: 3.440708e-09
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_epochs=10, verbose=False)

print 'Final training loss: ', stats['loss_history'][-1]

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.318471886318

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 120
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_epochs=10, batch_size=400,
            learning_rate=5e-4, learning_rate_decay=0.95,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print 'Validation accuracy: ', val_acc
# Out:
# epoch 0 / 10: loss 2.303503
# epoch 0 / 10: loss 1.772916
# epoch 1 / 10: loss 1.710802
# epoch 2 / 10: loss 1.697581
# epoch 3 / 10: loss 1.733440
# epoch 4 / 10: loss 1.615735
# epoch 4 / 10: loss 1.566269
# epoch 5 / 10: loss 1.678582
# epoch 6 / 10: loss 1.659093
# epoch 7 / 10: loss 1.622680
# epoch 8 / 10: loss 1.684550
# epoch 9 / 10: loss 1.569671
# epoch 9 / 10: loss 1.670711
# Validation accuracy:  0.487

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
  W1 = net.params['W1']
  W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
  plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
  plt.gca().axis('off')
  plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
results = {}
best_val = -1
best_rate = -1
best_reg = -1
best_net = -1
best_stats = -1
best_h = -1
learning_rates = [5e-7, 1e-7, 5e-6, 1e-6, 5e-5]
regularization_strengths = [5e4, 1e4, 1e5, 5e5, 1e6, 5e6]


cnt = 0
max_count = 100
for count in xrange(1, max_count + 1):    
    reg = 10 ** np.random.uniform(-4, 1)    
    rate = 10 ** np.random.uniform(-5, -3) 
    if True :
        for h_add in range(5):
            cnt += 1
            print "round %d / %d" % (cnt, 5 * max_count)
            input_size = 32 * 32 * 3
            hidden_size = 170 + 4 * h_add
            num_classes = 10
            net = TwoLayerNet(input_size, hidden_size, num_classes)

            # Train the network
            stats = net.train(X_train, y_train, X_val, y_val,
                        num_epochs=10, batch_size=400,
                        learning_rate=rate, learning_rate_decay=0.95, mu=0.5, mu_increase=1.0,
                        reg=reg, verbose=True)

            # Predict on the validation set
            training_accuracy = np.mean(y_train == net.predict(X_train))
            validation_accuracy = (net.predict(X_val) == y_val).mean()
            print 'Validation accuracy: ', validation_accuracy

            if validation_accuracy > best_val:
                best_rate = rate
                best_reg = reg
                best_val = validation_accuracy
                best_net = net
                best_stats = stats
                best_h = hidden_size
            results[(rate, reg)] = (training_accuracy, validation_accuracy)
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f, in hidden size %d' % (best_val, best_h)
# Out:
# round 1 / 500
# epoch 0 / 10: loss 2.302659
# epoch 0 / 10: loss 1.836558
# epoch 1 / 10: loss 1.637383
# epoch 2 / 10: loss 1.679038
# epoch 3 / 10: loss 1.595532
# epoch 4 / 10: loss 1.561730
# epoch 4 / 10: loss 1.630676
# epoch 5 / 10: loss 1.582451
# epoch 6 / 10: loss 1.540693
# epoch 7 / 10: loss 1.514754
# epoch 8 / 10: loss 1.531324
# epoch 9 / 10: loss 1.543023
# epoch 9 / 10: loss 1.432210
# Validation accuracy:  0.502
# round 2 / 500
# epoch 0 / 10: loss 2.302658
# epoch 0 / 10: loss 1.927320
# epoch 1 / 10: loss 1.669618
# epoch 2 / 10: loss 1.648201
# epoch 3 / 10: loss 1.670660
# epoch 4 / 10: loss 1.631251
# epoch 4 / 10: loss 1.673202
# epoch 5 / 10: loss 1.598143
# epoch 6 / 10: loss 1.430333
# epoch 7 / 10: loss 1.540207
# epoch 8 / 10: loss 1.451238
# epoch 9 / 10: loss 1.496501
# epoch 9 / 10: loss 1.471197
# Validation accuracy:  0.484
# round 3 / 500
# epoch 0 / 10: loss 2.302568
# epoch 0 / 10: loss 1.875280
# epoch 1 / 10: loss 1.737796
# epoch 2 / 10: loss 1.575512
# epoch 3 / 10: loss 1.585635
# epoch 4 / 10: loss 1.592004
# epoch 4 / 10: loss 1.503157
# epoch 5 / 10: loss 1.567904
# epoch 6 / 10: loss 1.525365
# epoch 7 / 10: loss 1.531275
# epoch 8 / 10: loss 1.431699
# epoch 9 / 10: loss 1.441908
# epoch 9 / 10: loss 1.664228
# Validation accuracy:  0.504
# round 4 / 500
# epoch 0 / 10: loss 2.302594
# epoch 0 / 10: loss 1.838230
# epoch 1 / 10: loss 1.626889
# epoch 2 / 10: loss 1.694319
# epoch 3 / 10: loss 1.684990
# epoch 4 / 10: loss 1.461920
# epoch 4 / 10: loss 1.651439
# epoch 5 / 10: loss 1.511171
# epoch 6 / 10: loss 1.620727
# epoch 7 / 10: loss 1.548847
# epoch 8 / 10: loss 1.546945
# epoch 9 / 10: loss 1.491110
# epoch 9 / 10: loss 1.400660
# Validation accuracy:  0.505
# round 5 / 500
# epoch 0 / 10: loss 2.302616
# epoch 0 / 10: loss 1.793489
# epoch 1 / 10: loss 1.701728
# epoch 2 / 10: loss 1.653577
# epoch 3 / 10: loss 1.674375
# epoch 4 / 10: loss 1.580498
# epoch 4 / 10: loss 1.553973
# epoch 5 / 10: loss 1.487882
# epoch 6 / 10: loss 1.530920
# epoch 7 / 10: loss 1.438799
# epoch 8 / 10: loss 1.418822
# epoch 9 / 10: loss 1.456759
# epoch 9 / 10: loss 1.446096
# Validation accuracy:  0.507
# round 6 / 500
# epoch 0 / 10: loss 2.302580
# epoch 0 / 10: loss 1.799958
# epoch 1 / 10: loss 1.571750
# epoch 2 / 10: loss 1.674165
# epoch 3 / 10: loss 1.643730
# epoch 4 / 10: loss 1.576341
# epoch 4 / 10: loss 1.563880
# epoch 5 / 10: loss 1.471837
# epoch 6 / 10: loss 1.487349
# epoch 7 / 10: loss 1.465133
# epoch 8 / 10: loss 1.427605
# epoch 9 / 10: loss 1.483816
# epoch 9 / 10: loss 1.461681
# Validation accuracy:  0.491
# round 7 / 500
# epoch 0 / 10: loss 2.302547
# epoch 0 / 10: loss 1.835785
# epoch 1 / 10: loss 1.598123
# epoch 2 / 10: loss 1.709998
# epoch 3 / 10: loss 1.506075
# epoch 4 / 10: loss 1.512932
# epoch 4 / 10: loss 1.608542
# epoch 5 / 10: loss 1.622212
# epoch 6 / 10: loss 1.641394
# epoch 7 / 10: loss 1.506785
# epoch 8 / 10: loss 1.517910
# epoch 9 / 10: loss 1.568165
# epoch 9 / 10: loss 1.461643
# Validation accuracy:  0.506
# round 8 / 500
# epoch 0 / 10: loss 2.302613
# epoch 0 / 10: loss 1.796547
# epoch 1 / 10: loss 1.718718
# epoch 2 / 10: loss 1.685113
# epoch 3 / 10: loss 1.659494
# epoch 4 / 10: loss 1.509694
# epoch 4 / 10: loss 1.590650
# epoch 5 / 10: loss 1.476212
# epoch 6 / 10: loss 1.512334
# epoch 7 / 10: loss 1.492303
# epoch 8 / 10: loss 1.613908
# epoch 9 / 10: loss 1.506818
# epoch 9 / 10: loss 1.497184
# Validation accuracy:  0.507
# round 9 / 500
# epoch 0 / 10: loss 2.302595
# epoch 0 / 10: loss 1.695998
# epoch 1 / 10: loss 1.685399
# epoch 2 / 10: loss 1.603329
# epoch 3 / 10: loss 1.528457
# epoch 4 / 10: loss 1.617094
# epoch 4 / 10: loss 1.530740
# epoch 5 / 10: loss 1.539868
# epoch 6 / 10: loss 1.584555
# epoch 7 / 10: loss 1.514472
# epoch 8 / 10: loss 1.468181
# epoch 9 / 10: loss 1.462200
# epoch 9 / 10: loss 1.491246
# Validation accuracy:  0.51
# round 10 / 500
# epoch 0 / 10: loss 2.302558
# epoch 0 / 10: loss 1.660072
# epoch 1 / 10: loss 1.741049
# epoch 2 / 10: loss 1.593195
# epoch 3 / 10: loss 1.554453
# epoch 4 / 10: loss 1.698225
# epoch 4 / 10: loss 1.512669
# epoch 5 / 10: loss 1.482828
# epoch 6 / 10: loss 1.551219
# epoch 7 / 10: loss 1.534110
# epoch 8 / 10: loss 1.492946
# epoch 9 / 10: loss 1.470176
# epoch 9 / 10: loss 1.382354
# Validation accuracy:  0.478
# round 11 / 500
# epoch 0 / 10: loss 2.302602
# epoch 0 / 10: loss 1.740282
# epoch 1 / 10: loss 1.753428
# epoch 2 / 10: loss 1.717938
# epoch 3 / 10: loss 1.714384
# epoch 4 / 10: loss 1.742881
# epoch 4 / 10: loss 1.687501
# epoch 5 / 10: loss 1.638078
# epoch 6 / 10: loss 1.562105
# epoch 7 / 10: loss 1.653738
# epoch 8 / 10: loss 1.591077
# epoch 9 / 10: loss 1.592623
# epoch 9 / 10: loss 1.444526
# Validation accuracy:  0.501
# round 12 / 500
# epoch 0 / 10: loss 2.302560
# epoch 0 / 10: loss 1.676459
# epoch 1 / 10: loss 1.656095
# epoch 2 / 10: loss 1.748265
# epoch 3 / 10: loss 1.650279
# epoch 4 / 10: loss 1.656865
# epoch 4 / 10: loss 1.539747
# epoch 5 / 10: loss 1.599361
# epoch 6 / 10: loss 1.534383
# epoch 7 / 10: loss 1.505970
# epoch 8 / 10: loss 1.549714
# epoch 9 / 10: loss 1.527177
# epoch 9 / 10: loss 1.534123
# Validation accuracy:  0.499
# round 13 / 500
# epoch 0 / 10: loss 2.302570
# epoch 0 / 10: loss 1.712549
# epoch 1 / 10: loss 1.756287
# epoch 2 / 10: loss 1.723267
# epoch 3 / 10: loss 1.607270
# epoch 4 / 10: loss 1.769898
# epoch 4 / 10: loss 1.680671
# epoch 5 / 10: loss 1.645312
# epoch 6 / 10: loss 1.531515
# epoch 7 / 10: loss 1.613862
# epoch 8 / 10: loss 1.501210
# epoch 9 / 10: loss 1.471156
# epoch 9 / 10: loss 1.506869
# Validation accuracy:  0.498
# round 14 / 500
# epoch 0 / 10: loss 2.302652
# epoch 0 / 10: loss 1.853546
# epoch 1 / 10: loss 1.660085
# epoch 2 / 10: loss 1.740889
# epoch 3 / 10: loss 1.568901
# epoch 4 / 10: loss 1.680762
# epoch 4 / 10: loss 1.621898
# epoch 5 / 10: loss 1.635170
# epoch 6 / 10: loss 1.452279
# epoch 7 / 10: loss 1.564868
# epoch 8 / 10: loss 1.661054
# epoch 9 / 10: loss 1.486128
# epoch 9 / 10: loss 1.620601
# Validation accuracy:  0.489
# round 15 / 500
# epoch 0 / 10: loss 2.302570
# epoch 0 / 10: loss 1.751846
# epoch 1 / 10: loss 1.731983
# epoch 2 / 10: loss 1.693350
# epoch 3 / 10: loss 1.635207
# epoch 4 / 10: loss 1.583578
# epoch 4 / 10: loss 1.610321
# epoch 5 / 10: loss 1.549122
# epoch 6 / 10: loss 1.537131
# epoch 7 / 10: loss 1.461409
# epoch 8 / 10: loss 1.561437
# epoch 9 / 10: loss 1.638875
# epoch 9 / 10: loss 1.570515
# Validation accuracy:  0.487
# round 16 / 500
# epoch 0 / 10: loss 2.302623
# epoch 0 / 10: loss 2.300900
# epoch 1 / 10: loss 2.281653
# epoch 2 / 10: loss 2.202708
# epoch 3 / 10: loss 2.084354
# epoch 4 / 10: loss 2.086687
# epoch 4 / 10: loss 2.025943
# epoch 5 / 10: loss 1.967060
# epoch 6 / 10: loss 1.979082
# epoch 7 / 10: loss 1.882421
# epoch 8 / 10: loss 1.952644
# epoch 9 / 10: loss 1.795833
# epoch 9 / 10: loss 1.838810
# Validation accuracy:  0.339
# round 17 / 500
# epoch 0 / 10: loss 2.302617
# epoch 0 / 10: loss 2.300697
# epoch 1 / 10: loss 2.268323
# epoch 2 / 10: loss 2.167075
# epoch 3 / 10: loss 2.107123
# epoch 4 / 10: loss 2.044817
# epoch 4 / 10: loss 2.030718
# epoch 5 / 10: loss 1.923014
# epoch 6 / 10: loss 1.942711
# epoch 7 / 10: loss 1.899945
# epoch 8 / 10: loss 1.900539
# epoch 9 / 10: loss 1.885059
# epoch 9 / 10: loss 1.877798
# Validation accuracy:  0.338
# round 18 / 500
# epoch 0 / 10: loss 2.302541
# epoch 0 / 10: loss 2.300923
# epoch 1 / 10: loss 2.276003
# epoch 2 / 10: loss 2.189852
# epoch 3 / 10: loss 2.103797
# epoch 4 / 10: loss 2.054151
# epoch 4 / 10: loss 2.015047
# epoch 5 / 10: loss 1.974599
# epoch 6 / 10: loss 1.992224
# epoch 7 / 10: loss 1.869860
# epoch 8 / 10: loss 1.857616
# epoch 9 / 10: loss 1.903803
# epoch 9 / 10: loss 1.852583
# Validation accuracy:  0.332
# round 19 / 500
# epoch 0 / 10: loss 2.302682
# epoch 0 / 10: loss 2.300642
# epoch 1 / 10: loss 2.280463
# epoch 2 / 10: loss 2.181649
# epoch 3 / 10: loss 2.094896
# epoch 4 / 10: loss 2.055578
# epoch 4 / 10: loss 2.001276
# epoch 5 / 10: loss 1.962129
# epoch 6 / 10: loss 1.923919
# epoch 7 / 10: loss 1.911753
# epoch 8 / 10: loss 1.967652
# epoch 9 / 10: loss 1.850781
# epoch 9 / 10: loss 1.889196
# Validation accuracy:  0.338
# round 20 / 500
# epoch 0 / 10: loss 2.302626
# epoch 0 / 10: loss 2.300803
# epoch 1 / 10: loss 2.279679
# epoch 2 / 10: loss 2.231635
# epoch 3 / 10: loss 2.077533
# epoch 4 / 10: loss 2.065231
# epoch 4 / 10: loss 2.015631
# epoch 5 / 10: loss 2.024037
# epoch 6 / 10: loss 1.981932
# epoch 7 / 10: loss 1.947560
# epoch 8 / 10: loss 1.907964
# epoch 9 / 10: loss 1.921124
# epoch 9 / 10: loss 1.875724
# Validation accuracy:  0.338
# round 21 / 500
# epoch 0 / 10: loss 2.309512
# epoch 0 / 10: loss 2.022872
# epoch 1 / 10: loss 1.875068
# epoch 2 / 10: loss 1.816476
# epoch 3 / 10: loss 1.833209
# epoch 4 / 10: loss 1.739241
# epoch 4 / 10: loss 1.770340
# epoch 5 / 10: loss 1.771720
# epoch 6 / 10: loss 1.821175
# epoch 7 / 10: loss 1.683195
# epoch 8 / 10: loss 1.756185
# epoch 9 / 10: loss 1.794252
# epoch 9 / 10: loss 1.791188
# Validation accuracy:  0.444
# round 22 / 500
# epoch 0 / 10: loss 2.309722
# epoch 0 / 10: loss 2.010411
# epoch 1 / 10: loss 1.829218
# epoch 2 / 10: loss 1.798334
# epoch 3 / 10: loss 1.806108
# epoch 4 / 10: loss 1.779793
# epoch 4 / 10: loss 1.761890
# epoch 5 / 10: loss 1.797717
# epoch 6 / 10: loss 1.780347
# epoch 7 / 10: loss 1.815676
# epoch 8 / 10: loss 1.782624
# epoch 9 / 10: loss 1.780332
# epoch 9 / 10: loss 1.754983
# Validation accuracy:  0.457
# round 23 / 500
# epoch 0 / 10: loss 2.309844
# epoch 0 / 10: loss 1.950902
# epoch 1 / 10: loss 1.915322
# epoch 2 / 10: loss 1.837128
# epoch 3 / 10: loss 1.777139
# epoch 4 / 10: loss 1.890959
# epoch 4 / 10: loss 1.773774
# epoch 5 / 10: loss 1.812387
# epoch 6 / 10: loss 1.764551
# epoch 7 / 10: loss 1.809203
# epoch 8 / 10: loss 1.790154
# epoch 9 / 10: loss 1.765635
# epoch 9 / 10: loss 1.810248
# Validation accuracy:  0.453
# round 24 / 500
# epoch 0 / 10: loss 2.310053
# epoch 0 / 10: loss 2.021754
# epoch 1 / 10: loss 1.857607
# epoch 2 / 10: loss 1.840682
# epoch 3 / 10: loss 1.781620
# epoch 4 / 10: loss 1.791948
# epoch 4 / 10: loss 1.863708
# epoch 5 / 10: loss 1.768552
# epoch 6 / 10: loss 1.815425
# epoch 7 / 10: loss 1.725534
# epoch 8 / 10: loss 1.805588
# epoch 9 / 10: loss 1.774689
# epoch 9 / 10: loss 1.720998
# Validation accuracy:  0.46
# round 25 / 500
# epoch 0 / 10: loss 2.310157
# epoch 0 / 10: loss 1.943860
# epoch 1 / 10: loss 1.798445
# epoch 2 / 10: loss 1.813391
# epoch 3 / 10: loss 1.808915
# epoch 4 / 10: loss 1.800336
# epoch 4 / 10: loss 1.799759
# epoch 5 / 10: loss 1.790823
# epoch 6 / 10: loss 1.720886
# epoch 7 / 10: loss 1.759379
# epoch 8 / 10: loss 1.723290
# epoch 9 / 10: loss 1.772930
# epoch 9 / 10: loss 1.695730
# Validation accuracy:  0.451
# round 26 / 500
# epoch 0 / 10: loss 2.302941
# epoch 0 / 10: loss 1.832661
# epoch 1 / 10: loss 1.791233
# epoch 2 / 10: loss 1.702197
# epoch 3 / 10: loss 1.746974
# epoch 4 / 10: loss 1.698140
# epoch 4 / 10: loss 1.721621
# epoch 5 / 10: loss 1.674472
# epoch 6 / 10: loss 1.671178
# epoch 7 / 10: loss 1.670458
# epoch 8 / 10: loss 1.654307
# epoch 9 / 10: loss 1.625392
# epoch 9 / 10: loss 1.551692
# Validation accuracy:  0.489
# round 27 / 500
# epoch 0 / 10: loss 2.302985
# epoch 0 / 10: loss 1.771218
# epoch 1 / 10: loss 1.682167
# epoch 2 / 10: loss 1.762808
# epoch 3 / 10: loss 1.733379
# epoch 4 / 10: loss 1.623127
# epoch 4 / 10: loss 1.727032
# epoch 5 / 10: loss 1.648179
# epoch 6 / 10: loss 1.580058
# epoch 7 / 10: loss 1.562392
# epoch 8 / 10: loss 1.584899
# epoch 9 / 10: loss 1.538181
# epoch 9 / 10: loss 1.551791
# Validation accuracy:  0.488
# round 28 / 500
# epoch 0 / 10: loss 2.302979
# epoch 0 / 10: loss 1.813693
# epoch 1 / 10: loss 1.734684
# epoch 2 / 10: loss 1.759666
# epoch 3 / 10: loss 1.588599
# epoch 4 / 10: loss 1.714769
# epoch 4 / 10: loss 1.774910
# epoch 5 / 10: loss 1.645054
# epoch 6 / 10: loss 1.531400
# epoch 7 / 10: loss 1.628469
# epoch 8 / 10: loss 1.593389
# epoch 9 / 10: loss 1.590225
# epoch 9 / 10: loss 1.652688
# Validation accuracy:  0.48
# round 29 / 500
# epoch 0 / 10: loss 2.302991
# epoch 0 / 10: loss 1.698890
# epoch 1 / 10: loss 1.714672
# epoch 2 / 10: loss 1.635347
# epoch 3 / 10: loss 1.663532
# epoch 4 / 10: loss 1.575331
# epoch 4 / 10: loss 1.652970
# epoch 5 / 10: loss 1.594751
# epoch 6 / 10: loss 1.616675
# epoch 7 / 10: loss 1.661760
# epoch 8 / 10: loss 1.547746
# epoch 9 / 10: loss 1.622179
# epoch 9 / 10: loss 1.499427
# Validation accuracy:  0.498
# round 30 / 500
# epoch 0 / 10: loss 2.302979
# epoch 0 / 10: loss 1.733031
# epoch 1 / 10: loss 1.571079
# epoch 2 / 10: loss 1.573102
# epoch 3 / 10: loss 1.720561
# epoch 4 / 10: loss 1.670386
# epoch 4 / 10: loss 1.661138
# epoch 5 / 10: loss 1.614461
# epoch 6 / 10: loss 1.630873
# epoch 7 / 10: loss 1.623553
# epoch 8 / 10: loss 1.621371
# epoch 9 / 10: loss 1.637348
# epoch 9 / 10: loss 1.656528
# Validation accuracy:  0.491
# round 31 / 500
# epoch 0 / 10: loss 2.302603
# epoch 0 / 10: loss 1.693529
# epoch 1 / 10: loss 1.735697
# epoch 2 / 10: loss 1.712809
# epoch 3 / 10: loss 1.648390
# epoch 4 / 10: loss 1.645529
# epoch 4 / 10: loss 1.593769
# epoch 5 / 10: loss 1.630047
# epoch 6 / 10: loss 1.440146
# epoch 7 / 10: loss 1.557493
# epoch 8 / 10: loss 1.479843
# epoch 9 / 10: loss 1.476569
# epoch 9 / 10: loss 1.432228
# Validation accuracy:  0.489
# round 32 / 500
# epoch 0 / 10: loss 2.302553
# epoch 0 / 10: loss 1.751673
# epoch 1 / 10: loss 1.764860
# epoch 2 / 10: loss 1.769169
# epoch 3 / 10: loss 1.611709
# epoch 4 / 10: loss 1.568195
# epoch 4 / 10: loss 1.621983
# epoch 5 / 10: loss 1.579878
# epoch 6 / 10: loss 1.593277
# epoch 7 / 10: loss 1.614006
# epoch 8 / 10: loss 1.460189
# epoch 9 / 10: loss 1.514642
# epoch 9 / 10: loss 1.495307
# Validation accuracy:  0.49
# round 33 / 500
# epoch 0 / 10: loss 2.302616
# epoch 0 / 10: loss 1.834484
# epoch 1 / 10: loss 1.693686
# epoch 2 / 10: loss 1.763962
# epoch 3 / 10: loss 1.533057
# epoch 4 / 10: loss 1.587933
# epoch 4 / 10: loss 1.581388
# epoch 5 / 10: loss 1.428894
# epoch 6 / 10: loss 1.604585
# epoch 7 / 10: loss 1.591013
# epoch 8 / 10: loss 1.537289
# epoch 9 / 10: loss 1.613621
# epoch 9 / 10: loss 1.553871
# Validation accuracy:  0.481
# round 34 / 500
# epoch 0 / 10: loss 2.302603
# epoch 0 / 10: loss 1.720390
# epoch 1 / 10: loss 1.767121
# epoch 2 / 10: loss 1.626081
# epoch 3 / 10: loss 1.574133
# epoch 4 / 10: loss 1.634427
# epoch 4 / 10: loss 1.603556
# epoch 5 / 10: loss 1.570836
# epoch 6 / 10: loss 1.577514
# epoch 7 / 10: loss 1.501048
# epoch 8 / 10: loss 1.483783
# epoch 9 / 10: loss 1.507319
# epoch 9 / 10: loss 1.485959
# Validation accuracy:  0.525
# round 35 / 500
# epoch 0 / 10: loss 2.302571
# epoch 0 / 10: loss 1.739810
# epoch 1 / 10: loss 1.727079
# epoch 2 / 10: loss 1.645446
# epoch 3 / 10: loss 1.621184
# epoch 4 / 10: loss 1.642426
# epoch 4 / 10: loss 1.536548
# epoch 5 / 10: loss 1.573804
# epoch 6 / 10: loss 1.471249
# epoch 7 / 10: loss 1.457777
# epoch 8 / 10: loss 1.550939
# epoch 9 / 10: loss 1.531478
# epoch 9 / 10: loss 1.541676
# Validation accuracy:  0.496
# round 36 / 500
# epoch 0 / 10: loss 2.302801
# epoch 0 / 10: loss 2.301461
# epoch 1 / 10: loss 2.292346
# epoch 2 / 10: loss 2.241554
# epoch 3 / 10: loss 2.176546
# epoch 4 / 10: loss 2.149184
# epoch 4 / 10: loss 2.092914
# epoch 5 / 10: loss 2.052845
# epoch 6 / 10: loss 1.968026
# epoch 7 / 10: loss 1.971535
# epoch 8 / 10: loss 1.978843
# epoch 9 / 10: loss 1.944570
# epoch 9 / 10: loss 1.959497
# Validation accuracy:  0.308
# round 37 / 500
# epoch 0 / 10: loss 2.302824
# epoch 0 / 10: loss 2.301415
# epoch 1 / 10: loss 2.291280
# epoch 2 / 10: loss 2.243989
# epoch 3 / 10: loss 2.193836
# epoch 4 / 10: loss 2.069676
# epoch 4 / 10: loss 2.062668
# epoch 5 / 10: loss 2.039134
# epoch 6 / 10: loss 2.015718
# epoch 7 / 10: loss 1.979897
# epoch 8 / 10: loss 2.024369
# epoch 9 / 10: loss 1.966699
# epoch 9 / 10: loss 1.950678
# Validation accuracy:  0.306
# round 38 / 500
# epoch 0 / 10: loss 2.302794
# epoch 0 / 10: loss 2.301677
# epoch 1 / 10: loss 2.289728
# epoch 2 / 10: loss 2.243125
# epoch 3 / 10: loss 2.175887
# epoch 4 / 10: loss 2.117205
# epoch 4 / 10: loss 2.017193
# epoch 5 / 10: loss 2.039298
# epoch 6 / 10: loss 2.048391
# epoch 7 / 10: loss 1.984026
# epoch 8 / 10: loss 1.954137
# epoch 9 / 10: loss 1.952773
# epoch 9 / 10: loss 1.937765
# Validation accuracy:  0.313
# round 39 / 500
# epoch 0 / 10: loss 2.302825
# epoch 0 / 10: loss 2.301383
# epoch 1 / 10: loss 2.292118
# epoch 2 / 10: loss 2.243369
# epoch 3 / 10: loss 2.172014
# epoch 4 / 10: loss 2.113745
# epoch 4 / 10: loss 2.056477
# epoch 5 / 10: loss 2.010639
# epoch 6 / 10: loss 1.993391
# epoch 7 / 10: loss 1.954067
# epoch 8 / 10: loss 1.962857
# epoch 9 / 10: loss 2.005450
# epoch 9 / 10: loss 1.903699
# Validation accuracy:  0.308
# round 40 / 500
# epoch 0 / 10: loss 2.302816
# epoch 0 / 10: loss 2.301298
# epoch 1 / 10: loss 2.293272
# epoch 2 / 10: loss 2.235860
# epoch 3 / 10: loss 2.169009
# epoch 4 / 10: loss 2.090534
# epoch 4 / 10: loss 2.033714
# epoch 5 / 10: loss 1.980301
# epoch 6 / 10: loss 2.021874
# epoch 7 / 10: loss 1.973037
# epoch 8 / 10: loss 1.970841
# epoch 9 / 10: loss 1.966480
# epoch 9 / 10: loss 1.999632
# Validation accuracy:  0.308
# round 41 / 500
# epoch 0 / 10: loss 2.302559
# epoch 0 / 10: loss 1.784433
# epoch 1 / 10: loss 1.738444
# epoch 2 / 10: loss 1.614007
# epoch 3 / 10: loss 1.705764
# epoch 4 / 10: loss 1.682415
# epoch 4 / 10: loss 1.662374
# epoch 5 / 10: loss 1.649800
# epoch 6 / 10: loss 1.511851
# epoch 7 / 10: loss 1.506142
# epoch 8 / 10: loss 1.620304
# epoch 9 / 10: loss 1.457570
# epoch 9 / 10: loss 1.583695
# Validation accuracy:  0.486
# round 42 / 500
# epoch 0 / 10: loss 2.302599
# epoch 0 / 10: loss 1.781274
# epoch 1 / 10: loss 1.698400
# epoch 2 / 10: loss 1.650594
# epoch 3 / 10: loss 1.668860
# epoch 4 / 10: loss 1.573946
# epoch 4 / 10: loss 1.560685
# epoch 5 / 10: loss 1.662242
# epoch 6 / 10: loss 1.524221
# epoch 7 / 10: loss 1.620563
# epoch 8 / 10: loss 1.603370
# epoch 9 / 10: loss 1.462250
# epoch 9 / 10: loss 1.502762
# Validation accuracy:  0.496
# round 43 / 500
# epoch 0 / 10: loss 2.302593
# epoch 0 / 10: loss 1.775700
# epoch 1 / 10: loss 1.720509
# epoch 2 / 10: loss 1.633586
# epoch 3 / 10: loss 1.659836
# epoch 4 / 10: loss 1.598772
# epoch 4 / 10: loss 1.617035
# epoch 5 / 10: loss 1.551065
# epoch 6 / 10: loss 1.623938
# epoch 7 / 10: loss 1.660401
# epoch 8 / 10: loss 1.548661
# epoch 9 / 10: loss 1.449269
# epoch 9 / 10: loss 1.480671
# Validation accuracy:  0.493
# round 44 / 500
# epoch 0 / 10: loss 2.302536
# epoch 0 / 10: loss 1.735358
# epoch 1 / 10: loss 1.609509
# epoch 2 / 10: loss 1.718072
# epoch 3 / 10: loss 1.664356
# epoch 4 / 10: loss 1.656326
# epoch 4 / 10: loss 1.597219
# epoch 5 / 10: loss 1.609059
# epoch 6 / 10: loss 1.668046
# epoch 7 / 10: loss 1.624399
# epoch 8 / 10: loss 1.519085
# epoch 9 / 10: loss 1.491392
# epoch 9 / 10: loss 1.491271
# Validation accuracy:  0.477
# round 45 / 500
# epoch 0 / 10: loss 2.302643
# epoch 0 / 10: loss 1.730773
# epoch 1 / 10: loss 1.712385
# epoch 2 / 10: loss 1.671429
# epoch 3 / 10: loss 1.557320
# epoch 4 / 10: loss 1.655278
# epoch 4 / 10: loss 1.610799
# epoch 5 / 10: loss 1.620685
# epoch 6 / 10: loss 1.624556
# epoch 7 / 10: loss 1.473798
# epoch 8 / 10: loss 1.480300
# epoch 9 / 10: loss 1.574682
# epoch 9 / 10: loss 1.504683
# Validation accuracy:  0.477
# round 46 / 500
# epoch 0 / 10: loss 2.305775
# epoch 0 / 10: loss 2.303992
# epoch 1 / 10: loss 2.287641
# epoch 2 / 10: loss 2.191704
# epoch 3 / 10: loss 2.143850
# epoch 4 / 10: loss 2.079745
# epoch 4 / 10: loss 2.036152
# epoch 5 / 10: loss 1.982690
# epoch 6 / 10: loss 1.977997
# epoch 7 / 10: loss 1.970551
# epoch 8 / 10: loss 2.025535
# epoch 9 / 10: loss 1.884051
# epoch 9 / 10: loss 1.911889
# Validation accuracy:  0.326
# round 47 / 500
# epoch 0 / 10: loss 2.305817
# epoch 0 / 10: loss 2.303933
# epoch 1 / 10: loss 2.281425
# epoch 2 / 10: loss 2.181371
# epoch 3 / 10: loss 2.095640
# epoch 4 / 10: loss 2.057958
# epoch 4 / 10: loss 2.075585
# epoch 5 / 10: loss 1.993706
# epoch 6 / 10: loss 2.005318
# epoch 7 / 10: loss 1.999384
# epoch 8 / 10: loss 1.914064
# epoch 9 / 10: loss 1.934094
# epoch 9 / 10: loss 1.893324
# Validation accuracy:  0.331
# round 48 / 500
# epoch 0 / 10: loss 2.305906
# epoch 0 / 10: loss 2.304103
# epoch 1 / 10: loss 2.278433
# epoch 2 / 10: loss 2.176753
# epoch 3 / 10: loss 2.110142
# epoch 4 / 10: loss 2.056873
# epoch 4 / 10: loss 2.019398
# epoch 5 / 10: loss 1.999306
# epoch 6 / 10: loss 1.978809
# epoch 7 / 10: loss 1.948025
# epoch 8 / 10: loss 1.932698
# epoch 9 / 10: loss 1.903851
# epoch 9 / 10: loss 1.903074
# Validation accuracy:  0.334
# round 49 / 500
# epoch 0 / 10: loss 2.305944
# epoch 0 / 10: loss 2.303731
# epoch 1 / 10: loss 2.275790
# epoch 2 / 10: loss 2.182236
# epoch 3 / 10: loss 2.114896
# epoch 4 / 10: loss 2.044258
# epoch 4 / 10: loss 1.980232
# epoch 5 / 10: loss 2.002502
# epoch 6 / 10: loss 1.983161
# epoch 7 / 10: loss 1.939761
# epoch 8 / 10: loss 1.926741
# epoch 9 / 10: loss 1.946285
# epoch 9 / 10: loss 1.874236
# Validation accuracy:  0.326
# round 50 / 500
# epoch 0 / 10: loss 2.306024
# epoch 0 / 10: loss 2.304128
# epoch 1 / 10: loss 2.281100
# epoch 2 / 10: loss 2.215894
# epoch 3 / 10: loss 2.080730
# epoch 4 / 10: loss 2.056092
# epoch 4 / 10: loss 2.077335
# epoch 5 / 10: loss 2.040880
# epoch 6 / 10: loss 1.940011
# epoch 7 / 10: loss 1.917723
# epoch 8 / 10: loss 1.874738
# epoch 9 / 10: loss 1.908284
# epoch 9 / 10: loss 1.885835
# Validation accuracy:  0.331
# round 51 / 500
# epoch 0 / 10: loss 2.302612
# epoch 0 / 10: loss 1.868830
# epoch 1 / 10: loss 1.828164
# epoch 2 / 10: loss 1.685994
# epoch 3 / 10: loss 1.505548
# epoch 4 / 10: loss 1.602679
# epoch 4 / 10: loss 1.589619
# epoch 5 / 10: loss 1.585281
# epoch 6 / 10: loss 1.521448
# epoch 7 / 10: loss 1.586202
# epoch 8 / 10: loss 1.586945
# epoch 9 / 10: loss 1.511782
# epoch 9 / 10: loss 1.613816
# Validation accuracy:  0.493
# round 52 / 500
# epoch 0 / 10: loss 2.302594
# epoch 0 / 10: loss 1.848386
# epoch 1 / 10: loss 1.728113
# epoch 2 / 10: loss 1.641402
# epoch 3 / 10: loss 1.735438
# epoch 4 / 10: loss 1.638404
# epoch 4 / 10: loss 1.601794
# epoch 5 / 10: loss 1.536449
# epoch 6 / 10: loss 1.536558
# epoch 7 / 10: loss 1.503701
# epoch 8 / 10: loss 1.487686
# epoch 9 / 10: loss 1.461208
# epoch 9 / 10: loss 1.547270
# Validation accuracy:  0.496
# round 53 / 500
# epoch 0 / 10: loss 2.302569
# epoch 0 / 10: loss 1.901179
# epoch 1 / 10: loss 1.673380
# epoch 2 / 10: loss 1.609701
# epoch 3 / 10: loss 1.671106
# epoch 4 / 10: loss 1.669295
# epoch 4 / 10: loss 1.537054
# epoch 5 / 10: loss 1.489750
# epoch 6 / 10: loss 1.627112
# epoch 7 / 10: loss 1.526080
# epoch 8 / 10: loss 1.493361
# epoch 9 / 10: loss 1.525900
# epoch 9 / 10: loss 1.437676
# Validation accuracy:  0.493
# round 54 / 500
# epoch 0 / 10: loss 2.302567
# epoch 0 / 10: loss 1.826676
# epoch 1 / 10: loss 1.822050
# epoch 2 / 10: loss 1.653489
# epoch 3 / 10: loss 1.562900
# epoch 4 / 10: loss 1.589238
# epoch 4 / 10: loss 1.463384
# epoch 5 / 10: loss 1.572505
# epoch 6 / 10: loss 1.479856
# epoch 7 / 10: loss 1.552100
# epoch 8 / 10: loss 1.452362
# epoch 9 / 10: loss 1.488321
# epoch 9 / 10: loss 1.531072
# Validation accuracy:  0.494
# round 55 / 500
# epoch 0 / 10: loss 2.302574
# epoch 0 / 10: loss 1.873253
# epoch 1 / 10: loss 1.699564
# epoch 2 / 10: loss 1.686383
# epoch 3 / 10: loss 1.598954
# epoch 4 / 10: loss 1.538776
# epoch 4 / 10: loss 1.537861
# epoch 5 / 10: loss 1.522562
# epoch 6 / 10: loss 1.650040
# epoch 7 / 10: loss 1.540426
# epoch 8 / 10: loss 1.526971
# epoch 9 / 10: loss 1.543295
# epoch 9 / 10: loss 1.586696
# Validation accuracy:  0.505
# round 56 / 500
# epoch 0 / 10: loss 2.311505
# epoch 0 / 10: loss 2.310116
# epoch 1 / 10: loss 2.306889
# epoch 2 / 10: loss 2.288844
# epoch 3 / 10: loss 2.241537
# epoch 4 / 10: loss 2.187679
# epoch 4 / 10: loss 2.129094
# epoch 5 / 10: loss 2.107663
# epoch 6 / 10: loss 2.095487
# epoch 7 / 10: loss 2.122198
# epoch 8 / 10: loss 2.053209
# epoch 9 / 10: loss 2.130577
# epoch 9 / 10: loss 2.029543
# Validation accuracy:  0.283
# round 57 / 500
# epoch 0 / 10: loss 2.311691
# epoch 0 / 10: loss 2.310326
# epoch 1 / 10: loss 2.306889
# epoch 2 / 10: loss 2.291600
# epoch 3 / 10: loss 2.248238
# epoch 4 / 10: loss 2.215845
# epoch 4 / 10: loss 2.190345
# epoch 5 / 10: loss 2.115023
# epoch 6 / 10: loss 2.093416
# epoch 7 / 10: loss 2.117206
# epoch 8 / 10: loss 2.079479
# epoch 9 / 10: loss 2.042518
# epoch 9 / 10: loss 1.990017
# Validation accuracy:  0.278
# round 58 / 500
# epoch 0 / 10: loss 2.311913
# epoch 0 / 10: loss 2.310369
# epoch 1 / 10: loss 2.306468
# epoch 2 / 10: loss 2.289673
# epoch 3 / 10: loss 2.247132
# epoch 4 / 10: loss 2.164877
# epoch 4 / 10: loss 2.116619
# epoch 5 / 10: loss 2.123509
# epoch 6 / 10: loss 2.079949
# epoch 7 / 10: loss 2.097594
# epoch 8 / 10: loss 2.019629
# epoch 9 / 10: loss 2.037452
# epoch 9 / 10: loss 2.048780
# Validation accuracy:  0.281
# round 59 / 500
# epoch 0 / 10: loss 2.312097
# epoch 0 / 10: loss 2.310478
# epoch 1 / 10: loss 2.306885
# epoch 2 / 10: loss 2.289236
# epoch 3 / 10: loss 2.237460
# epoch 4 / 10: loss 2.193329
# epoch 4 / 10: loss 2.121943
# epoch 5 / 10: loss 2.091445
# epoch 6 / 10: loss 2.035406
# epoch 7 / 10: loss 2.100360
# epoch 8 / 10: loss 2.065815
# epoch 9 / 10: loss 2.016396
# epoch 9 / 10: loss 2.025446
# Validation accuracy:  0.282
# round 60 / 500
# epoch 0 / 10: loss 2.312420
# epoch 0 / 10: loss 2.310968
# epoch 1 / 10: loss 2.306355
# epoch 2 / 10: loss 2.287527
# epoch 3 / 10: loss 2.250367
# epoch 4 / 10: loss 2.204749
# epoch 4 / 10: loss 2.165457
# epoch 5 / 10: loss 2.112110
# epoch 6 / 10: loss 2.097125
# epoch 7 / 10: loss 2.090711
# epoch 8 / 10: loss 2.060284
# epoch 9 / 10: loss 2.068383
# epoch 9 / 10: loss 2.029627
# Validation accuracy:  0.284
# round 61 / 500
# epoch 0 / 10: loss 2.319222
# epoch 0 / 10: loss 2.013860
# epoch 1 / 10: loss 2.003701
# epoch 2 / 10: loss 1.961733
# epoch 3 / 10: loss 1.910446
# epoch 4 / 10: loss 1.873695
# epoch 4 / 10: loss 1.970806
# epoch 5 / 10: loss 1.900357
# epoch 6 / 10: loss 1.927039
# epoch 7 / 10: loss 1.918927
# epoch 8 / 10: loss 1.908364
# epoch 9 / 10: loss 1.858692
# epoch 9 / 10: loss 1.893268
# Validation accuracy:  0.418
# round 62 / 500
# epoch 0 / 10: loss 2.319612
# epoch 0 / 10: loss 2.021090
# epoch 1 / 10: loss 2.007074
# epoch 2 / 10: loss 1.915325
# epoch 3 / 10: loss 1.908054
# epoch 4 / 10: loss 1.885205
# epoch 4 / 10: loss 1.891311
# epoch 5 / 10: loss 1.933412
# epoch 6 / 10: loss 1.928500
# epoch 7 / 10: loss 1.856989
# epoch 8 / 10: loss 1.935294
# epoch 9 / 10: loss 1.903775
# epoch 9 / 10: loss 1.895924
# Validation accuracy:  0.401
# round 63 / 500
# epoch 0 / 10: loss 2.319941
# epoch 0 / 10: loss 2.011953
# epoch 1 / 10: loss 1.956272
# epoch 2 / 10: loss 1.977516
# epoch 3 / 10: loss 1.876522
# epoch 4 / 10: loss 1.919029
# epoch 4 / 10: loss 1.928168
# epoch 5 / 10: loss 1.916409
# epoch 6 / 10: loss 1.885590
# epoch 7 / 10: loss 1.908337
# epoch 8 / 10: loss 1.906326
# epoch 9 / 10: loss 1.942237
# epoch 9 / 10: loss 1.877434
# Validation accuracy:  0.416
# round 64 / 500
# epoch 0 / 10: loss 2.320414
# epoch 0 / 10: loss 2.011571
# epoch 1 / 10: loss 1.993480
# epoch 2 / 10: loss 1.902663
# epoch 3 / 10: loss 1.953849
# epoch 4 / 10: loss 1.894991
# epoch 4 / 10: loss 1.870473
# epoch 5 / 10: loss 1.956560
# epoch 6 / 10: loss 1.931175
# epoch 7 / 10: loss 1.888848
# epoch 8 / 10: loss 1.866983
# epoch 9 / 10: loss 1.916755
# epoch 9 / 10: loss 1.859267
# Validation accuracy:  0.411
# round 65 / 500
# epoch 0 / 10: loss 2.320727
# epoch 0 / 10: loss 1.996921
# epoch 1 / 10: loss 1.958144
# epoch 2 / 10: loss 1.955957
# epoch 3 / 10: loss 1.932436
# epoch 4 / 10: loss 1.915879
# epoch 4 / 10: loss 1.948913
# epoch 5 / 10: loss 1.900877
# epoch 6 / 10: loss 1.933731
# epoch 7 / 10: loss 1.919926
# epoch 8 / 10: loss 1.882039
# epoch 9 / 10: loss 1.997504
# epoch 9 / 10: loss 1.890600
# Validation accuracy:  0.412
# round 66 / 500
# epoch 0 / 10: loss 2.302605
# epoch 0 / 10: loss 1.764394
# epoch 1 / 10: loss 1.831034
# epoch 2 / 10: loss 1.678352
# epoch 3 / 10: loss 1.699886
# epoch 4 / 10: loss 1.657875
# epoch 4 / 10: loss 1.733347
# epoch 5 / 10: loss 1.751326
# epoch 6 / 10: loss 1.824883
# epoch 7 / 10: loss 1.535382
# epoch 8 / 10: loss 1.633871
# epoch 9 / 10: loss 1.637174
# epoch 9 / 10: loss 1.606636
# Validation accuracy:  0.473
# round 67 / 500
# epoch 0 / 10: loss 2.302596
# epoch 0 / 10: loss 1.826751
# epoch 1 / 10: loss 1.799002
# epoch 2 / 10: loss 1.771240
# epoch 3 / 10: loss 1.765681
# epoch 4 / 10: loss 1.668466
# epoch 4 / 10: loss 1.715797
# epoch 5 / 10: loss 1.562935
# epoch 6 / 10: loss 1.735905
# epoch 7 / 10: loss 1.634076
# epoch 8 / 10: loss 1.573591
# epoch 9 / 10: loss 1.551182
# epoch 9 / 10: loss 1.548172
# Validation accuracy:  0.459
# round 68 / 500
# epoch 0 / 10: loss 2.302576
# epoch 0 / 10: loss 1.804719
# epoch 1 / 10: loss 1.751310
# epoch 2 / 10: loss 1.793543
# epoch 3 / 10: loss 1.851704
# epoch 4 / 10: loss 1.729635
# epoch 4 / 10: loss 1.583317
# epoch 5 / 10: loss 1.630249
# epoch 6 / 10: loss 1.698263
# epoch 7 / 10: loss 1.566333
# epoch 8 / 10: loss 1.665177
# epoch 9 / 10: loss 1.502033
# epoch 9 / 10: loss 1.505003
# Validation accuracy:  0.479
# round 69 / 500
# epoch 0 / 10: loss 2.302574
# epoch 0 / 10: loss 1.809003
# epoch 1 / 10: loss 1.738206
# epoch 2 / 10: loss 1.654022
# epoch 3 / 10: loss 1.720010
# epoch 4 / 10: loss 1.720924
# epoch 4 / 10: loss 1.624506
# epoch 5 / 10: loss 1.698548
# epoch 6 / 10: loss 1.572541
# epoch 7 / 10: loss 1.646937
# epoch 8 / 10: loss 1.530149
# epoch 9 / 10: loss 1.500517
# epoch 9 / 10: loss 1.614824
# Validation accuracy:  0.486
# round 70 / 500
# epoch 0 / 10: loss 2.302633
# epoch 0 / 10: loss 1.777089
# epoch 1 / 10: loss 1.875552
# epoch 2 / 10: loss 1.753638
# epoch 3 / 10: loss 1.787711
# epoch 4 / 10: loss 1.782091
# epoch 4 / 10: loss 1.604323
# epoch 5 / 10: loss 1.715987
# epoch 6 / 10: loss 1.625614
# epoch 7 / 10: loss 1.599206
# epoch 8 / 10: loss 1.559659
# epoch 9 / 10: loss 1.623454
# epoch 9 / 10: loss 1.638776
# Validation accuracy:  0.476
# round 71 / 500
# epoch 0 / 10: loss 2.304946
# epoch 0 / 10: loss 1.795703
# epoch 1 / 10: loss 1.782379
# epoch 2 / 10: loss 1.787236
# epoch 3 / 10: loss 1.691892
# epoch 4 / 10: loss 1.724209
# epoch 4 / 10: loss 1.821316
# epoch 5 / 10: loss 1.831441
# epoch 6 / 10: loss 1.734240
# epoch 7 / 10: loss 1.762411
# epoch 8 / 10: loss 1.643560
# epoch 9 / 10: loss 1.705784
# epoch 9 / 10: loss 1.783067
# Validation accuracy:  0.482
# round 72 / 500
# epoch 0 / 10: loss 2.304978
# epoch 0 / 10: loss 1.785554
# epoch 1 / 10: loss 1.791599
# epoch 2 / 10: loss 1.804654
# epoch 3 / 10: loss 1.824654
# epoch 4 / 10: loss 1.840087
# epoch 4 / 10: loss 1.784449
# epoch 5 / 10: loss 1.728874
# epoch 6 / 10: loss 1.768808
# epoch 7 / 10: loss 1.806291
# epoch 8 / 10: loss 1.811191
# epoch 9 / 10: loss 1.656899
# epoch 9 / 10: loss 1.735494
# Validation accuracy:  0.456
# round 73 / 500
# epoch 0 / 10: loss 2.305055
# epoch 0 / 10: loss 1.864766
# epoch 1 / 10: loss 1.804556
# epoch 2 / 10: loss 1.870027
# epoch 3 / 10: loss 1.771393
# epoch 4 / 10: loss 1.799990
# epoch 4 / 10: loss 1.723812
# epoch 5 / 10: loss 1.670893
# epoch 6 / 10: loss 1.795199
# epoch 7 / 10: loss 1.627731
# epoch 8 / 10: loss 1.701922
# epoch 9 / 10: loss 1.705025
# epoch 9 / 10: loss 1.704379
# Validation accuracy:  0.459
# round 74 / 500
# epoch 0 / 10: loss 2.305058
# epoch 0 / 10: loss 1.821049
# epoch 1 / 10: loss 1.863924
# epoch 2 / 10: loss 1.844085
# epoch 3 / 10: loss 1.824894
# epoch 4 / 10: loss 1.794742
# epoch 4 / 10: loss 1.794410
# epoch 5 / 10: loss 1.810542
# epoch 6 / 10: loss 1.642707
# epoch 7 / 10: loss 1.773706
# epoch 8 / 10: loss 1.755584
# epoch 9 / 10: loss 1.782217
# epoch 9 / 10: loss 1.634309
# Validation accuracy:  0.449
# round 75 / 500
# epoch 0 / 10: loss 2.305180
# epoch 0 / 10: loss 1.753429
# epoch 1 / 10: loss 1.766227
# epoch 2 / 10: loss 1.898389
# epoch 3 / 10: loss 1.768876
# epoch 4 / 10: loss 1.793196
# epoch 4 / 10: loss 1.783520
# epoch 5 / 10: loss 1.714959
# epoch 6 / 10: loss 1.698387
# epoch 7 / 10: loss 1.726003
# epoch 8 / 10: loss 1.704493
# epoch 9 / 10: loss 1.681677
# epoch 9 / 10: loss 1.779620
# Validation accuracy:  0.457
# round 76 / 500
# epoch 0 / 10: loss 2.302648
# epoch 0 / 10: loss 2.042250
# epoch 1 / 10: loss 1.790029
# epoch 2 / 10: loss 1.775336
# epoch 3 / 10: loss 1.738868
# epoch 4 / 10: loss 1.633763
# epoch 4 / 10: loss 1.589055
# epoch 5 / 10: loss 1.624430
# epoch 6 / 10: loss 1.608503
# epoch 7 / 10: loss 1.546300
# epoch 8 / 10: loss 1.576918
# epoch 9 / 10: loss 1.541516
# epoch 9 / 10: loss 1.536012
# Validation accuracy:  0.483
# round 77 / 500
# epoch 0 / 10: loss 2.302663
# epoch 0 / 10: loss 2.045276
# epoch 1 / 10: loss 1.820569
# epoch 2 / 10: loss 1.779557
# epoch 3 / 10: loss 1.749823
# epoch 4 / 10: loss 1.748448
# epoch 4 / 10: loss 1.738694
# epoch 5 / 10: loss 1.628582
# epoch 6 / 10: loss 1.620165
# epoch 7 / 10: loss 1.523031
# epoch 8 / 10: loss 1.531820
# epoch 9 / 10: loss 1.535974
# epoch 9 / 10: loss 1.572634
# Validation accuracy:  0.481
# round 78 / 500
# epoch 0 / 10: loss 2.302665
# epoch 0 / 10: loss 2.049231
# epoch 1 / 10: loss 1.858353
# epoch 2 / 10: loss 1.713439
# epoch 3 / 10: loss 1.672114
# epoch 4 / 10: loss 1.674792
# epoch 4 / 10: loss 1.631217
# epoch 5 / 10: loss 1.744693
# epoch 6 / 10: loss 1.550318
# epoch 7 / 10: loss 1.603059
# epoch 8 / 10: loss 1.604366
# epoch 9 / 10: loss 1.563874
# epoch 9 / 10: loss 1.534618
# Validation accuracy:  0.474
# round 79 / 500
# epoch 0 / 10: loss 2.302640
# epoch 0 / 10: loss 2.053381
# epoch 1 / 10: loss 1.836063
# epoch 2 / 10: loss 1.790287
# epoch 3 / 10: loss 1.682166
# epoch 4 / 10: loss 1.604714
# epoch 4 / 10: loss 1.650097
# epoch 5 / 10: loss 1.721470
# epoch 6 / 10: loss 1.584723
# epoch 7 / 10: loss 1.646202
# epoch 8 / 10: loss 1.539388
# epoch 9 / 10: loss 1.460538
# epoch 9 / 10: loss 1.540756
# Validation accuracy:  0.481
# round 80 / 500
# epoch 0 / 10: loss 2.302635
# epoch 0 / 10: loss 2.127326
# epoch 1 / 10: loss 1.845240
# epoch 2 / 10: loss 1.751757
# epoch 3 / 10: loss 1.791503
# epoch 4 / 10: loss 1.675779
# epoch 4 / 10: loss 1.721033
# epoch 5 / 10: loss 1.547098
# epoch 6 / 10: loss 1.668372
# epoch 7 / 10: loss 1.563419
# epoch 8 / 10: loss 1.552562
# epoch 9 / 10: loss 1.547383
# epoch 9 / 10: loss 1.536151
# Validation accuracy:  0.471
# round 81 / 500
# epoch 0 / 10: loss 2.303700
# epoch 0 / 10: loss 2.300878
# epoch 1 / 10: loss 2.240315
# epoch 2 / 10: loss 2.127451
# epoch 3 / 10: loss 2.056721
# epoch 4 / 10: loss 2.026966
# epoch 4 / 10: loss 1.980546
# epoch 5 / 10: loss 1.934461
# epoch 6 / 10: loss 1.900707
# epoch 7 / 10: loss 1.944356
# epoch 8 / 10: loss 1.925186
# epoch 9 / 10: loss 1.794285
# epoch 9 / 10: loss 1.810715
# Validation accuracy:  0.353
# round 82 / 500
# epoch 0 / 10: loss 2.303709
# epoch 0 / 10: loss 2.300785
# epoch 1 / 10: loss 2.233620
# epoch 2 / 10: loss 2.137929
# epoch 3 / 10: loss 2.070160
# epoch 4 / 10: loss 2.029495
# epoch 4 / 10: loss 1.984506
# epoch 5 / 10: loss 1.978348
# epoch 6 / 10: loss 1.979330
# epoch 7 / 10: loss 1.878412
# epoch 8 / 10: loss 1.854665
# epoch 9 / 10: loss 1.818872
# epoch 9 / 10: loss 1.801945
# Validation accuracy:  0.354
# round 83 / 500
# epoch 0 / 10: loss 2.303724
# epoch 0 / 10: loss 2.300158
# epoch 1 / 10: loss 2.245600
# epoch 2 / 10: loss 2.156594
# epoch 3 / 10: loss 2.026846
# epoch 4 / 10: loss 1.975216
# epoch 4 / 10: loss 1.914669
# epoch 5 / 10: loss 1.960579
# epoch 6 / 10: loss 1.920517
# epoch 7 / 10: loss 1.886665
# epoch 8 / 10: loss 1.883343
# epoch 9 / 10: loss 1.848045
# epoch 9 / 10: loss 1.804371
# Validation accuracy:  0.356
# round 84 / 500
# epoch 0 / 10: loss 2.303792
# epoch 0 / 10: loss 2.301060
# epoch 1 / 10: loss 2.255639
# epoch 2 / 10: loss 2.145187
# epoch 3 / 10: loss 2.047024
# epoch 4 / 10: loss 1.997483
# epoch 4 / 10: loss 1.948686
# epoch 5 / 10: loss 1.911174
# epoch 6 / 10: loss 1.950251
# epoch 7 / 10: loss 1.903115
# epoch 8 / 10: loss 1.861358
# epoch 9 / 10: loss 1.892425
# epoch 9 / 10: loss 1.826445
# Validation accuracy:  0.36
# round 85 / 500
# epoch 0 / 10: loss 2.303754
# epoch 0 / 10: loss 2.300411
# epoch 1 / 10: loss 2.242288
# epoch 2 / 10: loss 2.148441
# epoch 3 / 10: loss 2.028758
# epoch 4 / 10: loss 2.021373
# epoch 4 / 10: loss 1.946077
# epoch 5 / 10: loss 1.935970
# epoch 6 / 10: loss 1.866500
# epoch 7 / 10: loss 1.861856
# epoch 8 / 10: loss 1.861107
# epoch 9 / 10: loss 1.867381
# epoch 9 / 10: loss 1.809718
# Validation accuracy:  0.363
# round 86 / 500
# epoch 0 / 10: loss 2.303418
# epoch 0 / 10: loss 2.254836
# epoch 1 / 10: loss 2.068778
# epoch 2 / 10: loss 1.924493
# epoch 3 / 10: loss 1.923264
# epoch 4 / 10: loss 1.809381
# epoch 4 / 10: loss 1.826863
# epoch 5 / 10: loss 1.750052
# epoch 6 / 10: loss 1.846895
# epoch 7 / 10: loss 1.726425
# epoch 8 / 10: loss 1.660655
# epoch 9 / 10: loss 1.671126
# epoch 9 / 10: loss 1.722042
# Validation accuracy:  0.435
# round 87 / 500
# epoch 0 / 10: loss 2.303464
# epoch 0 / 10: loss 2.254550
# epoch 1 / 10: loss 2.072545
# epoch 2 / 10: loss 1.973849
# epoch 3 / 10: loss 1.887833
# epoch 4 / 10: loss 1.829815
# epoch 4 / 10: loss 1.771701
# epoch 5 / 10: loss 1.746935
# epoch 6 / 10: loss 1.687151
# epoch 7 / 10: loss 1.739434
# epoch 8 / 10: loss 1.661769
# epoch 9 / 10: loss 1.768488
# epoch 9 / 10: loss 1.772946
# Validation accuracy:  0.441
# round 88 / 500
# epoch 0 / 10: loss 2.303480
# epoch 0 / 10: loss 2.255584
# epoch 1 / 10: loss 2.099706
# epoch 2 / 10: loss 1.974947
# epoch 3 / 10: loss 1.895166
# epoch 4 / 10: loss 1.814466
# epoch 4 / 10: loss 1.795272
# epoch 5 / 10: loss 1.783656
# epoch 6 / 10: loss 1.720274
# epoch 7 / 10: loss 1.683632
# epoch 8 / 10: loss 1.697037
# epoch 9 / 10: loss 1.708547
# epoch 9 / 10: loss 1.632510
# Validation accuracy:  0.439
# round 89 / 500
# epoch 0 / 10: loss 2.303537
# epoch 0 / 10: loss 2.255987
# epoch 1 / 10: loss 2.030118
# epoch 2 / 10: loss 2.044106
# epoch 3 / 10: loss 1.870627
# epoch 4 / 10: loss 1.888471
# epoch 4 / 10: loss 1.896626
# epoch 5 / 10: loss 1.658369
# epoch 6 / 10: loss 1.845634
# epoch 7 / 10: loss 1.694733
# epoch 8 / 10: loss 1.753680
# epoch 9 / 10: loss 1.659042
# epoch 9 / 10: loss 1.736357
# Validation accuracy:  0.441
# round 90 / 500
# epoch 0 / 10: loss 2.303523
# epoch 0 / 10: loss 2.255824
# epoch 1 / 10: loss 2.059784
# epoch 2 / 10: loss 1.914615
# epoch 3 / 10: loss 1.905110
# epoch 4 / 10: loss 1.816777
# epoch 4 / 10: loss 1.809402
# epoch 5 / 10: loss 1.784740
# epoch 6 / 10: loss 1.813945
# epoch 7 / 10: loss 1.742338
# epoch 8 / 10: loss 1.658628
# epoch 9 / 10: loss 1.649816
# epoch 9 / 10: loss 1.717799
# Validation accuracy:  0.436
# round 91 / 500
# epoch 0 / 10: loss 2.302604
# epoch 0 / 10: loss 1.792043
# epoch 1 / 10: loss 1.724513
# epoch 2 / 10: loss 1.550863
# epoch 3 / 10: loss 1.522265
# epoch 4 / 10: loss 1.560278
# epoch 4 / 10: loss 1.589943
# epoch 5 / 10: loss 1.563237
# epoch 6 / 10: loss 1.568474
# epoch 7 / 10: loss 1.477274
# epoch 8 / 10: loss 1.499926
# epoch 9 / 10: loss 1.425082
# epoch 9 / 10: loss 1.477151
# Validation accuracy:  0.507
# round 92 / 500
# epoch 0 / 10: loss 2.302560
# epoch 0 / 10: loss 1.781510
# epoch 1 / 10: loss 1.653591
# epoch 2 / 10: loss 1.623192
# epoch 3 / 10: loss 1.601718
# epoch 4 / 10: loss 1.585343
# epoch 4 / 10: loss 1.627808
# epoch 5 / 10: loss 1.485884
# epoch 6 / 10: loss 1.545772
# epoch 7 / 10: loss 1.613642
# epoch 8 / 10: loss 1.405831
# epoch 9 / 10: loss 1.550499
# epoch 9 / 10: loss 1.558404
# Validation accuracy:  0.517
# round 93 / 500
# epoch 0 / 10: loss 2.302645
# epoch 0 / 10: loss 1.755701
# epoch 1 / 10: loss 1.702170
# epoch 2 / 10: loss 1.597420
# epoch 3 / 10: loss 1.661316
# epoch 4 / 10: loss 1.568971
# epoch 4 / 10: loss 1.505387
# epoch 5 / 10: loss 1.500753
# epoch 6 / 10: loss 1.549394
# epoch 7 / 10: loss 1.524364
# epoch 8 / 10: loss 1.498207
# epoch 9 / 10: loss 1.540251
# epoch 9 / 10: loss 1.504492
# Validation accuracy:  0.515
# round 94 / 500
# epoch 0 / 10: loss 2.302617
# epoch 0 / 10: loss 1.665979
# epoch 1 / 10: loss 1.638663
# epoch 2 / 10: loss 1.685834
# epoch 3 / 10: loss 1.606122
# epoch 4 / 10: loss 1.683535
# epoch 4 / 10: loss 1.439041
# epoch 5 / 10: loss 1.504187
# epoch 6 / 10: loss 1.447059
# epoch 7 / 10: loss 1.559890
# epoch 8 / 10: loss 1.523314
# epoch 9 / 10: loss 1.486073
# epoch 9 / 10: loss 1.522501
# Validation accuracy:  0.512
# round 95 / 500
# epoch 0 / 10: loss 2.302596
# epoch 0 / 10: loss 1.739504
# epoch 1 / 10: loss 1.725161
# epoch 2 / 10: loss 1.567590
# epoch 3 / 10: loss 1.604544
# epoch 4 / 10: loss 1.548470
# epoch 4 / 10: loss 1.582919
# epoch 5 / 10: loss 1.658876
# epoch 6 / 10: loss 1.582523
# epoch 7 / 10: loss 1.557220
# epoch 8 / 10: loss 1.438781
# epoch 9 / 10: loss 1.441326
# epoch 9 / 10: loss 1.470177
# Validation accuracy:  0.497
# round 96 / 500
# epoch 0 / 10: loss 2.317287
# epoch 0 / 10: loss 2.014022
# epoch 1 / 10: loss 1.965079
# epoch 2 / 10: loss 2.003905
# epoch 3 / 10: loss 2.007225
# epoch 4 / 10: loss 1.953153
# epoch 4 / 10: loss 1.941225
# epoch 5 / 10: loss 1.934920
# epoch 6 / 10: loss 2.050030
# epoch 7 / 10: loss 1.947670
# epoch 8 / 10: loss 1.959266
# epoch 9 / 10: loss 1.969155
# epoch 9 / 10: loss 1.916873
# Validation accuracy:  0.398
# round 97 / 500
# epoch 0 / 10: loss 2.317550
# epoch 0 / 10: loss 2.051927
# epoch 1 / 10: loss 1.952711
# epoch 2 / 10: loss 2.022659
# epoch 3 / 10: loss 1.913395
# epoch 4 / 10: loss 1.984446
# epoch 4 / 10: loss 1.965700
# epoch 5 / 10: loss 1.873195
# epoch 6 / 10: loss 1.878980
# epoch 7 / 10: loss 1.938364
# epoch 8 / 10: loss 1.907362
# epoch 9 / 10: loss 1.892793
# epoch 9 / 10: loss 1.930668
# Validation accuracy:  0.398
# round 98 / 500
# epoch 0 / 10: loss 2.317834
# epoch 0 / 10: loss 1.944218
# epoch 1 / 10: loss 2.016367
# epoch 2 / 10: loss 2.021590
# epoch 3 / 10: loss 1.973691
# epoch 4 / 10: loss 1.959338
# epoch 4 / 10: loss 1.947500
# epoch 5 / 10: loss 2.020310
# epoch 6 / 10: loss 2.014922
# epoch 7 / 10: loss 1.960722
# epoch 8 / 10: loss 1.935705
# epoch 9 / 10: loss 1.987681
# epoch 9 / 10: loss 1.902845
# Validation accuracy:  0.403
# round 99 / 500
# epoch 0 / 10: loss 2.318277
# epoch 0 / 10: loss 1.986196
# epoch 1 / 10: loss 1.954498
# epoch 2 / 10: loss 1.954820
# epoch 3 / 10: loss 1.976053
# epoch 4 / 10: loss 1.990604
# epoch 4 / 10: loss 1.969585
# epoch 5 / 10: loss 1.910441
# epoch 6 / 10: loss 1.972648
# epoch 7 / 10: loss 1.926501
# epoch 8 / 10: loss 1.929334
# epoch 9 / 10: loss 1.980633
# epoch 9 / 10: loss 1.890317
# Validation accuracy:  0.402
# round 100 / 500
# epoch 0 / 10: loss 2.318623
# epoch 0 / 10: loss 1.929876
# epoch 1 / 10: loss 1.970211
# epoch 2 / 10: loss 1.922038
# epoch 3 / 10: loss 1.936413
# epoch 4 / 10: loss 1.974185
# epoch 4 / 10: loss 1.971827
# epoch 5 / 10: loss 1.953605
# epoch 6 / 10: loss 1.936422
# epoch 7 / 10: loss 1.944796
# epoch 8 / 10: loss 1.932040
# epoch 9 / 10: loss 1.992616
# epoch 9 / 10: loss 1.948029
# Validation accuracy:  0.38
# round 101 / 500
# epoch 0 / 10: loss 2.302634
# epoch 0 / 10: loss 2.066432
# epoch 1 / 10: loss 1.923988
# epoch 2 / 10: loss 1.728071
# epoch 3 / 10: loss 1.733090
# epoch 4 / 10: loss 1.731762
# epoch 4 / 10: loss 1.694234
# epoch 5 / 10: loss 1.658765
# epoch 6 / 10: loss 1.639995
# epoch 7 / 10: loss 1.557932
# epoch 8 / 10: loss 1.577465
# epoch 9 / 10: loss 1.624237
# epoch 9 / 10: loss 1.535193
# Validation accuracy:  0.473
# round 102 / 500
# epoch 0 / 10: loss 2.302640
# epoch 0 / 10: loss 2.070744
# epoch 1 / 10: loss 1.915214
# epoch 2 / 10: loss 1.805074
# epoch 3 / 10: loss 1.704217
# epoch 4 / 10: loss 1.708730
# epoch 4 / 10: loss 1.729916
# epoch 5 / 10: loss 1.677099
# epoch 6 / 10: loss 1.616011
# epoch 7 / 10: loss 1.544090
# epoch 8 / 10: loss 1.661342
# epoch 9 / 10: loss 1.718330
# epoch 9 / 10: loss 1.505685
# Validation accuracy:  0.465
# round 103 / 500
# epoch 0 / 10: loss 2.302648
# epoch 0 / 10: loss 2.099396
# epoch 1 / 10: loss 1.835325
# epoch 2 / 10: loss 1.708821
# epoch 3 / 10: loss 1.783837
# epoch 4 / 10: loss 1.649461
# epoch 4 / 10: loss 1.656736
# epoch 5 / 10: loss 1.685756
# epoch 6 / 10: loss 1.600638
# epoch 7 / 10: loss 1.615298
# epoch 8 / 10: loss 1.558620
# epoch 9 / 10: loss 1.545579
# epoch 9 / 10: loss 1.556280
# Validation accuracy:  0.461
# round 104 / 500
# epoch 0 / 10: loss 2.302599
# epoch 0 / 10: loss 2.082489
# epoch 1 / 10: loss 1.843398
# epoch 2 / 10: loss 1.783045
# epoch 3 / 10: loss 1.678297
# epoch 4 / 10: loss 1.753971
# epoch 4 / 10: loss 1.697053
# epoch 5 / 10: loss 1.671101
# epoch 6 / 10: loss 1.662803
# epoch 7 / 10: loss 1.579547
# epoch 8 / 10: loss 1.615327
# epoch 9 / 10: loss 1.610116
# epoch 9 / 10: loss 1.691181
# Validation accuracy:  0.464
# round 105 / 500
# epoch 0 / 10: loss 2.302602
# epoch 0 / 10: loss 2.075541
# epoch 1 / 10: loss 1.894688
# epoch 2 / 10: loss 1.864836
# epoch 3 / 10: loss 1.674306
# epoch 4 / 10: loss 1.710504
# epoch 4 / 10: loss 1.642768
# epoch 5 / 10: loss 1.710394
# epoch 6 / 10: loss 1.577892
# epoch 7 / 10: loss 1.603486
# epoch 8 / 10: loss 1.641911
# epoch 9 / 10: loss 1.576860
# epoch 9 / 10: loss 1.560545
# Validation accuracy:  0.474
# round 106 / 500
# epoch 0 / 10: loss 2.302638
# epoch 0 / 10: loss 2.301575
# epoch 1 / 10: loss 2.293479
# epoch 2 / 10: loss 2.263100
# epoch 3 / 10: loss 2.185146
# epoch 4 / 10: loss 2.114189
# epoch 4 / 10: loss 2.061659
# epoch 5 / 10: loss 2.017737
# epoch 6 / 10: loss 2.062507
# epoch 7 / 10: loss 2.010552
# epoch 8 / 10: loss 2.007118
# epoch 9 / 10: loss 1.991412
# epoch 9 / 10: loss 1.925166
# Validation accuracy:  0.301
# round 107 / 500
# epoch 0 / 10: loss 2.302666
# epoch 0 / 10: loss 2.301473
# epoch 1 / 10: loss 2.295549
# epoch 2 / 10: loss 2.258332
# epoch 3 / 10: loss 2.180092
# epoch 4 / 10: loss 2.148340
# epoch 4 / 10: loss 2.078238
# epoch 5 / 10: loss 2.037362
# epoch 6 / 10: loss 2.034668
# epoch 7 / 10: loss 2.004535
# epoch 8 / 10: loss 1.964252
# epoch 9 / 10: loss 1.931518
# epoch 9 / 10: loss 1.911954
# Validation accuracy:  0.302
# round 108 / 500
# epoch 0 / 10: loss 2.302638
# epoch 0 / 10: loss 2.301700
# epoch 1 / 10: loss 2.294608
# epoch 2 / 10: loss 2.250108
# epoch 3 / 10: loss 2.174607
# epoch 4 / 10: loss 2.154419
# epoch 4 / 10: loss 2.064050
# epoch 5 / 10: loss 2.055373
# epoch 6 / 10: loss 2.009850
# epoch 7 / 10: loss 1.970000
# epoch 8 / 10: loss 1.896397
# epoch 9 / 10: loss 1.954806
# epoch 9 / 10: loss 1.930803
# Validation accuracy:  0.306
# round 109 / 500
# epoch 0 / 10: loss 2.302695
# epoch 0 / 10: loss 2.301444
# epoch 1 / 10: loss 2.293883
# epoch 2 / 10: loss 2.250674
# epoch 3 / 10: loss 2.213370
# epoch 4 / 10: loss 2.129093
# epoch 4 / 10: loss 2.113371
# epoch 5 / 10: loss 2.041169
# epoch 6 / 10: loss 2.001863
# epoch 7 / 10: loss 2.010191
# epoch 8 / 10: loss 1.989080
# epoch 9 / 10: loss 1.949817
# epoch 9 / 10: loss 1.915092
# Validation accuracy:  0.309
# round 110 / 500
# epoch 0 / 10: loss 2.302666
# epoch 0 / 10: loss 2.301592
# epoch 1 / 10: loss 2.295666
# epoch 2 / 10: loss 2.258246
# epoch 3 / 10: loss 2.203541
# epoch 4 / 10: loss 2.178647
# epoch 4 / 10: loss 2.095329
# epoch 5 / 10: loss 2.033670
# epoch 6 / 10: loss 2.001592
# epoch 7 / 10: loss 1.993318
# epoch 8 / 10: loss 1.991122
# epoch 9 / 10: loss 1.965283
# epoch 9 / 10: loss 2.013681
# Validation accuracy:  0.301
# round 111 / 500
# epoch 0 / 10: loss 2.302595
# epoch 0 / 10: loss 1.855758
# epoch 1 / 10: loss 1.673499
# epoch 2 / 10: loss 1.636482
# epoch 3 / 10: loss 1.687228
# epoch 4 / 10: loss 1.491053
# epoch 4 / 10: loss 1.494615
# epoch 5 / 10: loss 1.551584
# epoch 6 / 10: loss 1.630004
# epoch 7 / 10: loss 1.553226
# epoch 8 / 10: loss 1.480334
# epoch 9 / 10: loss 1.543023
# epoch 9 / 10: loss 1.398410
# Validation accuracy:  0.495
# round 112 / 500
# epoch 0 / 10: loss 2.302629
# epoch 0 / 10: loss 1.921319
# epoch 1 / 10: loss 1.754489
# epoch 2 / 10: loss 1.629754
# epoch 3 / 10: loss 1.648558
# epoch 4 / 10: loss 1.546813
# epoch 4 / 10: loss 1.563430
# epoch 5 / 10: loss 1.587310
# epoch 6 / 10: loss 1.569769
# epoch 7 / 10: loss 1.645502
# epoch 8 / 10: loss 1.495682
# epoch 9 / 10: loss 1.539971
# epoch 9 / 10: loss 1.353457
# Validation accuracy:  0.495
# round 113 / 500
# epoch 0 / 10: loss 2.302589
# epoch 0 / 10: loss 1.842152
# epoch 1 / 10: loss 1.827141
# epoch 2 / 10: loss 1.673245
# epoch 3 / 10: loss 1.607250
# epoch 4 / 10: loss 1.649800
# epoch 4 / 10: loss 1.528513
# epoch 5 / 10: loss 1.630280
# epoch 6 / 10: loss 1.482134
# epoch 7 / 10: loss 1.588284
# epoch 8 / 10: loss 1.489984
# epoch 9 / 10: loss 1.485535
# epoch 9 / 10: loss 1.468057
# Validation accuracy:  0.491
# round 114 / 500
# epoch 0 / 10: loss 2.302567
# epoch 0 / 10: loss 1.848261
# epoch 1 / 10: loss 1.700885
# epoch 2 / 10: loss 1.593248
# epoch 3 / 10: loss 1.577152
# epoch 4 / 10: loss 1.600579
# epoch 4 / 10: loss 1.589471
# epoch 5 / 10: loss 1.552109
# epoch 6 / 10: loss 1.564852
# epoch 7 / 10: loss 1.715202
# epoch 8 / 10: loss 1.574511
# epoch 9 / 10: loss 1.577971
# epoch 9 / 10: loss 1.419713
# Validation accuracy:  0.485
# round 115 / 500
# epoch 0 / 10: loss 2.302624
# epoch 0 / 10: loss 1.904633
# epoch 1 / 10: loss 1.801884
# epoch 2 / 10: loss 1.742408
# epoch 3 / 10: loss 1.576226
# epoch 4 / 10: loss 1.574513
# epoch 4 / 10: loss 1.531399
# epoch 5 / 10: loss 1.509829
# epoch 6 / 10: loss 1.523340
# epoch 7 / 10: loss 1.604308
# epoch 8 / 10: loss 1.411933
# epoch 9 / 10: loss 1.497918
# epoch 9 / 10: loss 1.557558
# Validation accuracy:  0.5
# round 116 / 500
# epoch 0 / 10: loss 2.311777
# epoch 0 / 10: loss 1.892316
# epoch 1 / 10: loss 1.846896
# epoch 2 / 10: loss 1.906305
# epoch 3 / 10: loss 1.868865
# epoch 4 / 10: loss 1.788753
# epoch 4 / 10: loss 1.799683
# epoch 5 / 10: loss 1.883267
# epoch 6 / 10: loss 1.881576
# epoch 7 / 10: loss 1.872401
# epoch 8 / 10: loss 1.837145
# epoch 9 / 10: loss 1.806861
# epoch 9 / 10: loss 1.809130
# Validation accuracy:  0.441
# round 117 / 500
# epoch 0 / 10: loss 2.311978
# epoch 0 / 10: loss 1.877007
# epoch 1 / 10: loss 1.789674
# epoch 2 / 10: loss 1.860511
# epoch 3 / 10: loss 1.848937
# epoch 4 / 10: loss 1.829706
# epoch 4 / 10: loss 1.837661
# epoch 5 / 10: loss 1.856158
# epoch 6 / 10: loss 1.816825
# epoch 7 / 10: loss 1.743902
# epoch 8 / 10: loss 1.831518
# epoch 9 / 10: loss 1.854236
# epoch 9 / 10: loss 1.818491
# Validation accuracy:  0.434
# round 118 / 500
# epoch 0 / 10: loss 2.312182
# epoch 0 / 10: loss 1.876230
# epoch 1 / 10: loss 1.849493
# epoch 2 / 10: loss 1.866506
# epoch 3 / 10: loss 1.824183
# epoch 4 / 10: loss 1.829046
# epoch 4 / 10: loss 1.850834
# epoch 5 / 10: loss 1.913513
# epoch 6 / 10: loss 1.909852
# epoch 7 / 10: loss 1.804588
# epoch 8 / 10: loss 1.793037
# epoch 9 / 10: loss 1.796210
# epoch 9 / 10: loss 1.681956
# ...
# epoch 0 / 10: loss 2.302607
# epoch 0 / 10: loss 1.967858
# epoch 1 / 10: loss 1.792009
# epoch 2 / 10: loss 1.631393
# epoch 3 / 10: loss 1.653983
# epoch 4 / 10: loss 1.609364
# epoch 4 / 10: loss 1.607985
# epoch 5 / 10: loss 1.536281
# epoch 6 / 10: loss 1.581002
# epoch 7 / 10: loss 1.546302
# epoch 8 / 10: loss 1.649799
# epoch 9 / 10: loss 1.485289
# epoch 9 / 10: loss 1.493630
# Validation accuracy:  0.495
# round 484 / 500
# epoch 0 / 10: loss 2.302597
# epoch 0 / 10: loss 1.972314
# epoch 1 / 10: loss 1.789870
# epoch 2 / 10: loss 1.746388
# epoch 3 / 10: loss 1.678950
# epoch 4 / 10: loss 1.714280
# epoch 4 / 10: loss 1.581133
# epoch 5 / 10: loss 1.652667
# epoch 6 / 10: loss 1.509190
# epoch 7 / 10: loss 1.616485
# epoch 8 / 10: loss 1.566658
# epoch 9 / 10: loss 1.506103
# epoch 9 / 10: loss 1.425332
# Validation accuracy:  0.485
# round 485 / 500
# epoch 0 / 10: loss 2.302579
# epoch 0 / 10: loss 1.952726
# epoch 1 / 10: loss 1.825222
# epoch 2 / 10: loss 1.721271
# epoch 3 / 10: loss 1.637517
# epoch 4 / 10: loss 1.716655
# epoch 4 / 10: loss 1.588423
# epoch 5 / 10: loss 1.584030
# epoch 6 / 10: loss 1.581231
# epoch 7 / 10: loss 1.515515
# epoch 8 / 10: loss 1.506608
# epoch 9 / 10: loss 1.556397
# epoch 9 / 10: loss 1.487776
# Validation accuracy:  0.494
# round 486 / 500
# epoch 0 / 10: loss 2.302646
# epoch 0 / 10: loss 2.290215
# epoch 1 / 10: loss 2.149965
# epoch 2 / 10: loss 2.056684
# epoch 3 / 10: loss 2.023726
# epoch 4 / 10: loss 1.929503
# epoch 4 / 10: loss 1.835745
# epoch 5 / 10: loss 1.816463
# epoch 6 / 10: loss 1.791502
# epoch 7 / 10: loss 1.796043
# epoch 8 / 10: loss 1.756553
# epoch 9 / 10: loss 1.758423
# epoch 9 / 10: loss 1.748468
# Validation accuracy:  0.39
# round 487 / 500
# epoch 0 / 10: loss 2.302569
# epoch 0 / 10: loss 2.292426
# epoch 1 / 10: loss 2.128612
# epoch 2 / 10: loss 1.999412
# epoch 3 / 10: loss 1.981436
# epoch 4 / 10: loss 1.970931
# epoch 4 / 10: loss 1.966964
# epoch 5 / 10: loss 1.817779
# epoch 6 / 10: loss 1.881424
# epoch 7 / 10: loss 1.750471
# epoch 8 / 10: loss 1.713016
# epoch 9 / 10: loss 1.801009
# epoch 9 / 10: loss 1.822569
# Validation accuracy:  0.393
# round 488 / 500
# epoch 0 / 10: loss 2.302602
# epoch 0 / 10: loss 2.291481
# epoch 1 / 10: loss 2.153642
# epoch 2 / 10: loss 2.007783
# epoch 3 / 10: loss 1.959652
# epoch 4 / 10: loss 1.902638
# epoch 4 / 10: loss 1.903787
# epoch 5 / 10: loss 1.832251
# epoch 6 / 10: loss 1.780930
# epoch 7 / 10: loss 1.808375
# epoch 8 / 10: loss 1.753854
# epoch 9 / 10: loss 1.765300
# epoch 9 / 10: loss 1.743634
# Validation accuracy:  0.396
# round 489 / 500
# epoch 0 / 10: loss 2.302607
# epoch 0 / 10: loss 2.290731
# epoch 1 / 10: loss 2.146824
# epoch 2 / 10: loss 2.036978
# epoch 3 / 10: loss 1.957898
# epoch 4 / 10: loss 1.870150
# epoch 4 / 10: loss 1.822742
# epoch 5 / 10: loss 1.828693
# epoch 6 / 10: loss 1.852550
# epoch 7 / 10: loss 1.773470
# epoch 8 / 10: loss 1.772249
# epoch 9 / 10: loss 1.744412
# epoch 9 / 10: loss 1.712979
# Validation accuracy:  0.391
# round 490 / 500
# epoch 0 / 10: loss 2.302589
# epoch 0 / 10: loss 2.293069
# epoch 1 / 10: loss 2.144231
# epoch 2 / 10: loss 2.084704
# epoch 3 / 10: loss 2.019691
# epoch 4 / 10: loss 1.888756
# epoch 4 / 10: loss 1.880525
# epoch 5 / 10: loss 1.891163
# epoch 6 / 10: loss 1.747509
# epoch 7 / 10: loss 1.718239
# epoch 8 / 10: loss 1.788600
# epoch 9 / 10: loss 1.761098
# epoch 9 / 10: loss 1.729981
# Validation accuracy:  0.384
# round 491 / 500
# epoch 0 / 10: loss 2.302628
# epoch 0 / 10: loss 1.756196
# epoch 1 / 10: loss 1.699991
# epoch 2 / 10: loss 1.634833
# epoch 3 / 10: loss 1.611656
# epoch 4 / 10: loss 1.658316
# epoch 4 / 10: loss 1.535534
# epoch 5 / 10: loss 1.635805
# epoch 6 / 10: loss 1.559430
# epoch 7 / 10: loss 1.575193
# epoch 8 / 10: loss 1.664826
# epoch 9 / 10: loss 1.459056
# epoch 9 / 10: loss 1.442866
# Validation accuracy:  0.483
# round 492 / 500
# epoch 0 / 10: loss 2.302567
# epoch 0 / 10: loss 1.718836
# epoch 1 / 10: loss 1.810625
# epoch 2 / 10: loss 1.697873
# epoch 3 / 10: loss 1.588644
# epoch 4 / 10: loss 1.681432
# epoch 4 / 10: loss 1.604961
# epoch 5 / 10: loss 1.472138
# epoch 6 / 10: loss 1.562681
# epoch 7 / 10: loss 1.586507
# epoch 8 / 10: loss 1.509128
# epoch 9 / 10: loss 1.417925
# epoch 9 / 10: loss 1.496876
# Validation accuracy:  0.489
# round 493 / 500
# epoch 0 / 10: loss 2.302587
# epoch 0 / 10: loss 1.797866
# epoch 1 / 10: loss 1.805938
# epoch 2 / 10: loss 1.636537
# epoch 3 / 10: loss 1.539867
# epoch 4 / 10: loss 1.630031
# epoch 4 / 10: loss 1.470748
# epoch 5 / 10: loss 1.619052
# epoch 6 / 10: loss 1.592814
# epoch 7 / 10: loss 1.520089
# epoch 8 / 10: loss 1.525203
# epoch 9 / 10: loss 1.549952
# epoch 9 / 10: loss 1.449716
# Validation accuracy:  0.514
# round 494 / 500
# epoch 0 / 10: loss 2.302570
# epoch 0 / 10: loss 1.772974
# epoch 1 / 10: loss 1.827247
# epoch 2 / 10: loss 1.690495
# epoch 3 / 10: loss 1.684791
# epoch 4 / 10: loss 1.575420
# epoch 4 / 10: loss 1.624678
# epoch 5 / 10: loss 1.490911
# epoch 6 / 10: loss 1.574878
# epoch 7 / 10: loss 1.500667
# epoch 8 / 10: loss 1.610712
# epoch 9 / 10: loss 1.443594
# epoch 9 / 10: loss 1.431034
# Validation accuracy:  0.499
# round 495 / 500
# epoch 0 / 10: loss 2.302544
# epoch 0 / 10: loss 1.760621
# epoch 1 / 10: loss 1.575312
# epoch 2 / 10: loss 1.648955
# epoch 3 / 10: loss 1.715816
# epoch 4 / 10: loss 1.698325
# epoch 4 / 10: loss 1.739984
# epoch 5 / 10: loss 1.500058
# epoch 6 / 10: loss 1.521338
# epoch 7 / 10: loss 1.567989
# epoch 8 / 10: loss 1.475949
# epoch 9 / 10: loss 1.581440
# epoch 9 / 10: loss 1.601449
# Validation accuracy:  0.493
# round 496 / 500
# epoch 0 / 10: loss 2.302666
# epoch 0 / 10: loss 2.300795
# epoch 1 / 10: loss 2.271710
# epoch 2 / 10: loss 2.143637
# epoch 3 / 10: loss 2.071585
# epoch 4 / 10: loss 2.118345
# epoch 4 / 10: loss 2.016987
# epoch 5 / 10: loss 1.974174
# epoch 6 / 10: loss 1.942395
# epoch 7 / 10: loss 1.912600
# epoch 8 / 10: loss 1.916834
# epoch 9 / 10: loss 1.919561
# epoch 9 / 10: loss 1.881514
# Validation accuracy:  0.344
# round 497 / 500
# epoch 0 / 10: loss 2.302684
# epoch 0 / 10: loss 2.300319
# epoch 1 / 10: loss 2.269004
# epoch 2 / 10: loss 2.183488
# epoch 3 / 10: loss 2.055884
# epoch 4 / 10: loss 2.027548
# epoch 4 / 10: loss 2.005740
# epoch 5 / 10: loss 1.925293
# epoch 6 / 10: loss 1.937810
# epoch 7 / 10: loss 1.868918
# epoch 8 / 10: loss 1.837708
# epoch 9 / 10: loss 1.908212
# epoch 9 / 10: loss 1.897160
# Validation accuracy:  0.346
# round 498 / 500
# epoch 0 / 10: loss 2.302626
# epoch 0 / 10: loss 2.299700
# epoch 1 / 10: loss 2.258281
# epoch 2 / 10: loss 2.147277
# epoch 3 / 10: loss 2.054476
# epoch 4 / 10: loss 2.043318
# epoch 4 / 10: loss 1.994817
# epoch 5 / 10: loss 1.936692
# epoch 6 / 10: loss 1.878529
# epoch 7 / 10: loss 1.898421
# epoch 8 / 10: loss 1.851282
# epoch 9 / 10: loss 1.912575
# epoch 9 / 10: loss 1.789936
# Validation accuracy:  0.347
# round 499 / 500
# epoch 0 / 10: loss 2.302649
# epoch 0 / 10: loss 2.300889
# epoch 1 / 10: loss 2.265119
# epoch 2 / 10: loss 2.160319
# epoch 3 / 10: loss 2.030338
# epoch 4 / 10: loss 2.092726
# epoch 4 / 10: loss 1.985044
# epoch 5 / 10: loss 1.989987
# epoch 6 / 10: loss 1.879861
# epoch 7 / 10: loss 1.933265
# epoch 8 / 10: loss 1.857424
# epoch 9 / 10: loss 1.834081
# epoch 9 / 10: loss 1.836235
# Validation accuracy:  0.348
# round 500 / 500
# epoch 0 / 10: loss 2.302651
# epoch 0 / 10: loss 2.300371
# epoch 1 / 10: loss 2.261692
# epoch 2 / 10: loss 2.180726
# epoch 3 / 10: loss 2.084105
# epoch 4 / 10: loss 2.072127
# epoch 4 / 10: loss 1.945475
# epoch 5 / 10: loss 1.936054
# epoch 6 / 10: loss 1.959614
# epoch 7 / 10: loss 1.946182
# epoch 8 / 10: loss 1.865516
# epoch 9 / 10: loss 1.842535
# epoch 9 / 10: loss 1.862853
# Validation accuracy:  0.343
# lr 1.001438e-05 reg 1.539671e+00 train accuracy: 0.261429 val accuracy: 0.267000
# lr 1.023457e-05 reg 1.472516e-03 train accuracy: 0.269796 val accuracy: 0.275000
# lr 1.043698e-05 reg 8.334367e-03 train accuracy: 0.270898 val accuracy: 0.282000
# lr 1.137200e-05 reg 7.947101e-03 train accuracy: 0.278061 val accuracy: 0.286000
# lr 1.183141e-05 reg 3.392887e+00 train accuracy: 0.279061 val accuracy: 0.284000
# lr 1.365591e-05 reg 2.936906e-02 train accuracy: 0.303306 val accuracy: 0.301000
# lr 1.447699e-05 reg 1.459586e-03 train accuracy: 0.312939 val accuracy: 0.305000
# lr 1.467892e-05 reg 8.530860e-02 train accuracy: 0.316347 val accuracy: 0.308000
# lr 1.545465e-05 reg 1.328492e-04 train accuracy: 0.324531 val accuracy: 0.323000
# lr 1.850637e-05 reg 1.206705e+00 train accuracy: 0.335265 val accuracy: 0.331000
# lr 1.872182e-05 reg 1.049778e-04 train accuracy: 0.340469 val accuracy: 0.338000
# lr 2.020358e-05 reg 2.550115e-02 train accuracy: 0.350082 val accuracy: 0.343000
# lr 2.221522e-05 reg 2.182704e-04 train accuracy: 0.357245 val accuracy: 0.360000
# lr 2.241664e-05 reg 4.190409e-01 train accuracy: 0.357755 val accuracy: 0.363000
# lr 2.243094e-05 reg 1.181510e-01 train accuracy: 0.355918 val accuracy: 0.356000
# lr 2.263018e-05 reg 3.771667e+00 train accuracy: 0.342102 val accuracy: 0.337000
# lr 2.464002e-05 reg 2.321772e-02 train accuracy: 0.367265 val accuracy: 0.373000
# lr 2.868994e-05 reg 6.516254e-01 train accuracy: 0.376898 val accuracy: 0.384000
# lr 2.884050e-05 reg 1.421317e-04 train accuracy: 0.382286 val accuracy: 0.391000
# lr 2.985037e-05 reg 1.232042e+00 train accuracy: 0.374755 val accuracy: 0.370000
# lr 3.057353e-05 reg 1.692242e-04 train accuracy: 0.388082 val accuracy: 0.383000
# lr 3.328284e-05 reg 1.991773e-03 train accuracy: 0.391776 val accuracy: 0.384000
# lr 3.661323e-05 reg 1.160537e-01 train accuracy: 0.401184 val accuracy: 0.396000
# lr 3.678033e-05 reg 1.742913e-03 train accuracy: 0.402531 val accuracy: 0.405000
# lr 3.685435e-05 reg 3.371590e+00 train accuracy: 0.377531 val accuracy: 0.381000
# lr 3.746535e-05 reg 1.446715e-04 train accuracy: 0.407612 val accuracy: 0.412000
# lr 4.106413e-05 reg 1.735142e-03 train accuracy: 0.412082 val accuracy: 0.419000
# lr 4.365208e-05 reg 8.697247e+00 train accuracy: 0.357673 val accuracy: 0.366000
# lr 4.497998e-05 reg 3.685355e-03 train accuracy: 0.420143 val accuracy: 0.429000
# lr 4.962255e-05 reg 3.283686e-01 train accuracy: 0.427449 val accuracy: 0.436000
# lr 5.311953e-05 reg 4.928465e-02 train accuracy: 0.437796 val accuracy: 0.437000
# lr 5.611235e-05 reg 7.630651e-02 train accuracy: 0.439184 val accuracy: 0.454000
# lr 5.640896e-05 reg 6.763638e-04 train accuracy: 0.441041 val accuracy: 0.443000
# lr 5.852528e-05 reg 1.363842e+00 train accuracy: 0.427347 val accuracy: 0.431000
# lr 6.498648e-05 reg 2.609564e-02 train accuracy: 0.455286 val accuracy: 0.458000
# lr 6.595418e-05 reg 1.184732e-04 train accuracy: 0.456816 val accuracy: 0.453000
# lr 7.797113e-05 reg 2.166118e+00 train accuracy: 0.436939 val accuracy: 0.442000
# lr 7.936907e-05 reg 7.689277e-04 train accuracy: 0.470551 val accuracy: 0.464000
# lr 8.023599e-05 reg 1.600057e-02 train accuracy: 0.472878 val accuracy: 0.467000
# lr 8.200913e-05 reg 3.848396e-03 train accuracy: 0.473020 val accuracy: 0.465000
# lr 8.243539e-05 reg 7.993043e-04 train accuracy: 0.472245 val accuracy: 0.471000
# lr 9.468916e-05 reg 1.208462e-02 train accuracy: 0.484102 val accuracy: 0.474000
# lr 1.039629e-04 reg 3.116551e-01 train accuracy: 0.484388 val accuracy: 0.466000
# lr 1.103783e-04 reg 1.792997e-02 train accuracy: 0.493388 val accuracy: 0.471000
# lr 1.194336e-04 reg 2.961615e-03 train accuracy: 0.502184 val accuracy: 0.463000
# lr 1.261003e-04 reg 3.199145e-02 train accuracy: 0.505306 val accuracy: 0.470000
# lr 1.271636e-04 reg 8.561495e-02 train accuracy: 0.502918 val accuracy: 0.484000
# lr 1.284745e-04 reg 2.440892e-01 train accuracy: 0.498469 val accuracy: 0.479000
# lr 1.407901e-04 reg 2.722107e-03 train accuracy: 0.510633 val accuracy: 0.494000
# lr 1.442432e-04 reg 8.131590e+00 train accuracy: 0.376041 val accuracy: 0.373000
# lr 1.469067e-04 reg 2.110258e-02 train accuracy: 0.507449 val accuracy: 0.497000
# lr 1.475151e-04 reg 2.315173e-04 train accuracy: 0.512245 val accuracy: 0.485000
# lr 1.534388e-04 reg 6.709567e-01 train accuracy: 0.496347 val accuracy: 0.471000
# lr 1.701826e-04 reg 1.561890e-01 train accuracy: 0.514755 val accuracy: 0.497000
# lr 1.867699e-04 reg 2.642641e+00 train accuracy: 0.454061 val accuracy: 0.451000
# lr 2.005868e-04 reg 7.145913e-04 train accuracy: 0.530000 val accuracy: 0.508000
# lr 2.088898e-04 reg 6.351313e+00 train accuracy: 0.402265 val accuracy: 0.412000
# lr 2.119295e-04 reg 2.285606e-02 train accuracy: 0.533122 val accuracy: 0.512000
# lr 2.344225e-04 reg 2.231771e-03 train accuracy: 0.534286 val accuracy: 0.516000
# lr 2.367744e-04 reg 1.259694e-04 train accuracy: 0.538531 val accuracy: 0.505000
# lr 2.437906e-04 reg 1.298229e-04 train accuracy: 0.534510 val accuracy: 0.494000
# lr 2.698602e-04 reg 1.116065e-02 train accuracy: 0.543388 val accuracy: 0.500000
# lr 2.825146e-04 reg 1.314299e-02 train accuracy: 0.544694 val accuracy: 0.507000
# lr 3.111557e-04 reg 2.199490e-01 train accuracy: 0.534959 val accuracy: 0.506000
# lr 3.112397e-04 reg 5.723716e-02 train accuracy: 0.536857 val accuracy: 0.497000
# lr 3.134745e-04 reg 2.021723e-02 train accuracy: 0.540204 val accuracy: 0.496000
# lr 3.170032e-04 reg 3.216943e-01 train accuracy: 0.526633 val accuracy: 0.511000
# lr 3.184094e-04 reg 2.980895e-02 train accuracy: 0.540163 val accuracy: 0.496000
# lr 3.264846e-04 reg 3.604637e-04 train accuracy: 0.537980 val accuracy: 0.496000
# lr 3.674036e-04 reg 4.193080e+00 train accuracy: 0.423918 val accuracy: 0.435000
# lr 3.776656e-04 reg 2.091937e-01 train accuracy: 0.534367 val accuracy: 0.508000
# lr 3.823004e-04 reg 4.893643e-03 train accuracy: 0.542184 val accuracy: 0.504000
# lr 3.908504e-04 reg 4.217181e+00 train accuracy: 0.419673 val accuracy: 0.428000
# lr 3.946533e-04 reg 2.454428e-02 train accuracy: 0.547327 val accuracy: 0.507000
# lr 4.250454e-04 reg 5.135006e-02 train accuracy: 0.544633 val accuracy: 0.504000
# lr 4.425951e-04 reg 3.774456e-02 train accuracy: 0.548102 val accuracy: 0.496000
# lr 4.456617e-04 reg 3.508259e+00 train accuracy: 0.421510 val accuracy: 0.433000
# lr 4.655842e-04 reg 1.268226e-03 train accuracy: 0.547245 val accuracy: 0.498000
# lr 4.906725e-04 reg 1.932152e-01 train accuracy: 0.531347 val accuracy: 0.513000
# lr 5.072563e-04 reg 5.651731e-01 train accuracy: 0.511000 val accuracy: 0.495000
# lr 5.073723e-04 reg 1.230129e+00 train accuracy: 0.475000 val accuracy: 0.462000
# lr 5.441232e-04 reg 4.702420e-04 train accuracy: 0.548612 val accuracy: 0.478000
# lr 5.719859e-04 reg 1.689168e-03 train accuracy: 0.543041 val accuracy: 0.497000
# lr 5.753431e-04 reg 1.232693e-01 train accuracy: 0.532122 val accuracy: 0.485000
# lr 6.400184e-04 reg 3.648632e+00 train accuracy: 0.417898 val accuracy: 0.402000
# lr 6.642626e-04 reg 8.721474e-04 train accuracy: 0.536878 val accuracy: 0.494000
# lr 6.676407e-04 reg 2.614505e-03 train accuracy: 0.543041 val accuracy: 0.496000
# lr 6.859531e-04 reg 8.246104e+00 train accuracy: 0.364592 val accuracy: 0.367000
# lr 6.895540e-04 reg 2.538931e-04 train accuracy: 0.536469 val accuracy: 0.493000
# lr 7.952945e-04 reg 4.244716e-04 train accuracy: 0.532041 val accuracy: 0.477000
# lr 7.953105e-04 reg 1.109086e+00 train accuracy: 0.466347 val accuracy: 0.459000
# lr 8.142808e-04 reg 1.118281e-01 train accuracy: 0.527000 val accuracy: 0.492000
# lr 8.456166e-04 reg 6.368041e-03 train accuracy: 0.534653 val accuracy: 0.487000
# lr 8.710697e-04 reg 4.563768e-04 train accuracy: 0.526612 val accuracy: 0.503000
# lr 8.763228e-04 reg 4.174738e-01 train accuracy: 0.503469 val accuracy: 0.483000
# lr 8.815110e-04 reg 8.946834e-01 train accuracy: 0.462531 val accuracy: 0.457000
# lr 8.842329e-04 reg 1.430610e-01 train accuracy: 0.517592 val accuracy: 0.491000
# lr 8.950079e-04 reg 6.169046e-01 train accuracy: 0.470122 val accuracy: 0.470000
# lr 8.967609e-04 reg 5.591984e+00 train accuracy: 0.380714 val accuracy: 0.380000
# lr 9.924382e-04 reg 3.556013e-03 train accuracy: 0.506490 val accuracy: 0.476000
# best validation accuracy achieved during cross-validation: 0.525000, in hidden size 182
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-4b9550792b3c> in <module>()
#      83             num_iters=3000, batch_size=600,
#      84             learning_rate=best_rate, learning_rate_decay=0.95, mu=0.5, mu_increase=1.0,
# ---> 85             reg=best_reg, verbose=True)
#      86
#      87
#
# TypeError: train() got an unexpected keyword argument 'num_iters'

# %%
input_size = 32 * 32 * 3
hidden_size = 182
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

best_stats = net.train(X_train, y_train, X_val, y_val,
            num_epochs=30, batch_size=600,
            learning_rate=2.544225e-04, learning_rate_decay=0.95, mu=0.5, mu_increase=1.0,
            reg= 2.231771e-03, verbose=True)

training_accuracy = np.mean(y_train == net.predict(X_train))
validation_accuracy = (net.predict(X_val) == y_val).mean()
print 'Validation accuracy: ', validation_accuracy

plt.subplot(2, 1, 1)
plt.plot(best_stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(best_stats['train_acc_history'], label='train')
plt.plot(best_stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.grid(True)
plt.show()

def show_net_weights(net):
  W1 = net.params['W1']
  W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
  plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
  plt.gca().axis('off')
  plt.show()

show_net_weights(net)
# Out:
# epoch 0 / 30: loss 2.302611
# epoch 1 / 30: loss 1.842487
# epoch 2 / 30: loss 1.716540
# epoch 3 / 30: loss 1.589369
# epoch 4 / 30: loss 1.597759
# epoch 6 / 30: loss 1.528289
# epoch 7 / 30: loss 1.634345
# epoch 8 / 30: loss 1.514943
# epoch 9 / 30: loss 1.526927
# epoch 11 / 30: loss 1.576825
# epoch 12 / 30: loss 1.470467
# epoch 13 / 30: loss 1.568033
# epoch 14 / 30: loss 1.455917
# epoch 16 / 30: loss 1.404229
# epoch 17 / 30: loss 1.418039
# epoch 18 / 30: loss 1.461737
# epoch 19 / 30: loss 1.434399
# epoch 20 / 30: loss 1.413488
# epoch 22 / 30: loss 1.430452
# epoch 23 / 30: loss 1.383968
# epoch 24 / 30: loss 1.457226
# epoch 25 / 30: loss 1.407308
# epoch 27 / 30: loss 1.357680
# epoch 28 / 30: loss 1.396266
# epoch 29 / 30: loss 1.301242
# Validation accuracy:  0.518

# %%
# visualize the weights of the best network
show_net_weights(net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (net.predict(X_test) == y_test).mean()
print 'Test accuracy: ', test_acc
# Out:
# Test accuracy:  0.528

# %% [markdown]
# # Fully-Connected Neural Nets
# In the previous homework you implemented a fully-connected two-layer neural network on CIFAR-10. The implementation was simple but not very modular since the loss and gradient were computed in a single monolithic function. This is manageable for a simple two-layer network, but would become impractical as we move to bigger models. Ideally we want to build networks using a more modular design so that we can implement different layer types in isolation and then snap them together into models with different architectures.
#
# In this exercise we will implement fully-connected networks using a more modular approach. For each layer we will implement a `forward` and a `backward` function. The `forward` function will receive inputs, weights, and other parameters and will return both an output and a `cache` object storing data needed for the backward pass, like this:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
# The backward pass will receive upstream derivatives and the `cache` object, and will return gradients with respect to the inputs and weights, like this:
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive derivative of loss with respect to outputs and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# In addition to implementing fully-connected networks of arbitrary depth, we will also explore different update rules for optimization, and introduce Dropout as a regularizer and Batch Normalization as a tool to more efficiently optimize deep networks.

# %%
# As usual, a bit of setup

import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# run the following from the cs231n directory and try again:
# python setup.py build_ext --inplace
# You may also need to restart your iPython kernel

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k, v in data.iteritems():
  print '%s: ' % k, v.shape
# Out:
# X_val:  (1000, 3, 32, 32)
# X_train:  (49000, 3, 32, 32)
# X_test:  (1000, 3, 32, 32)
# y_val:  (1000,)
# y_train:  (49000,)
# y_test:  (1000,)

# %% [markdown]
# # Affine layer: foward
# Open the file `cs231n/layers.py` and implement the `affine_forward` function.
#
# Once you are done you can test your implementaion by running the following:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)
out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around 1e-9.
print 'Testing affine_forward function:'
print 'difference: ', rel_error(out, correct_out)
# Out:
# Testing affine_forward function:
# difference:  9.76984946819e-10

# %% [markdown]
# # Affine layer: backward
# Now implement the `affine_backward` function and test your implementation using numeric gradient checking.

# %%
# Test the affine_backward function

x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around 1e-10
print 'Testing affine_backward function:'
print 'dx error: ', rel_error(dx_num, dx)
print 'dw error: ', rel_error(dw_num, dw)
print 'db error: ', rel_error(db_num, db)
# Out:
# Testing affine_backward function:
# dx error:  3.24098201864e-10
# dw error:  4.12380782703e-11
# db error:  1.36892058442e-11

# %% [markdown]
# # ReLU layer: forward
# Implement the forward pass for the ReLU activation function in the `relu_forward` function and test your implementation using the following:

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be around 1e-8
print 'Testing relu_forward function:'
print 'difference: ', rel_error(out, correct_out)
# Out:
# Testing relu_forward function:
# difference:  4.99999979802e-08

# %% [markdown]
# # ReLU layer: backward
# Now implement the backward pass for the ReLU activation function in the `relu_backward` function and test your implementation using numeric gradient checking:

# %%
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be around 1e-12
print 'Testing relu_backward function:'
print 'dx error: ', rel_error(dx_num, dx)
# Out:
# Testing relu_backward function:
# dx error:  3.27561103868e-12

# %% [markdown]
# # "Sandwich" layers
# There are some common patterns of layers that are frequently used in neural nets. For example, affine layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define several convenience layers in the file `cs231n/layer_utils.py`.
#
# For now take a look at the `affine_relu_forward` and `affine_relu_backward` functions, and run the following to numerically gradient check the backward pass:

# %%
from cs231n.layer_utils import affine_relu_forward, affine_relu_backward

x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

print 'Testing affine_relu_forward:'
print 'dx error: ', rel_error(dx_num, dx)
print 'dw error: ', rel_error(dw_num, dw)
print 'db error: ', rel_error(db_num, db)
# Out:
# Testing affine_relu_forward:
# dx error:  5.08528971482e-11
# dw error:  3.57116579019e-10
# db error:  6.70017306702e-12

# %% [markdown]
# # Loss layers: Softmax and SVM
# You implemented these loss functions in the last assignment, so we'll give them to you for free here. You should still make sure you understand how they work by looking at the implementations in `cs231n/layers.py`.
#
# You can make sure that the implementations are correct by running the following:

# %%
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)

dx_num = eval_numerical_gradient(lambda x: svm_loss(x, y)[0], x, verbose=False)
loss, dx = svm_loss(x, y)

# Test svm_loss function. Loss should be around 9 and dx error should be 1e-9
print 'Testing svm_loss:'
print 'loss: ', loss
print 'dx error: ', rel_error(dx_num, dx)

dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be 2.3 and dx error should be 1e-8
print '\nTesting softmax_loss:'
print 'loss: ', loss
print 'dx error: ', rel_error(dx_num, dx)
# Out:
# Testing svm_loss:
# loss:  9.00079451417
# dx error:  1.40215660067e-09
#
# Testing softmax_loss:
# loss:  2.30266498882
# dx error:  8.25426955911e-09

# %% [markdown]
# # Two-layer network
# In the previous assignment you implemented a two-layer neural network in a single monolithic class. Now that you have implemented modular versions of the necessary layers, you will reimplement the two layer network using these modular implementations.
#
# Open the file `cs231n/classifiers/fc_net.py` and complete the implementation of the `TwoLayerNet` class. This class will serve as a model for the other networks you will implement in this assignment, so read through it to make sure you understand the API. You can run the cell below to test your implementation.

# %%
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-2
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print 'Testing initialization ... '
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print 'Testing test-time forward pass ... '
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print 'Testing training loss (no regularization)'
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

for reg in [0.0, 0.7]:
  print 'Running numeric gradient check with reg = ', reg
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print '%s relative error: %.2e' % (name, rel_error(grad_num, grads[name]))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.83e-08
# W2 relative error: 3.48e-10
# b1 relative error: 6.55e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 2.85e-08
# b1 relative error: 1.35e-08
# b2 relative error: 9.09e-10

# %% [markdown]
# # Solver
# In the previous assignment, the logic for training models was coupled to the models themselves. Following a more modular design, for this assignment we have split the logic for training models into a separate class.
#
# Open the file `cs231n/solver.py` and read through it to familiarize yourself with the API. After doing so, use a `Solver` instance to train a `TwoLayerNet` that achieves at least `50%` accuracy on the validation set.

# %%
model = TwoLayerNet()
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################
solver = Solver(model, data,
                update_rule='sgd',
                optim_config={
                  'learning_rate': 1e-3,
                },
                lr_decay=0.95,
                num_epochs=10, batch_size=100,
                print_every=100)
solver.train()
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 4900) loss: 2.303253
# (Epoch 0 / 10) train acc: 0.126000; val_acc: 0.143000
# (Iteration 101 / 4900) loss: 1.773078
# (Iteration 201 / 4900) loss: 1.749995
# (Iteration 301 / 4900) loss: 1.563398
# (Iteration 401 / 4900) loss: 1.788354
# (Epoch 1 / 10) train acc: 0.470000; val_acc: 0.441000
# (Iteration 501 / 4900) loss: 1.720576
# (Iteration 601 / 4900) loss: 1.635965
# (Iteration 701 / 4900) loss: 1.464487
# (Iteration 801 / 4900) loss: 1.654657
# (Iteration 901 / 4900) loss: 1.529893
# (Epoch 2 / 10) train acc: 0.491000; val_acc: 0.440000
# (Iteration 1001 / 4900) loss: 1.591363
# (Iteration 1101 / 4900) loss: 1.413362
# (Iteration 1201 / 4900) loss: 1.353589
# (Iteration 1301 / 4900) loss: 1.543202
# (Iteration 1401 / 4900) loss: 1.366267
# (Epoch 3 / 10) train acc: 0.507000; val_acc: 0.465000
# (Iteration 1501 / 4900) loss: 1.404267
# (Iteration 1601 / 4900) loss: 1.489604
# (Iteration 1701 / 4900) loss: 1.387280
# (Iteration 1801 / 4900) loss: 1.416666
# (Iteration 1901 / 4900) loss: 1.258504
# (Epoch 4 / 10) train acc: 0.525000; val_acc: 0.491000
# (Iteration 2001 / 4900) loss: 1.487517
# (Iteration 2101 / 4900) loss: 1.271520
# (Iteration 2201 / 4900) loss: 1.191868
# (Iteration 2301 / 4900) loss: 1.358329
# (Iteration 2401 / 4900) loss: 1.380633
# (Epoch 5 / 10) train acc: 0.549000; val_acc: 0.479000
# (Iteration 2501 / 4900) loss: 1.195011
# (Iteration 2601 / 4900) loss: 1.323890
# (Iteration 2701 / 4900) loss: 1.293238
# (Iteration 2801 / 4900) loss: 1.296908
# (Iteration 2901 / 4900) loss: 1.109981
# (Epoch 6 / 10) train acc: 0.568000; val_acc: 0.509000
# (Iteration 3001 / 4900) loss: 1.185113
# (Iteration 3101 / 4900) loss: 1.205970
# (Iteration 3201 / 4900) loss: 0.880449
# (Iteration 3301 / 4900) loss: 1.296484
# (Iteration 3401 / 4900) loss: 1.136582
# (Epoch 7 / 10) train acc: 0.571000; val_acc: 0.513000
# (Iteration 3501 / 4900) loss: 1.132782
# (Iteration 3601 / 4900) loss: 1.156126
# (Iteration 3701 / 4900) loss: 1.067482
# (Iteration 3801 / 4900) loss: 1.073796
# (Iteration 3901 / 4900) loss: 1.276243
# (Epoch 8 / 10) train acc: 0.623000; val_acc: 0.534000
# (Iteration 4001 / 4900) loss: 1.221245
# (Iteration 4101 / 4900) loss: 1.031621
# (Iteration 4201 / 4900) loss: 1.205554
# (Iteration 4301 / 4900) loss: 1.273454
# (Iteration 4401 / 4900) loss: 1.231870
# (Epoch 9 / 10) train acc: 0.641000; val_acc: 0.495000
# (Iteration 4501 / 4900) loss: 1.396635
# (Iteration 4601 / 4900) loss: 1.217628
# (Iteration 4701 / 4900) loss: 1.049607
# (Iteration 4801 / 4900) loss: 1.145294
# (Epoch 10 / 10) train acc: 0.634000; val_acc: 0.541000

# %%
# Run this cell to visualize training loss and train / val accuracy

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# # Multilayer network
# Next you will implement a fully-connected network with an arbitrary number of hidden layers.
#
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the initialization, the forward pass, and the backward pass. For the moment don't worry about implementing dropout or batch normalization; we will add those features soon.

# %% [markdown]
# ## Initial loss and gradient check

# %% [markdown]
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors around 1e-6 or less.

# %%
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
  print 'Running check with reg = ', reg
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print 'Initial loss: ', loss

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print '%s relative error: %.2e' % (name, rel_error(grad_num, grads[name]))
# Out:
# Running check with reg =  0
# Initial loss:  3.42064665987
# W1 relative error: 2.98e-08
# W2 relative error: 2.04e-06
# b1 relative error: 5.86e-09
# b2 relative error: 6.26e-10
# Running check with reg =  3.14
# Initial loss:  7.29274057589
# W1 relative error: 1.14e-08
# W2 relative error: 6.59e-08
# b1 relative error: 2.29e-08
# b2 relative error: 1.39e-09

# %% [markdown]
# As another sanity check, make sure you can overfit a small dataset of 50 images. First we will try a three-layer network with 100 units in each hidden layer. You will need to tweak the learning rate and initialization scale, but you should be able to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 1e-2
learning_rate = 1e-3
model = FullyConnectedNet([100, 100],
              weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 9.530133
# (Epoch 0 / 20) train acc: 0.240000; val_acc: 0.107000
# (Epoch 1 / 20) train acc: 0.380000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.620000; val_acc: 0.114000
# (Epoch 3 / 20) train acc: 0.680000; val_acc: 0.177000
# (Epoch 4 / 20) train acc: 0.820000; val_acc: 0.144000
# (Epoch 5 / 20) train acc: 0.860000; val_acc: 0.152000
# (Iteration 11 / 40) loss: 0.319706
# (Epoch 6 / 20) train acc: 0.980000; val_acc: 0.163000
# (Epoch 7 / 20) train acc: 0.960000; val_acc: 0.166000
# (Epoch 8 / 20) train acc: 1.000000; val_acc: 0.164000
# (Epoch 9 / 20) train acc: 1.000000; val_acc: 0.166000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.162000
# (Iteration 21 / 40) loss: 0.075440
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.160000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.157000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.155000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.155000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.157000
# (Iteration 31 / 40) loss: 0.026700
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.159000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.161000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.159000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.161000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.163000

# %% [markdown]
# Now try to use a five-layer network with 100 units on each layer to overfit 50 training examples. Again you will have to adjust the learning rate and weight initialization, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate = 1e-3
weight_scale = 5e-2
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=10, num_epochs=20, batch_size=25,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                }
         )
solver.train()

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# (Iteration 1 / 40) loss: 15.863697
# (Epoch 0 / 20) train acc: 0.020000; val_acc: 0.022000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.054000
# (Epoch 2 / 20) train acc: 0.240000; val_acc: 0.079000
# (Epoch 3 / 20) train acc: 0.440000; val_acc: 0.093000
# (Epoch 4 / 20) train acc: 0.600000; val_acc: 0.100000
# (Epoch 5 / 20) train acc: 0.680000; val_acc: 0.109000
# (Iteration 11 / 40) loss: 1.950706
# (Epoch 6 / 20) train acc: 0.780000; val_acc: 0.110000
# (Epoch 7 / 20) train acc: 0.880000; val_acc: 0.113000
# (Epoch 8 / 20) train acc: 0.900000; val_acc: 0.108000
# (Epoch 9 / 20) train acc: 0.920000; val_acc: 0.114000
# (Epoch 10 / 20) train acc: 0.940000; val_acc: 0.112000
# (Iteration 21 / 40) loss: 0.615072
# (Epoch 11 / 20) train acc: 0.940000; val_acc: 0.122000
# (Epoch 12 / 20) train acc: 0.960000; val_acc: 0.119000
# (Epoch 13 / 20) train acc: 0.960000; val_acc: 0.124000
# (Epoch 14 / 20) train acc: 0.980000; val_acc: 0.121000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.119000
# (Iteration 31 / 40) loss: 0.128204
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.132000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.130000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.127000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.122000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.124000

# %% [markdown]
# # Inline question:
# Did you notice anything about the comparative difficulty of training the three-layer net vs training the five layer net?
#
# # Answer:
# [FILL THIS IN]

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# # SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochstic gradient descent.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than 1e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

print 'next_w error: ', rel_error(next_w, expected_next_w)
print 'velocity error: ', rel_error(expected_velocity, config['velocity'])
# Out:
# next_w error:  8.88234703351e-09
# velocity error:  4.26928774328e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
  print 'running with ', update_rule
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': 1e-2,
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.iteritems():
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  sgd
# (Iteration 1 / 200) loss: 6.030818
# (Epoch 0 / 5) train acc: 0.102000; val_acc: 0.096000
# (Iteration 11 / 200) loss: 3.045420
# (Iteration 21 / 200) loss: 2.278913
# (Iteration 31 / 200) loss: 2.462062
# (Epoch 1 / 5) train acc: 0.323000; val_acc: 0.251000
# (Iteration 41 / 200) loss: 2.028774
# (Iteration 51 / 200) loss: 2.141156
# (Iteration 61 / 200) loss: 1.950646
# (Iteration 71 / 200) loss: 1.743803
# (Epoch 2 / 5) train acc: 0.351000; val_acc: 0.297000
# (Iteration 81 / 200) loss: 1.820516
# (Iteration 91 / 200) loss: 1.596013
# (Iteration 101 / 200) loss: 1.769794
# (Iteration 111 / 200) loss: 1.722498
# (Epoch 3 / 5) train acc: 0.373000; val_acc: 0.309000
# (Iteration 121 / 200) loss: 1.886594
# (Iteration 131 / 200) loss: 1.792250
# (Iteration 141 / 200) loss: 1.870496
# (Iteration 151 / 200) loss: 1.623688
# (Epoch 4 / 5) train acc: 0.446000; val_acc: 0.311000
# (Iteration 161 / 200) loss: 1.716361
# (Iteration 171 / 200) loss: 1.690126
# (Iteration 181 / 200) loss: 1.671047
# (Iteration 191 / 200) loss: 1.548534
# (Epoch 5 / 5) train acc: 0.524000; val_acc: 0.319000
#
# running with  sgd_momentum
# (Iteration 1 / 200) loss: 11.415566
# (Epoch 0 / 5) train acc: 0.105000; val_acc: 0.078000
# (Iteration 11 / 200) loss: 2.565416
# (Iteration 21 / 200) loss: 2.192246
# (Iteration 31 / 200) loss: 2.131907
# (Epoch 1 / 5) train acc: 0.281000; val_acc: 0.272000
# (Iteration 41 / 200) loss: 2.006018
# (Iteration 51 / 200) loss: 1.883299
# (Iteration 61 / 200) loss: 2.027221
# (Iteration 71 / 200) loss: 2.025349
# (Epoch 2 / 5) train acc: 0.324000; val_acc: 0.283000
# (Iteration 81 / 200) loss: 1.885322
# (Iteration 91 / 200) loss: 1.971997
# (Iteration 101 / 200) loss: 1.920144
# (Iteration 111 / 200) loss: 1.805035
# (Epoch 3 / 5) train acc: 0.392000; val_acc: 0.331000
# (Iteration 121 / 200) loss: 1.585082
# (Iteration 131 / 200) loss: 1.665139
# (Iteration 141 / 200) loss: 1.445764
# (Iteration 151 / 200) loss: 1.553220
# (Epoch 4 / 5) train acc: 0.417000; val_acc: 0.328000
# (Iteration 161 / 200) loss: 1.808426
# (Iteration 171 / 200) loss: 1.669233
# (Iteration 181 / 200) loss: 1.700582
# (Iteration 191 / 200) loss: 1.667956
# (Epoch 5 / 5) train acc: 0.474000; val_acc: 0.376000

# %% [markdown]
# # RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation; you should see errors less than 1e-7
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

print 'next_w error: ', rel_error(expected_next_w, next_w)
print 'cache error: ', rel_error(expected_cache, config['cache'])
# Out:
# next_w error:  9.52468751104e-08
# cache error:  2.64779558072e-09

# %%
# Test Adam implementation; you should see errors around 1e-7 or less
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

print 'next_w error: ', rel_error(expected_next_w, next_w)
print 'v error: ', rel_error(expected_v, config['v'])
print 'm error: ', rel_error(expected_m, config['m'])
# Out:
# next_w error:  1.13956917985e-07
# v error:  4.20831403811e-09
# m error:  4.21496319311e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
  print 'running with ', update_rule
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': learning_rates[update_rule]
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.iteritems():
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  adam
# (Iteration 1 / 200) loss: 7.993409
# (Epoch 0 / 5) train acc: 0.012000; val_acc: 0.022000
# (Iteration 11 / 200) loss: 2.670932
# (Iteration 21 / 200) loss: 2.212371
# (Iteration 31 / 200) loss: 1.988857
# (Epoch 1 / 5) train acc: 0.377000; val_acc: 0.292000
# (Iteration 41 / 200) loss: 1.717360
# (Iteration 51 / 200) loss: 1.777652
# (Iteration 61 / 200) loss: 1.694077
# (Iteration 71 / 200) loss: 1.477598
# (Epoch 2 / 5) train acc: 0.458000; val_acc: 0.338000
# (Iteration 81 / 200) loss: 1.681243
# (Iteration 91 / 200) loss: 1.746404
# (Iteration 101 / 200) loss: 1.500132
# (Iteration 111 / 200) loss: 1.555772
# (Epoch 3 / 5) train acc: 0.534000; val_acc: 0.349000
# (Iteration 121 / 200) loss: 1.128096
# (Iteration 131 / 200) loss: 1.306029
# (Iteration 141 / 200) loss: 1.166439
# (Iteration 151 / 200) loss: 1.162251
# (Epoch 4 / 5) train acc: 0.588000; val_acc: 0.362000
# (Iteration 161 / 200) loss: 1.438424
# (Iteration 171 / 200) loss: 1.049782
# (Iteration 181 / 200) loss: 1.289194
# (Iteration 191 / 200) loss: 1.129136
# (Epoch 5 / 5) train acc: 0.611000; val_acc: 0.381000
#
# running with  rmsprop
# (Iteration 1 / 200) loss: 8.438436
# (Epoch 0 / 5) train acc: 0.022000; val_acc: 0.025000
# (Iteration 11 / 200) loss: 2.826527
# (Iteration 21 / 200) loss: 2.174261
# (Iteration 31 / 200) loss: 2.054758
# (Epoch 1 / 5) train acc: 0.357000; val_acc: 0.261000
# (Iteration 41 / 200) loss: 2.033773
# (Iteration 51 / 200) loss: 1.915119
# (Iteration 61 / 200) loss: 1.984580
# (Iteration 71 / 200) loss: 1.902075
# (Epoch 2 / 5) train acc: 0.421000; val_acc: 0.309000
# (Iteration 81 / 200) loss: 1.602582
# (Iteration 91 / 200) loss: 1.805027
# (Iteration 101 / 200) loss: 1.814739
# (Iteration 111 / 200) loss: 1.378920
# (Epoch 3 / 5) train acc: 0.426000; val_acc: 0.311000
# (Iteration 121 / 200) loss: 1.655801
# (Iteration 131 / 200) loss: 1.277762
# (Iteration 141 / 200) loss: 1.680151
# (Iteration 151 / 200) loss: 1.368219
# (Epoch 4 / 5) train acc: 0.504000; val_acc: 0.339000
# (Iteration 161 / 200) loss: 1.483509
# (Iteration 171 / 200) loss: 1.389530
# (Iteration 181 / 200) loss: 1.277282
# (Iteration 191 / 200) loss: 1.275311
# (Epoch 5 / 5) train acc: 0.566000; val_acc: 0.345000

# %% [markdown]
# # Train a good model!
# Train the best fully-connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully-connected net.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional nets rather than fully-connected nets.
#
# You might find it useful to complete the `BatchNormalization.ipynb` and `Dropout.ipynb` notebooks before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None
################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# batch normalization and dropout useful. Store your best model in the         #
# best_model variable.                                                         #
################################################################################
"""
cnt = 0
best_acc = 0
best_rate = 0
best_reg = 0
best_model = None
max_count = 100
for count in xrange(1, max_count + 1):  
  cnt += 1
  rate = 10 ** np.random.uniform(-4, -2) 
  reg = 10 ** np.random.uniform(-2, 0)
  print "round %d / %d" % (cnt, max_count)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2,reg=reg)
  solver = Solver(model, data,
                  num_epochs=20, batch_size=1000,
                  update_rule= 'adam',
                  optim_config={
                    'learning_rate': rate
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  if solver.best_val_acc > best_acc:
    best_acc = solver.best_val_acc
    best_rate = rate
    best_reg = reg
    best_model = model
  print solver.best_val_acc

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.iteritems():
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label=update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label=update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label=update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
"""
# Out:
# round 1 / 100
# (Iteration 1 / 980) loss: 99.825839
# (Epoch 0 / 20) train acc: 0.038000; val_acc: 0.030000
# (Iteration 11 / 980) loss: 94.421688
# (Iteration 21 / 980) loss: 91.019275
# (Iteration 31 / 980) loss: 87.783401
# (Iteration 41 / 980) loss: 84.544876
# (Epoch 1 / 20) train acc: 0.229000; val_acc: 0.221000
# (Iteration 51 / 980) loss: 81.504101
# (Iteration 61 / 980) loss: 78.652021
# (Iteration 71 / 980) loss: 75.897579
# (Iteration 81 / 980) loss: 73.358603
# (Iteration 91 / 980) loss: 70.802296
# (Epoch 2 / 20) train acc: 0.272000; val_acc: 0.273000
# (Iteration 101 / 980) loss: 68.367938
# (Iteration 111 / 980) loss: 66.116988
# (Iteration 121 / 980) loss: 63.878426
# (Iteration 131 / 980) loss: 61.711713
# (Iteration 141 / 980) loss: 59.673994
# (Epoch 3 / 20) train acc: 0.332000; val_acc: 0.314000
# (Iteration 151 / 980) loss: 57.592389
# (Iteration 161 / 980) loss: 55.698955
# (Iteration 171 / 980) loss: 53.805203
# (Iteration 181 / 980) loss: 52.016717
# (Iteration 191 / 980) loss: 50.291240
# (Epoch 4 / 20) train acc: 0.347000; val_acc: 0.337000
# (Iteration 201 / 980) loss: 48.598268
# (Iteration 211 / 980) loss: 46.984690
# (Iteration 221 / 980) loss: 45.442878
# (Iteration 231 / 980) loss: 43.903465
# (Iteration 241 / 980) loss: 42.493897
# (Epoch 5 / 20) train acc: 0.340000; val_acc: 0.347000
# (Iteration 251 / 980) loss: 40.987994
# (Iteration 261 / 980) loss: 39.722030
# (Iteration 271 / 980) loss: 38.381448
# (Iteration 281 / 980) loss: 37.099779
# (Iteration 291 / 980) loss: 35.927261
# (Epoch 6 / 20) train acc: 0.369000; val_acc: 0.358000
# (Iteration 301 / 980) loss: 34.753902
# (Iteration 311 / 980) loss: 33.586748
# (Iteration 321 / 980) loss: 32.576425
# (Iteration 331 / 980) loss: 31.483398
# (Iteration 341 / 980) loss: 30.455654
# (Epoch 7 / 20) train acc: 0.388000; val_acc: 0.365000
# (Iteration 351 / 980) loss: 29.552044
# (Iteration 361 / 980) loss: 28.538209
# (Iteration 371 / 980) loss: 27.569284
# (Iteration 381 / 980) loss: 26.777615
# (Iteration 391 / 980) loss: 25.871998
# (Epoch 8 / 20) train acc: 0.402000; val_acc: 0.384000
# (Iteration 401 / 980) loss: 25.088586
# (Iteration 411 / 980) loss: 24.248045
# (Iteration 421 / 980) loss: 23.486737
# (Iteration 431 / 980) loss: 22.781880
# (Iteration 441 / 980) loss: 22.079623
# (Epoch 9 / 20) train acc: 0.401000; val_acc: 0.397000
# (Iteration 451 / 980) loss: 21.354219
# (Iteration 461 / 980) loss: 20.719348
# (Iteration 471 / 980) loss: 20.079170
# (Iteration 481 / 980) loss: 19.450561
# (Epoch 10 / 20) train acc: 0.410000; val_acc: 0.403000
# (Iteration 491 / 980) loss: 18.857094
# (Iteration 501 / 980) loss: 18.340505
# (Iteration 511 / 980) loss: 17.761016
# (Iteration 521 / 980) loss: 17.204878
# (Iteration 531 / 980) loss: 16.643311
# (Epoch 11 / 20) train acc: 0.429000; val_acc: 0.413000
# (Iteration 541 / 980) loss: 16.172751
# (Iteration 551 / 980) loss: 15.682402
# (Iteration 561 / 980) loss: 15.272050
# (Iteration 571 / 980) loss: 14.768261
# (Iteration 581 / 980) loss: 14.374092
# (Epoch 12 / 20) train acc: 0.387000; val_acc: 0.423000
# (Iteration 591 / 980) loss: 13.906074
# (Iteration 601 / 980) loss: 13.478385
# (Iteration 611 / 980) loss: 13.148247
# (Iteration 621 / 980) loss: 12.780513
# (Iteration 631 / 980) loss: 12.426070
# (Epoch 13 / 20) train acc: 0.436000; val_acc: 0.420000
# (Iteration 641 / 980) loss: 12.058497
# (Iteration 651 / 980) loss: 11.702117
# (Iteration 661 / 980) loss: 11.381062
# (Iteration 671 / 980) loss: 11.042155
# (Iteration 681 / 980) loss: 10.744761
# (Epoch 14 / 20) train acc: 0.418000; val_acc: 0.422000
# (Iteration 691 / 980) loss: 10.429742
# (Iteration 701 / 980) loss: 10.183674
# (Iteration 711 / 980) loss: 9.882298
# (Iteration 721 / 980) loss: 9.582189
# (Iteration 731 / 980) loss: 9.376296
# (Epoch 15 / 20) train acc: 0.461000; val_acc: 0.425000
# (Iteration 741 / 980) loss: 9.126612
# (Iteration 751 / 980) loss: 8.926428
# (Iteration 761 / 980) loss: 8.706909
# (Iteration 771 / 980) loss: 8.458253
# (Iteration 781 / 980) loss: 8.243361
# (Epoch 16 / 20) train acc: 0.405000; val_acc: 0.441000
# (Iteration 791 / 980) loss: 8.045595
# (Iteration 801 / 980) loss: 7.792035
# (Iteration 811 / 980) loss: 7.671855
# (Iteration 821 / 980) loss: 7.445658
# (Iteration 831 / 980) loss: 7.256920
# (Epoch 17 / 20) train acc: 0.428000; val_acc: 0.430000
# (Iteration 841 / 980) loss: 7.086777
# (Iteration 851 / 980) loss: 6.923723
# (Iteration 861 / 980) loss: 6.786920
# (Iteration 871 / 980) loss: 6.564107
# (Iteration 881 / 980) loss: 6.427661
# (Epoch 18 / 20) train acc: 0.444000; val_acc: 0.450000
# (Iteration 891 / 980) loss: 6.321948
# (Iteration 901 / 980) loss: 6.176644
# (Iteration 911 / 980) loss: 6.030540
# (Iteration 921 / 980) loss: 5.962753
# (Iteration 931 / 980) loss: 5.774025
# (Epoch 19 / 20) train acc: 0.440000; val_acc: 0.461000
# (Iteration 941 / 980) loss: 5.651550
# (Iteration 951 / 980) loss: 5.515703
# (Iteration 961 / 980) loss: 5.471664
# (Iteration 971 / 980) loss: 5.245439
# (Epoch 20 / 20) train acc: 0.494000; val_acc: 0.444000
# 0.461
# round 2 / 100
# (Iteration 1 / 980) loss: 15.337255
# (Epoch 0 / 20) train acc: 0.112000; val_acc: 0.108000
# (Iteration 11 / 980) loss: 8.097152
# (Iteration 21 / 980) loss: 7.082159
# (Iteration 31 / 980) loss: 6.163078
# (Iteration 41 / 980) loss: 5.336140
# (Epoch 1 / 20) train acc: 0.374000; val_acc: 0.378000
# (Iteration 51 / 980) loss: 4.623584
# (Iteration 61 / 980) loss: 4.006207
# (Iteration 71 / 980) loss: 3.587241
# (Iteration 81 / 980) loss: 3.139675
# (Iteration 91 / 980) loss: 2.870702
# (Epoch 2 / 20) train acc: 0.452000; val_acc: 0.431000
# (Iteration 101 / 980) loss: 2.672979
# (Iteration 111 / 980) loss: 2.488009
# (Iteration 121 / 980) loss: 2.383151
# (Iteration 131 / 980) loss: 2.361980
# (Iteration 141 / 980) loss: 2.180103
# (Epoch 3 / 20) train acc: 0.478000; val_acc: 0.423000
# (Iteration 151 / 980) loss: 2.128149
# (Iteration 161 / 980) loss: 2.013688
# (Iteration 171 / 980) loss: 2.020304
# (Iteration 181 / 980) loss: 1.939388
# (Iteration 191 / 980) loss: 1.969336
# (Epoch 4 / 20) train acc: 0.469000; val_acc: 0.451000
# (Iteration 201 / 980) loss: 1.863759
# (Iteration 211 / 980) loss: 1.947995
# (Iteration 221 / 980) loss: 1.876464
# (Iteration 231 / 980) loss: 1.908981
# (Iteration 241 / 980) loss: 1.878483
# (Epoch 5 / 20) train acc: 0.459000; val_acc: 0.441000
# (Iteration 251 / 980) loss: 1.908462
# (Iteration 261 / 980) loss: 1.809847
# (Iteration 271 / 980) loss: 1.804735
# (Iteration 281 / 980) loss: 1.822203
# (Iteration 291 / 980) loss: 1.799552
# (Epoch 6 / 20) train acc: 0.506000; val_acc: 0.465000
# (Iteration 301 / 980) loss: 1.862847
# (Iteration 311 / 980) loss: 1.786624
# (Iteration 321 / 980) loss: 1.791818
# (Iteration 331 / 980) loss: 1.729724
# (Iteration 341 / 980) loss: 1.801443
# (Epoch 7 / 20) train acc: 0.473000; val_acc: 0.476000
# (Iteration 351 / 980) loss: 1.772112
# (Iteration 361 / 980) loss: 1.820735
# (Iteration 371 / 980) loss: 1.728374
# (Iteration 381 / 980) loss: 1.749786
# (Iteration 391 / 980) loss: 1.750533
# (Epoch 8 / 20) train acc: 0.503000; val_acc: 0.463000
# (Iteration 401 / 980) loss: 1.759703
# (Iteration 411 / 980) loss: 1.703739
# (Iteration 421 / 980) loss: 1.770984
# (Iteration 431 / 980) loss: 1.772457
# (Iteration 441 / 980) loss: 1.727648
# (Epoch 9 / 20) train acc: 0.481000; val_acc: 0.481000
# (Iteration 451 / 980) loss: 1.774074
# (Iteration 461 / 980) loss: 1.726098
# (Iteration 471 / 980) loss: 1.756493
# (Iteration 481 / 980) loss: 1.739408
# (Epoch 10 / 20) train acc: 0.520000; val_acc: 0.465000
# (Iteration 491 / 980) loss: 1.693705
# (Iteration 501 / 980) loss: 1.721040
# (Iteration 511 / 980) loss: 1.810743
# (Iteration 521 / 980) loss: 1.681496
# (Iteration 531 / 980) loss: 1.712297
# (Epoch 11 / 20) train acc: 0.511000; val_acc: 0.481000
# (Iteration 541 / 980) loss: 1.693578
# (Iteration 551 / 980) loss: 1.648590
# (Iteration 561 / 980) loss: 1.667394
# (Iteration 571 / 980) loss: 1.672579
# (Iteration 581 / 980) loss: 1.709902
# (Epoch 12 / 20) train acc: 0.505000; val_acc: 0.498000
# (Iteration 591 / 980) loss: 1.705783
# (Iteration 601 / 980) loss: 1.686738
# (Iteration 611 / 980) loss: 1.713058
# (Iteration 621 / 980) loss: 1.682243
# (Iteration 631 / 980) loss: 1.647704
# (Epoch 13 / 20) train acc: 0.490000; val_acc: 0.473000
# (Iteration 641 / 980) loss: 1.682675
# (Iteration 651 / 980) loss: 1.672658
# (Iteration 661 / 980) loss: 1.688964
# (Iteration 671 / 980) loss: 1.735213
# (Iteration 681 / 980) loss: 1.678600
# (Epoch 14 / 20) train acc: 0.511000; val_acc: 0.467000
# (Iteration 691 / 980) loss: 1.629773
# (Iteration 701 / 980) loss: 1.607014
# (Iteration 711 / 980) loss: 1.628952
# (Iteration 721 / 980) loss: 1.584584
# (Iteration 731 / 980) loss: 1.626760
# (Epoch 15 / 20) train acc: 0.510000; val_acc: 0.481000
# (Iteration 741 / 980) loss: 1.663056
# (Iteration 751 / 980) loss: 1.664195
# (Iteration 761 / 980) loss: 1.578908
# (Iteration 771 / 980) loss: 1.583631
# (Iteration 781 / 980) loss: 1.671220
# (Epoch 16 / 20) train acc: 0.516000; val_acc: 0.468000
# (Iteration 791 / 980) loss: 1.679061
# (Iteration 801 / 980) loss: 1.640790
# (Iteration 811 / 980) loss: 1.638166
# (Iteration 821 / 980) loss: 1.598438
# (Iteration 831 / 980) loss: 1.518814
# (Epoch 17 / 20) train acc: 0.507000; val_acc: 0.505000
# (Iteration 841 / 980) loss: 1.583414
# (Iteration 851 / 980) loss: 1.571366
# (Iteration 861 / 980) loss: 1.604120
# (Iteration 871 / 980) loss: 1.593841
# (Iteration 881 / 980) loss: 1.623185
# (Epoch 18 / 20) train acc: 0.520000; val_acc: 0.499000
# (Iteration 891 / 980) loss: 1.580643
# (Iteration 901 / 980) loss: 1.596742
# (Iteration 911 / 980) loss: 1.580830
# (Iteration 921 / 980) loss: 1.620775
# (Iteration 931 / 980) loss: 1.606391
# (Epoch 19 / 20) train acc: 0.537000; val_acc: 0.468000
# (Iteration 941 / 980) loss: 1.600806
# (Iteration 951 / 980) loss: 1.602243
# (Iteration 961 / 980) loss: 1.571399
# (Iteration 971 / 980) loss: 1.662390
# (Epoch 20 / 20) train acc: 0.515000; val_acc: 0.483000
# 0.505
# round 3 / 100
# (Iteration 1 / 980) loss: 14.386371
# (Epoch 0 / 20) train acc: 0.118000; val_acc: 0.113000
# (Iteration 11 / 980) loss: 8.798654
# (Iteration 21 / 980) loss: 6.846764
# (Iteration 31 / 980) loss: 5.345941
# (Iteration 41 / 980) loss: 4.186033
# (Epoch 1 / 20) train acc: 0.385000; val_acc: 0.393000
# (Iteration 51 / 980) loss: 3.432235
# (Iteration 61 / 980) loss: 2.880316
# (Iteration 71 / 980) loss: 2.560829
# (Iteration 81 / 980) loss: 2.367996
# (Iteration 91 / 980) loss: 2.216020
# (Epoch 2 / 20) train acc: 0.457000; val_acc: 0.457000
# (Iteration 101 / 980) loss: 2.157058
# (Iteration 111 / 980) loss: 2.085061
# (Iteration 121 / 980) loss: 2.066249
# (Iteration 131 / 980) loss: 2.072715
# (Iteration 141 / 980) loss: 2.001715
# (Epoch 3 / 20) train acc: 0.432000; val_acc: 0.452000
# (Iteration 151 / 980) loss: 2.070498
# (Iteration 161 / 980) loss: 1.962973
# (Iteration 171 / 980) loss: 1.893480
# (Iteration 181 / 980) loss: 1.969666
# (Iteration 191 / 980) loss: 1.897628
# (Epoch 4 / 20) train acc: 0.445000; val_acc: 0.439000
# (Iteration 201 / 980) loss: 1.859064
# (Iteration 211 / 980) loss: 1.860047
# (Iteration 221 / 980) loss: 1.903168
# (Iteration 231 / 980) loss: 1.896168
# (Iteration 241 / 980) loss: 1.829722
# (Epoch 5 / 20) train acc: 0.471000; val_acc: 0.440000
# (Iteration 251 / 980) loss: 1.889350
# (Iteration 261 / 980) loss: 1.821366
# (Iteration 271 / 980) loss: 1.852319
# (Iteration 281 / 980) loss: 1.836435
# (Iteration 291 / 980) loss: 1.844940
# (Epoch 6 / 20) train acc: 0.457000; val_acc: 0.454000
# (Iteration 301 / 980) loss: 1.864865
# (Iteration 311 / 980) loss: 1.847469
# (Iteration 321 / 980) loss: 1.818607
# (Iteration 331 / 980) loss: 1.789916
# (Iteration 341 / 980) loss: 1.775496
# (Epoch 7 / 20) train acc: 0.466000; val_acc: 0.456000
# (Iteration 351 / 980) loss: 1.796692
# (Iteration 361 / 980) loss: 1.769742
# (Iteration 371 / 980) loss: 1.788782
# (Iteration 381 / 980) loss: 1.717791
# (Iteration 391 / 980) loss: 1.766540
# (Epoch 8 / 20) train acc: 0.481000; val_acc: 0.465000
# (Iteration 401 / 980) loss: 1.735078
# (Iteration 411 / 980) loss: 1.759989
# (Iteration 421 / 980) loss: 1.729794
# (Iteration 431 / 980) loss: 1.762324
# (Iteration 441 / 980) loss: 1.791045
# (Epoch 9 / 20) train acc: 0.461000; val_acc: 0.481000
# (Iteration 451 / 980) loss: 1.782603
# (Iteration 461 / 980) loss: 1.666662
# (Iteration 471 / 980) loss: 1.720851
# (Iteration 481 / 980) loss: 1.727933
# (Epoch 10 / 20) train acc: 0.485000; val_acc: 0.464000
# (Iteration 491 / 980) loss: 1.708438
# (Iteration 501 / 980) loss: 1.707932
# (Iteration 511 / 980) loss: 1.787774
# (Iteration 521 / 980) loss: 1.709737
# (Iteration 531 / 980) loss: 1.729446
# (Epoch 11 / 20) train acc: 0.468000; val_acc: 0.466000
# (Iteration 541 / 980) loss: 1.738747
# (Iteration 551 / 980) loss: 1.759441
# (Iteration 561 / 980) loss: 1.722105
# (Iteration 571 / 980) loss: 1.726504
# (Iteration 581 / 980) loss: 1.723667
# (Epoch 12 / 20) train acc: 0.506000; val_acc: 0.470000
# (Iteration 591 / 980) loss: 1.739665
# (Iteration 601 / 980) loss: 1.705255
# (Iteration 611 / 980) loss: 1.709445
# (Iteration 621 / 980) loss: 1.814658
# (Iteration 631 / 980) loss: 1.670290
# (Epoch 13 / 20) train acc: 0.471000; val_acc: 0.469000
# (Iteration 641 / 980) loss: 1.729164
# (Iteration 651 / 980) loss: 1.660524
# (Iteration 661 / 980) loss: 1.722145
# (Iteration 671 / 980) loss: 1.667652
# (Iteration 681 / 980) loss: 1.692940
# (Epoch 14 / 20) train acc: 0.524000; val_acc: 0.473000
# (Iteration 691 / 980) loss: 1.654852
# (Iteration 701 / 980) loss: 1.673997
# (Iteration 711 / 980) loss: 1.691312
# (Iteration 721 / 980) loss: 1.684270
# (Iteration 731 / 980) loss: 1.696646
# (Epoch 15 / 20) train acc: 0.483000; val_acc: 0.457000
# (Iteration 741 / 980) loss: 1.660976
# (Iteration 751 / 980) loss: 1.715765
# (Iteration 761 / 980) loss: 1.700415
# (Iteration 771 / 980) loss: 1.669554
# (Iteration 781 / 980) loss: 1.674079
# (Epoch 16 / 20) train acc: 0.519000; val_acc: 0.495000
# (Iteration 791 / 980) loss: 1.732393
# (Iteration 801 / 980) loss: 1.660220
# (Iteration 811 / 980) loss: 1.732173
# (Iteration 821 / 980) loss: 1.633610
# (Iteration 831 / 980) loss: 1.640752
# (Epoch 17 / 20) train acc: 0.512000; val_acc: 0.462000
# (Iteration 841 / 980) loss: 1.648535
# (Iteration 851 / 980) loss: 1.629144
# (Iteration 861 / 980) loss: 1.642596
# (Iteration 871 / 980) loss: 1.680121
# (Iteration 881 / 980) loss: 1.674096
# (Epoch 18 / 20) train acc: 0.507000; val_acc: 0.481000
# (Iteration 891 / 980) loss: 1.697198
# (Iteration 901 / 980) loss: 1.624661
# (Iteration 911 / 980) loss: 1.704230
# (Iteration 921 / 980) loss: 1.775497
# (Iteration 931 / 980) loss: 1.662713
# (Epoch 19 / 20) train acc: 0.493000; val_acc: 0.463000
# (Iteration 941 / 980) loss: 1.686240
# (Iteration 951 / 980) loss: 1.716444
# (Iteration 961 / 980) loss: 1.678984
# (Iteration 971 / 980) loss: 1.593467
# (Epoch 20 / 20) train acc: 0.493000; val_acc: 0.478000
# 0.495
# round 4 / 100
# (Iteration 1 / 980) loss: 16.069025
# (Epoch 0 / 20) train acc: 0.003000; val_acc: 0.001000
# (Iteration 11 / 980) loss: 12.547205
# (Iteration 21 / 980) loss: 11.353065
# (Iteration 31 / 980) loss: 10.607834
# (Iteration 41 / 980) loss: 10.109116
# (Epoch 1 / 20) train acc: 0.298000; val_acc: 0.317000
# (Iteration 51 / 980) loss: 9.798869
# (Iteration 61 / 980) loss: 9.619634
# (Iteration 71 / 980) loss: 9.386994
# (Iteration 81 / 980) loss: 9.271073
# (Iteration 91 / 980) loss: 9.088345
# (Epoch 2 / 20) train acc: 0.368000; val_acc: 0.367000
# (Iteration 101 / 980) loss: 8.893306
# (Iteration 111 / 980) loss: 8.691254
# (Iteration 121 / 980) loss: 8.539074
# (Iteration 131 / 980) loss: 8.444097
# (Iteration 141 / 980) loss: 8.252645
# (Epoch 3 / 20) train acc: 0.420000; val_acc: 0.381000
# (Iteration 151 / 980) loss: 8.148445
# (Iteration 161 / 980) loss: 7.999795
# (Iteration 171 / 980) loss: 7.820927
# (Iteration 181 / 980) loss: 7.697875
# (Iteration 191 / 980) loss: 7.557785
# (Epoch 4 / 20) train acc: 0.447000; val_acc: 0.410000
# (Iteration 201 / 980) loss: 7.440116
# (Iteration 211 / 980) loss: 7.212467
# (Iteration 221 / 980) loss: 7.109604
# (Iteration 231 / 980) loss: 7.044330
# (Iteration 241 / 980) loss: 6.921681
# (Epoch 5 / 20) train acc: 0.441000; val_acc: 0.431000
# (Iteration 251 / 980) loss: 6.767515
# (Iteration 261 / 980) loss: 6.680116
# (Iteration 271 / 980) loss: 6.521230
# (Iteration 281 / 980) loss: 6.388852
# (Iteration 291 / 980) loss: 6.294043
# (Epoch 6 / 20) train acc: 0.458000; val_acc: 0.441000
# (Iteration 301 / 980) loss: 6.113318
# (Iteration 311 / 980) loss: 6.035935
# (Iteration 321 / 980) loss: 5.897650
# (Iteration 331 / 980) loss: 5.838413
# (Iteration 341 / 980) loss: 5.755507
# (Epoch 7 / 20) train acc: 0.465000; val_acc: 0.445000
# (Iteration 351 / 980) loss: 5.638642
# (Iteration 361 / 980) loss: 5.587156
# (Iteration 371 / 980) loss: 5.439840
# (Iteration 381 / 980) loss: 5.324233
# (Iteration 391 / 980) loss: 5.242392
# (Epoch 8 / 20) train acc: 0.467000; val_acc: 0.461000
# (Iteration 401 / 980) loss: 5.098962
# (Iteration 411 / 980) loss: 5.074977
# (Iteration 421 / 980) loss: 4.975804
# (Iteration 431 / 980) loss: 4.910847
# (Iteration 441 / 980) loss: 4.882547
# (Epoch 9 / 20) train acc: 0.471000; val_acc: 0.460000
# (Iteration 451 / 980) loss: 4.742392
# (Iteration 461 / 980) loss: 4.681284
# (Iteration 471 / 980) loss: 4.551218
# (Iteration 481 / 980) loss: 4.533944
# (Epoch 10 / 20) train acc: 0.518000; val_acc: 0.471000
# (Iteration 491 / 980) loss: 4.409652
# (Iteration 501 / 980) loss: 4.415666
# (Iteration 511 / 980) loss: 4.312190
# (Iteration 521 / 980) loss: 4.198021
# (Iteration 531 / 980) loss: 4.166498
# (Epoch 11 / 20) train acc: 0.493000; val_acc: 0.482000
# (Iteration 541 / 980) loss: 4.072676
# (Iteration 551 / 980) loss: 4.000649
# (Iteration 561 / 980) loss: 3.915817
# (Iteration 571 / 980) loss: 3.915678
# (Iteration 581 / 980) loss: 3.796805
# (Epoch 12 / 20) train acc: 0.528000; val_acc: 0.483000
# (Iteration 591 / 980) loss: 3.795790
# (Iteration 601 / 980) loss: 3.748953
# (Iteration 611 / 980) loss: 3.732087
# (Iteration 621 / 980) loss: 3.683298
# (Iteration 631 / 980) loss: 3.571060
# (Epoch 13 / 20) train acc: 0.523000; val_acc: 0.505000
# (Iteration 641 / 980) loss: 3.585355
# (Iteration 651 / 980) loss: 3.492709
# (Iteration 661 / 980) loss: 3.483972
# (Iteration 671 / 980) loss: 3.430138
# (Iteration 681 / 980) loss: 3.401346
# (Epoch 14 / 20) train acc: 0.514000; val_acc: 0.501000
# (Iteration 691 / 980) loss: 3.286122
# (Iteration 701 / 980) loss: 3.354669
# (Iteration 711 / 980) loss: 3.184417
# (Iteration 721 / 980) loss: 3.223826
# (Iteration 731 / 980) loss: 3.200790
# (Epoch 15 / 20) train acc: 0.550000; val_acc: 0.497000
# (Iteration 741 / 980) loss: 3.159548
# (Iteration 751 / 980) loss: 3.046212
# (Iteration 761 / 980) loss: 3.031272
# (Iteration 771 / 980) loss: 2.997388
# (Iteration 781 / 980) loss: 2.923948
# (Epoch 16 / 20) train acc: 0.568000; val_acc: 0.507000
# (Iteration 791 / 980) loss: 2.948832
# (Iteration 801 / 980) loss: 2.899999
# (Iteration 811 / 980) loss: 2.917967
# (Iteration 821 / 980) loss: 2.861158
# (Iteration 831 / 980) loss: 2.775165
# (Epoch 17 / 20) train acc: 0.560000; val_acc: 0.494000
# (Iteration 841 / 980) loss: 2.792636
# (Iteration 851 / 980) loss: 2.725420
# (Iteration 861 / 980) loss: 2.749022
# (Iteration 871 / 980) loss: 2.749481
# (Iteration 881 / 980) loss: 2.695275
# (Epoch 18 / 20) train acc: 0.567000; val_acc: 0.508000
# (Iteration 891 / 980) loss: 2.662590
# (Iteration 901 / 980) loss: 2.634198
# (Iteration 911 / 980) loss: 2.578822
# (Iteration 921 / 980) loss: 2.540606
# (Iteration 931 / 980) loss: 2.559596
# (Epoch 19 / 20) train acc: 0.611000; val_acc: 0.510000
# (Iteration 941 / 980) loss: 2.527801
# (Iteration 951 / 980) loss: 2.465972
# (Iteration 961 / 980) loss: 2.479593
# (Iteration 971 / 980) loss: 2.448670
# (Epoch 20 / 20) train acc: 0.599000; val_acc: 0.501000
# 0.51
# round 5 / 100
# (Iteration 1 / 980) loss: 65.677185
# (Epoch 0 / 20) train acc: 0.077000; val_acc: 0.049000
# (Iteration 11 / 980) loss: 27.332865
# (Iteration 21 / 980) loss: 10.995037
# (Iteration 31 / 980) loss: 5.900917
# (Iteration 41 / 980) loss: 4.280926
# (Epoch 1 / 20) train acc: 0.374000; val_acc: 0.386000
# (Iteration 51 / 980) loss: 3.549300
# (Iteration 61 / 980) loss: 3.144262
# (Iteration 71 / 980) loss: 2.893740
# (Iteration 81 / 980) loss: 2.682648
# (Iteration 91 / 980) loss: 2.560478
# (Epoch 2 / 20) train acc: 0.378000; val_acc: 0.384000
# (Iteration 101 / 980) loss: 2.543631
# (Iteration 111 / 980) loss: 2.430824
# (Iteration 121 / 980) loss: 2.391932
# (Iteration 131 / 980) loss: 2.330732
# (Iteration 141 / 980) loss: 2.324786
# (Epoch 3 / 20) train acc: 0.352000; val_acc: 0.357000
# (Iteration 151 / 980) loss: 2.273401
# (Iteration 161 / 980) loss: 2.223981
# (Iteration 171 / 980) loss: 2.204390
# (Iteration 181 / 980) loss: 2.240092
# (Iteration 191 / 980) loss: 2.236134
# (Epoch 4 / 20) train acc: 0.373000; val_acc: 0.364000
# (Iteration 201 / 980) loss: 2.179355
# (Iteration 211 / 980) loss: 2.187339
# (Iteration 221 / 980) loss: 2.187713
# (Iteration 231 / 980) loss: 2.107633
# (Iteration 241 / 980) loss: 2.233051
# (Epoch 5 / 20) train acc: 0.347000; val_acc: 0.375000
# (Iteration 251 / 980) loss: 2.088993
# (Iteration 261 / 980) loss: 2.123643
# (Iteration 271 / 980) loss: 2.127545
# (Iteration 281 / 980) loss: 2.133999
# (Iteration 291 / 980) loss: 2.122673
# (Epoch 6 / 20) train acc: 0.366000; val_acc: 0.388000
# (Iteration 301 / 980) loss: 2.117405
# (Iteration 311 / 980) loss: 2.131404
# (Iteration 321 / 980) loss: 2.174047
# (Iteration 331 / 980) loss: 2.185333
# (Iteration 341 / 980) loss: 2.101511
# (Epoch 7 / 20) train acc: 0.360000; val_acc: 0.370000
# (Iteration 351 / 980) loss: 2.118719
# (Iteration 361 / 980) loss: 2.122458
# (Iteration 371 / 980) loss: 2.124154
# (Iteration 381 / 980) loss: 2.115383
# (Iteration 391 / 980) loss: 2.093901
# (Epoch 8 / 20) train acc: 0.355000; val_acc: 0.382000
# (Iteration 401 / 980) loss: 2.081021
# (Iteration 411 / 980) loss: 2.111550
# (Iteration 421 / 980) loss: 2.158976
# (Iteration 431 / 980) loss: 2.056350
# (Iteration 441 / 980) loss: 2.064875
# (Epoch 9 / 20) train acc: 0.385000; val_acc: 0.396000
# (Iteration 451 / 980) loss: 2.105474
# (Iteration 461 / 980) loss: 2.105991
# (Iteration 471 / 980) loss: 2.100993
# (Iteration 481 / 980) loss: 2.090403
# (Epoch 10 / 20) train acc: 0.380000; val_acc: 0.361000
# (Iteration 491 / 980) loss: 2.083296
# (Iteration 501 / 980) loss: 2.094309
# (Iteration 511 / 980) loss: 2.091923
# (Iteration 521 / 980) loss: 2.126382
# (Iteration 531 / 980) loss: 2.049707
# (Epoch 11 / 20) train acc: 0.393000; val_acc: 0.390000
# (Iteration 541 / 980) loss: 2.110311
# (Iteration 551 / 980) loss: 2.073512
# (Iteration 561 / 980) loss: 2.089391
# (Iteration 571 / 980) loss: 2.146865
# (Iteration 581 / 980) loss: 2.105980
# (Epoch 12 / 20) train acc: 0.372000; val_acc: 0.389000
# (Iteration 591 / 980) loss: 2.129496
# (Iteration 601 / 980) loss: 2.163557
# (Iteration 611 / 980) loss: 2.129149
# (Iteration 621 / 980) loss: 2.023224
# (Iteration 631 / 980) loss: 2.069734
# (Epoch 13 / 20) train acc: 0.375000; val_acc: 0.384000
# (Iteration 641 / 980) loss: 2.028169
# (Iteration 651 / 980) loss: 2.010752
# (Iteration 661 / 980) loss: 2.156979
# (Iteration 671 / 980) loss: 2.105162
# (Iteration 681 / 980) loss: 2.032536
# (Epoch 14 / 20) train acc: 0.361000; val_acc: 0.384000
# (Iteration 691 / 980) loss: 2.078749
# (Iteration 701 / 980) loss: 2.076137
# (Iteration 711 / 980) loss: 2.045884
# (Iteration 721 / 980) loss: 2.110631
# (Iteration 731 / 980) loss: 2.037623
# (Epoch 15 / 20) train acc: 0.366000; val_acc: 0.369000
# (Iteration 741 / 980) loss: 2.071797
# (Iteration 751 / 980) loss: 2.052067
# (Iteration 761 / 980) loss: 2.087527
# (Iteration 771 / 980) loss: 2.030776
# (Iteration 781 / 980) loss: 2.097341
# (Epoch 16 / 20) train acc: 0.394000; val_acc: 0.383000
# (Iteration 791 / 980) loss: 2.069133
# (Iteration 801 / 980) loss: 2.109114
# (Iteration 811 / 980) loss: 2.093698
# (Iteration 821 / 980) loss: 2.048077
# (Iteration 831 / 980) loss: 2.097400
# (Epoch 17 / 20) train acc: 0.366000; val_acc: 0.363000
# (Iteration 841 / 980) loss: 2.065277
# (Iteration 851 / 980) loss: 2.057712
# (Iteration 861 / 980) loss: 2.061020
# (Iteration 871 / 980) loss: 2.066028
# (Iteration 881 / 980) loss: 2.087814
# (Epoch 18 / 20) train acc: 0.345000; val_acc: 0.375000
# (Iteration 891 / 980) loss: 2.072752
# (Iteration 901 / 980) loss: 2.067245
# (Iteration 911 / 980) loss: 2.037851
# (Iteration 921 / 980) loss: 2.031388
# (Iteration 931 / 980) loss: 2.026582
# (Epoch 19 / 20) train acc: 0.341000; val_acc: 0.351000
# (Iteration 941 / 980) loss: 2.035450
# (Iteration 951 / 980) loss: 1.995497
# (Iteration 961 / 980) loss: 2.067688
# (Iteration 971 / 980) loss: 2.043232
# (Epoch 20 / 20) train acc: 0.377000; val_acc: 0.380000
# 0.396
# round 6 / 100
# (Iteration 1 / 980) loss: 265.657099
# (Epoch 0 / 20) train acc: 0.001000; val_acc: 0.001000
# (Iteration 11 / 980) loss: 196.160124
# (Iteration 21 / 980) loss: 145.197663
# (Iteration 31 / 980) loss: 107.372320
# (Iteration 41 / 980) loss: 79.584714
# (Epoch 1 / 20) train acc: 0.301000; val_acc: 0.323000
# (Iteration 51 / 980) loss: 59.353971
# (Iteration 61 / 980) loss: 44.612388
# (Iteration 71 / 980) loss: 33.830635
# (Iteration 81 / 980) loss: 25.923815
# (Iteration 91 / 980) loss: 19.995535
# (Epoch 2 / 20) train acc: 0.328000; val_acc: 0.329000
# (Iteration 101 / 980) loss: 15.689277
# (Iteration 111 / 980) loss: 12.475738
# (Iteration 121 / 980) loss: 10.082221
# (Iteration 131 / 980) loss: 8.330803
# (Iteration 141 / 980) loss: 6.952265
# (Epoch 3 / 20) train acc: 0.316000; val_acc: 0.317000
# (Iteration 151 / 980) loss: 5.941236
# (Iteration 161 / 980) loss: 5.162473
# (Iteration 171 / 980) loss: 4.661773
# (Iteration 181 / 980) loss: 4.169893
# (Iteration 191 / 980) loss: 3.886568
# (Epoch 4 / 20) train acc: 0.288000; val_acc: 0.273000
# (Iteration 201 / 980) loss: 3.579340
# (Iteration 211 / 980) loss: 3.362713
# (Iteration 221 / 980) loss: 3.218091
# (Iteration 231 / 980) loss: 3.109970
# (Iteration 241 / 980) loss: 3.005811
# (Epoch 5 / 20) train acc: 0.264000; val_acc: 0.245000
# (Iteration 251 / 980) loss: 2.983629
# (Iteration 261 / 980) loss: 2.892301
# (Iteration 271 / 980) loss: 2.859564
# (Iteration 281 / 980) loss: 2.842629
# (Iteration 291 / 980) loss: 2.825017
# (Epoch 6 / 20) train acc: 0.243000; val_acc: 0.249000
# (Iteration 301 / 980) loss: 2.793207
# (Iteration 311 / 980) loss: 2.725763
# (Iteration 321 / 980) loss: 2.722433
# (Iteration 331 / 980) loss: 2.753630
# (Iteration 341 / 980) loss: 2.740200
# (Epoch 7 / 20) train acc: 0.257000; val_acc: 0.253000
# (Iteration 351 / 980) loss: 2.758075
# (Iteration 361 / 980) loss: 2.744548
# (Iteration 371 / 980) loss: 2.719644
# (Iteration 381 / 980) loss: 2.674585
# (Iteration 391 / 980) loss: 2.709425
# (Epoch 8 / 20) train acc: 0.248000; val_acc: 0.252000
# (Iteration 401 / 980) loss: 2.702818
# (Iteration 411 / 980) loss: 2.680615
# (Iteration 421 / 980) loss: 2.693995
# (Iteration 431 / 980) loss: 2.666026
# (Iteration 441 / 980) loss: 2.710930
# (Epoch 9 / 20) train acc: 0.247000; val_acc: 0.249000
# (Iteration 451 / 980) loss: 2.684742
# (Iteration 461 / 980) loss: 2.713818
# (Iteration 471 / 980) loss: 2.670208
# (Iteration 481 / 980) loss: 2.694670
# (Epoch 10 / 20) train acc: 0.263000; val_acc: 0.247000
# (Iteration 491 / 980) loss: 2.665154
# (Iteration 501 / 980) loss: 2.625894
# (Iteration 511 / 980) loss: 2.654571
# (Iteration 521 / 980) loss: 2.688296
# (Iteration 531 / 980) loss: 2.664924
# (Epoch 11 / 20) train acc: 0.226000; val_acc: 0.250000
# (Iteration 541 / 980) loss: 2.665663
# (Iteration 551 / 980) loss: 2.679895
# (Iteration 561 / 980) loss: 2.693323
# (Iteration 571 / 980) loss: 2.662318
# (Iteration 581 / 980) loss: 2.681647
# (Epoch 12 / 20) train acc: 0.277000; val_acc: 0.270000
# (Iteration 591 / 980) loss: 2.702239
# (Iteration 601 / 980) loss: 2.660793
# (Iteration 611 / 980) loss: 2.660951
# (Iteration 621 / 980) loss: 2.646090
# (Iteration 631 / 980) loss: 2.710860
# (Epoch 13 / 20) train acc: 0.273000; val_acc: 0.258000
# (Iteration 641 / 980) loss: 2.663358
# (Iteration 651 / 980) loss: 2.645399
# (Iteration 661 / 980) loss: 2.660257
# (Iteration 671 / 980) loss: 2.645114
# (Iteration 681 / 980) loss: 2.687470
# (Epoch 14 / 20) train acc: 0.229000; val_acc: 0.254000
# (Iteration 691 / 980) loss: 2.668563
# (Iteration 701 / 980) loss: 2.661450
# (Iteration 711 / 980) loss: 2.662908
# (Iteration 721 / 980) loss: 2.639629
# (Iteration 731 / 980) loss: 2.651503
# (Epoch 15 / 20) train acc: 0.261000; val_acc: 0.256000
# (Iteration 741 / 980) loss: 2.681198
# (Iteration 751 / 980) loss: 2.620216
# (Iteration 761 / 980) loss: 2.642499
# (Iteration 771 / 980) loss: 2.652000
# (Iteration 781 / 980) loss: 2.592241
# (Epoch 16 / 20) train acc: 0.239000; val_acc: 0.233000
# (Iteration 791 / 980) loss: 2.641563
# (Iteration 801 / 980) loss: 2.648080
# (Iteration 811 / 980) loss: 2.642931
# (Iteration 821 / 980) loss: 2.650397
# (Iteration 831 / 980) loss: 2.646316
# (Epoch 17 / 20) train acc: 0.276000; val_acc: 0.260000
# (Iteration 841 / 980) loss: 2.622575
# (Iteration 851 / 980) loss: 2.680536
# (Iteration 861 / 980) loss: 2.634850
# (Iteration 871 / 980) loss: 2.648123
# (Iteration 881 / 980) loss: 2.644745
# (Epoch 18 / 20) train acc: 0.265000; val_acc: 0.256000
# (Iteration 891 / 980) loss: 2.652337
# (Iteration 901 / 980) loss: 2.594751
# (Iteration 911 / 980) loss: 2.635734
# (Iteration 921 / 980) loss: 2.644959
# (Iteration 931 / 980) loss: 2.670421
# (Epoch 19 / 20) train acc: 0.255000; val_acc: 0.260000
# (Iteration 941 / 980) loss: 2.617596
# (Iteration 951 / 980) loss: 2.592517
# (Iteration 961 / 980) loss: 2.619175
# (Iteration 971 / 980) loss: 2.617623
# (Epoch 20 / 20) train acc: 0.237000; val_acc: 0.240000
# 0.329
# round 7 / 100
# (Iteration 1 / 980) loss: 48.232768
# (Epoch 0 / 20) train acc: 0.134000; val_acc: 0.121000
# (Iteration 11 / 980) loss: 17.906211
# (Iteration 21 / 980) loss: 7.424010
# (Iteration 31 / 980) loss: 5.000935
# (Iteration 41 / 980) loss: 4.114444
# (Epoch 1 / 20) train acc: 0.324000; val_acc: 0.338000
# (Iteration 51 / 980) loss: 3.531175
# (Iteration 61 / 980) loss: 3.245673
# (Iteration 71 / 980) loss: 3.016213
# (Iteration 81 / 980) loss: 2.815121
# (Iteration 91 / 980) loss: 2.760428
# (Epoch 2 / 20) train acc: 0.352000; val_acc: 0.362000
# (Iteration 101 / 980) loss: 2.692791
# (Iteration 111 / 980) loss: 2.581122
# (Iteration 121 / 980) loss: 2.467015
# (Iteration 131 / 980) loss: 2.448463
# (Iteration 141 / 980) loss: 2.403900
# (Epoch 3 / 20) train acc: 0.344000; val_acc: 0.378000
# (Iteration 151 / 980) loss: 2.333594
# (Iteration 161 / 980) loss: 2.326849
# (Iteration 171 / 980) loss: 2.293973
# (Iteration 181 / 980) loss: 2.278789
# (Iteration 191 / 980) loss: 2.310541
# (Epoch 4 / 20) train acc: 0.368000; val_acc: 0.386000
# (Iteration 201 / 980) loss: 2.243529
# (Iteration 211 / 980) loss: 2.276382
# (Iteration 221 / 980) loss: 2.240850
# (Iteration 231 / 980) loss: 2.179792
# (Iteration 241 / 980) loss: 2.152099
# (Epoch 5 / 20) train acc: 0.343000; val_acc: 0.363000
# (Iteration 251 / 980) loss: 2.136067
# (Iteration 261 / 980) loss: 2.166295
# (Iteration 271 / 980) loss: 2.112748
# (Iteration 281 / 980) loss: 2.078451
# (Iteration 291 / 980) loss: 2.197336
# (Epoch 6 / 20) train acc: 0.395000; val_acc: 0.370000
# (Iteration 301 / 980) loss: 2.161701
# (Iteration 311 / 980) loss: 2.156610
# (Iteration 321 / 980) loss: 2.091971
# (Iteration 331 / 980) loss: 2.044100
# (Iteration 341 / 980) loss: 2.106204
# (Epoch 7 / 20) train acc: 0.320000; val_acc: 0.321000
# (Iteration 351 / 980) loss: 2.100594
# (Iteration 361 / 980) loss: 2.122464
# (Iteration 371 / 980) loss: 2.080321
# (Iteration 381 / 980) loss: 2.019095
# (Iteration 391 / 980) loss: 2.133842
# (Epoch 8 / 20) train acc: 0.316000; val_acc: 0.371000
# (Iteration 401 / 980) loss: 2.128680
# (Iteration 411 / 980) loss: 2.023756
# (Iteration 421 / 980) loss: 2.117941
# (Iteration 431 / 980) loss: 2.064875
# (Iteration 441 / 980) loss: 2.141416
# (Epoch 9 / 20) train acc: 0.361000; val_acc: 0.351000
# (Iteration 451 / 980) loss: 2.080578
# (Iteration 461 / 980) loss: 2.106780
# (Iteration 471 / 980) loss: 2.022801
# (Iteration 481 / 980) loss: 2.035756
# (Epoch 10 / 20) train acc: 0.361000; val_acc: 0.354000
# (Iteration 491 / 980) loss: 2.101120
# (Iteration 501 / 980) loss: 2.088779
# (Iteration 511 / 980) loss: 2.106779
# (Iteration 521 / 980) loss: 2.090397
# (Iteration 531 / 980) loss: 2.005044
# (Epoch 11 / 20) train acc: 0.367000; val_acc: 0.365000
# (Iteration 541 / 980) loss: 2.020424
# (Iteration 551 / 980) loss: 2.079265
# (Iteration 561 / 980) loss: 2.049923
# (Iteration 571 / 980) loss: 2.106849
# (Iteration 581 / 980) loss: 2.040801
# (Epoch 12 / 20) train acc: 0.375000; val_acc: 0.359000
# (Iteration 591 / 980) loss: 2.008134
# (Iteration 601 / 980) loss: 2.011596
# (Iteration 611 / 980) loss: 2.024412
# (Iteration 621 / 980) loss: 1.941565
# (Iteration 631 / 980) loss: 2.029136
# (Epoch 13 / 20) train acc: 0.352000; val_acc: 0.364000
# (Iteration 641 / 980) loss: 2.058363
# (Iteration 651 / 980) loss: 2.018570
# (Iteration 661 / 980) loss: 1.981683
# (Iteration 671 / 980) loss: 2.085463
# (Iteration 681 / 980) loss: 2.090120
# (Epoch 14 / 20) train acc: 0.376000; val_acc: 0.341000
# (Iteration 691 / 980) loss: 2.037044
# (Iteration 701 / 980) loss: 2.095859
# (Iteration 711 / 980) loss: 2.064127
# (Iteration 721 / 980) loss: 2.188251
# (Iteration 731 / 980) loss: 2.029286
# (Epoch 15 / 20) train acc: 0.327000; val_acc: 0.330000
# (Iteration 741 / 980) loss: 2.016635
# (Iteration 751 / 980) loss: 2.100498
# (Iteration 761 / 980) loss: 2.085889
# (Iteration 771 / 980) loss: 2.105003
# (Iteration 781 / 980) loss: 2.010736
# (Epoch 16 / 20) train acc: 0.388000; val_acc: 0.352000
# (Iteration 791 / 980) loss: 2.034166
# (Iteration 801 / 980) loss: 2.000603
# (Iteration 811 / 980) loss: 2.041263
# (Iteration 821 / 980) loss: 2.040287
# (Iteration 831 / 980) loss: 2.042461
# (Epoch 17 / 20) train acc: 0.364000; val_acc: 0.359000
# (Iteration 841 / 980) loss: 2.033542
# (Iteration 851 / 980) loss: 2.042983
# (Iteration 861 / 980) loss: 2.046638
# (Iteration 871 / 980) loss: 1.996096
# (Iteration 881 / 980) loss: 2.084368
# (Epoch 18 / 20) train acc: 0.349000; val_acc: 0.338000
# (Iteration 891 / 980) loss: 2.026852
# (Iteration 901 / 980) loss: 1.992230
# (Iteration 911 / 980) loss: 2.016768
# (Iteration 921 / 980) loss: 2.048114
# (Iteration 931 / 980) loss: 2.013219
# (Epoch 19 / 20) train acc: 0.354000; val_acc: 0.357000
# (Iteration 941 / 980) loss: 2.066363
# (Iteration 951 / 980) loss: 2.016841
# (Iteration 961 / 980) loss: 2.005654
# (Iteration 971 / 980) loss: 2.107511
# (Epoch 20 / 20) train acc: 0.363000; val_acc: 0.361000
# 0.386
# round 8 / 100
# (Iteration 1 / 980) loss: 29.420397
# (Epoch 0 / 20) train acc: 0.117000; val_acc: 0.119000
# (Iteration 11 / 980) loss: 16.183670
# (Iteration 21 / 980) loss: 9.100248
# (Iteration 31 / 980) loss: 5.488324
# (Iteration 41 / 980) loss: 3.931098
# (Epoch 1 / 20) train acc: 0.321000; val_acc: 0.355000
# (Iteration 51 / 980) loss: 3.248471
# (Iteration 61 / 980) loss: 2.993093
# (Iteration 71 / 980) loss: 2.832883
# (Iteration 81 / 980) loss: 2.763958
# (Iteration 91 / 980) loss: 2.615128
# (Epoch 2 / 20) train acc: 0.407000; val_acc: 0.382000
# (Iteration 101 / 980) loss: 2.498512
# (Iteration 111 / 980) loss: 2.453928
# (Iteration 121 / 980) loss: 2.362015
# (Iteration 131 / 980) loss: 2.301966
# (Iteration 141 / 980) loss: 2.343947
# (Epoch 3 / 20) train acc: 0.392000; val_acc: 0.398000
# (Iteration 151 / 980) loss: 2.260300
# (Iteration 161 / 980) loss: 2.302194
# (Iteration 171 / 980) loss: 2.223777
# (Iteration 181 / 980) loss: 2.150498
# (Iteration 191 / 980) loss: 2.181747
# (Epoch 4 / 20) train acc: 0.396000; val_acc: 0.401000
# (Iteration 201 / 980) loss: 2.212025
# (Iteration 211 / 980) loss: 2.154226
# (Iteration 221 / 980) loss: 2.083182
# (Iteration 231 / 980) loss: 2.169591
# (Iteration 241 / 980) loss: 2.087714
# (Epoch 5 / 20) train acc: 0.416000; val_acc: 0.417000
# (Iteration 251 / 980) loss: 2.044489
# (Iteration 261 / 980) loss: 2.077409
# (Iteration 271 / 980) loss: 2.054241
# (Iteration 281 / 980) loss: 2.016540
# (Iteration 291 / 980) loss: 2.044543
# (Epoch 6 / 20) train acc: 0.383000; val_acc: 0.401000
# (Iteration 301 / 980) loss: 2.048741
# (Iteration 311 / 980) loss: 2.022190
# (Iteration 321 / 980) loss: 2.038620
# (Iteration 331 / 980) loss: 1.955878
# (Iteration 341 / 980) loss: 2.030965
# (Epoch 7 / 20) train acc: 0.425000; val_acc: 0.427000
# (Iteration 351 / 980) loss: 2.056480
# (Iteration 361 / 980) loss: 2.002685
# (Iteration 371 / 980) loss: 2.002627
# (Iteration 381 / 980) loss: 2.002518
# (Iteration 391 / 980) loss: 1.959780
# (Epoch 8 / 20) train acc: 0.401000; val_acc: 0.428000
# (Iteration 401 / 980) loss: 1.981743
# (Iteration 411 / 980) loss: 2.010515
# (Iteration 421 / 980) loss: 1.996770
# (Iteration 431 / 980) loss: 1.920957
# (Iteration 441 / 980) loss: 1.926424
# (Epoch 9 / 20) train acc: 0.407000; val_acc: 0.420000
# (Iteration 451 / 980) loss: 1.920845
# (Iteration 461 / 980) loss: 1.917034
# (Iteration 471 / 980) loss: 1.956995
# (Iteration 481 / 980) loss: 1.919885
# (Epoch 10 / 20) train acc: 0.410000; val_acc: 0.401000
# (Iteration 491 / 980) loss: 1.924197
# (Iteration 501 / 980) loss: 1.907376
# (Iteration 511 / 980) loss: 1.924076
# (Iteration 521 / 980) loss: 1.921675
# (Iteration 531 / 980) loss: 1.940346
# (Epoch 11 / 20) train acc: 0.405000; val_acc: 0.398000
# (Iteration 541 / 980) loss: 2.032967
# (Iteration 551 / 980) loss: 1.950867
# (Iteration 561 / 980) loss: 1.910848
# (Iteration 571 / 980) loss: 1.896203
# (Iteration 581 / 980) loss: 1.939567
# (Epoch 12 / 20) train acc: 0.379000; val_acc: 0.407000
# (Iteration 591 / 980) loss: 1.910274
# (Iteration 601 / 980) loss: 1.981924
# (Iteration 611 / 980) loss: 1.895434
# (Iteration 621 / 980) loss: 1.917172
# (Iteration 631 / 980) loss: 1.903483
# (Epoch 13 / 20) train acc: 0.406000; val_acc: 0.404000
# (Iteration 641 / 980) loss: 1.959782
# (Iteration 651 / 980) loss: 1.974117
# (Iteration 661 / 980) loss: 1.866184
# (Iteration 671 / 980) loss: 1.871155
# (Iteration 681 / 980) loss: 1.841880
# (Epoch 14 / 20) train acc: 0.429000; val_acc: 0.383000
# (Iteration 691 / 980) loss: 2.005335
# (Iteration 701 / 980) loss: 1.896841
# (Iteration 711 / 980) loss: 1.937001
# (Iteration 721 / 980) loss: 1.908365
# (Iteration 731 / 980) loss: 1.891866
# (Epoch 15 / 20) train acc: 0.425000; val_acc: 0.415000
# (Iteration 741 / 980) loss: 1.870254
# (Iteration 751 / 980) loss: 1.896650
# (Iteration 761 / 980) loss: 1.951196
# (Iteration 771 / 980) loss: 1.890082
# (Iteration 781 / 980) loss: 1.872144
# (Epoch 16 / 20) train acc: 0.430000; val_acc: 0.400000
# (Iteration 791 / 980) loss: 1.907728
# (Iteration 801 / 980) loss: 1.911568
# (Iteration 811 / 980) loss: 1.958517
# (Iteration 821 / 980) loss: 1.852718
# (Iteration 831 / 980) loss: 1.925977
# (Epoch 17 / 20) train acc: 0.398000; val_acc: 0.407000
# (Iteration 841 / 980) loss: 1.866591
# (Iteration 851 / 980) loss: 1.876428
# (Iteration 861 / 980) loss: 1.864891
# (Iteration 871 / 980) loss: 1.942685
# (Iteration 881 / 980) loss: 1.833861
# (Epoch 18 / 20) train acc: 0.406000; val_acc: 0.395000
# (Iteration 891 / 980) loss: 1.863104
# (Iteration 901 / 980) loss: 1.868703
# (Iteration 911 / 980) loss: 1.894518
# (Iteration 921 / 980) loss: 1.951308
# (Iteration 931 / 980) loss: 1.831238
# (Epoch 19 / 20) train acc: 0.412000; val_acc: 0.415000
# (Iteration 941 / 980) loss: 1.918612
# (Iteration 951 / 980) loss: 1.892374
# (Iteration 961 / 980) loss: 1.851816
# (Iteration 971 / 980) loss: 1.849517
# (Epoch 20 / 20) train acc: 0.369000; val_acc: 0.403000
# 0.428
# round 9 / 100
# (Iteration 1 / 980) loss: 47.850569
# (Epoch 0 / 20) train acc: 0.002000; val_acc: 0.003000
# (Iteration 11 / 980) loss: 39.003796
# (Iteration 21 / 980) loss: 34.423285
# (Iteration 31 / 980) loss: 30.343375
# (Iteration 41 / 980) loss: 26.667984
# (Epoch 1 / 20) train acc: 0.377000; val_acc: 0.368000
# (Iteration 51 / 980) loss: 23.384356
# (Iteration 61 / 980) loss: 20.535823
# (Iteration 71 / 980) loss: 18.038485
# (Iteration 81 / 980) loss: 15.823881
# (Iteration 91 / 980) loss: 13.982787
# (Epoch 2 / 20) train acc: 0.406000; val_acc: 0.428000
# (Iteration 101 / 980) loss: 12.352481
# (Iteration 111 / 980) loss: 10.990312
# (Iteration 121 / 980) loss: 9.760180
# (Iteration 131 / 980) loss: 8.728929
# (Iteration 141 / 980) loss: 7.895672
# (Epoch 3 / 20) train acc: 0.441000; val_acc: 0.438000
# (Iteration 151 / 980) loss: 7.145477
# (Iteration 161 / 980) loss: 6.509368
# (Iteration 171 / 980) loss: 5.878962
# (Iteration 181 / 980) loss: 5.363069
# (Iteration 191 / 980) loss: 4.952193
# (Epoch 4 / 20) train acc: 0.474000; val_acc: 0.472000
# (Iteration 201 / 980) loss: 4.628452
# (Iteration 211 / 980) loss: 4.358577
# (Iteration 221 / 980) loss: 4.075399
# (Iteration 231 / 980) loss: 3.808360
# (Iteration 241 / 980) loss: 3.633596
# (Epoch 5 / 20) train acc: 0.473000; val_acc: 0.463000
# (Iteration 251 / 980) loss: 3.425935
# (Iteration 261 / 980) loss: 3.258717
# (Iteration 271 / 980) loss: 3.163586
# (Iteration 281 / 980) loss: 3.016713
# (Iteration 291 / 980) loss: 2.880550
# (Epoch 6 / 20) train acc: 0.480000; val_acc: 0.476000
# (Iteration 301 / 980) loss: 2.801056
# (Iteration 311 / 980) loss: 2.691383
# (Iteration 321 / 980) loss: 2.588713
# (Iteration 331 / 980) loss: 2.621081
# (Iteration 341 / 980) loss: 2.534905
# (Epoch 7 / 20) train acc: 0.514000; val_acc: 0.475000
# (Iteration 351 / 980) loss: 2.475359
# (Iteration 361 / 980) loss: 2.423760
# (Iteration 371 / 980) loss: 2.334559
# (Iteration 381 / 980) loss: 2.336584
# (Iteration 391 / 980) loss: 2.289994
# (Epoch 8 / 20) train acc: 0.481000; val_acc: 0.481000
# (Iteration 401 / 980) loss: 2.288045
# (Iteration 411 / 980) loss: 2.227503
# (Iteration 421 / 980) loss: 2.213083
# (Iteration 431 / 980) loss: 2.203846
# (Iteration 441 / 980) loss: 2.166937
# (Epoch 9 / 20) train acc: 0.529000; val_acc: 0.490000
# (Iteration 451 / 980) loss: 2.186383
# (Iteration 461 / 980) loss: 2.120890
# (Iteration 471 / 980) loss: 2.106753
# (Iteration 481 / 980) loss: 2.077821
# (Epoch 10 / 20) train acc: 0.464000; val_acc: 0.469000
# (Iteration 491 / 980) loss: 2.125042
# (Iteration 501 / 980) loss: 2.047358
# (Iteration 511 / 980) loss: 2.059528
# (Iteration 521 / 980) loss: 1.999976
# (Iteration 531 / 980) loss: 2.008850
# (Epoch 11 / 20) train acc: 0.498000; val_acc: 0.494000
# (Iteration 541 / 980) loss: 1.945638
# (Iteration 551 / 980) loss: 2.010117
# (Iteration 561 / 980) loss: 2.022101
# (Iteration 571 / 980) loss: 2.047851
# (Iteration 581 / 980) loss: 1.991885
# (Epoch 12 / 20) train acc: 0.501000; val_acc: 0.489000
# (Iteration 591 / 980) loss: 2.005626
# (Iteration 601 / 980) loss: 2.006158
# (Iteration 611 / 980) loss: 1.990712
# (Iteration 621 / 980) loss: 1.943702
# (Iteration 631 / 980) loss: 1.927776
# (Epoch 13 / 20) train acc: 0.507000; val_acc: 0.493000
# (Iteration 641 / 980) loss: 1.943355
# (Iteration 651 / 980) loss: 1.927033
# (Iteration 661 / 980) loss: 1.894237
# (Iteration 671 / 980) loss: 1.970358
# (Iteration 681 / 980) loss: 1.948581
# (Epoch 14 / 20) train acc: 0.504000; val_acc: 0.487000
# (Iteration 691 / 980) loss: 1.998699
# (Iteration 701 / 980) loss: 1.929302
# (Iteration 711 / 980) loss: 1.946038
# (Iteration 721 / 980) loss: 1.919963
# (Iteration 731 / 980) loss: 1.884692
# (Epoch 15 / 20) train acc: 0.536000; val_acc: 0.508000
# (Iteration 741 / 980) loss: 1.866631
# (Iteration 751 / 980) loss: 1.935153
# (Iteration 761 / 980) loss: 1.844773
# (Iteration 771 / 980) loss: 1.880760
# (Iteration 781 / 980) loss: 1.873147
# (Epoch 16 / 20) train acc: 0.526000; val_acc: 0.484000
# (Iteration 791 / 980) loss: 1.864246
# (Iteration 801 / 980) loss: 1.857947
# (Iteration 811 / 980) loss: 1.905763
# (Iteration 821 / 980) loss: 1.871242
# (Iteration 831 / 980) loss: 1.859729
# (Epoch 17 / 20) train acc: 0.475000; val_acc: 0.494000
# (Iteration 841 / 980) loss: 1.876098
# (Iteration 851 / 980) loss: 1.812106
# (Iteration 861 / 980) loss: 1.855979
# (Iteration 871 / 980) loss: 1.849517
# (Iteration 881 / 980) loss: 1.814991
# (Epoch 18 / 20) train acc: 0.466000; val_acc: 0.480000
# (Iteration 891 / 980) loss: 1.868002
# (Iteration 901 / 980) loss: 1.888301
# (Iteration 911 / 980) loss: 1.853172
# (Iteration 921 / 980) loss: 1.826177
# (Iteration 931 / 980) loss: 1.847288
# (Epoch 19 / 20) train acc: 0.503000; val_acc: 0.499000
# (Iteration 941 / 980) loss: 1.899144
# (Iteration 951 / 980) loss: 1.825108
# (Iteration 961 / 980) loss: 1.789357
# (Iteration 971 / 980) loss: 1.795840
# (Epoch 20 / 20) train acc: 0.493000; val_acc: 0.488000
# 0.508
# round 10 / 100
# (Iteration 1 / 980) loss: 14.964518
# (Epoch 0 / 20) train acc: 0.103000; val_acc: 0.104000
# (Iteration 11 / 980) loss: 8.539533
# (Iteration 21 / 980) loss: 7.016924
# (Iteration 31 / 980) loss: 5.674443
# (Iteration 41 / 980) loss: 4.626997
# (Epoch 1 / 20) train acc: 0.402000; val_acc: 0.391000
# (Iteration 51 / 980) loss: 3.783875
# (Iteration 61 / 980) loss: 3.256390
# (Iteration 71 / 980) loss: 2.972612
# (Iteration 81 / 980) loss: 2.564954
# (Iteration 91 / 980) loss: 2.447043
# (Epoch 2 / 20) train acc: 0.440000; val_acc: 0.441000
# (Iteration 101 / 980) loss: 2.316367
# (Iteration 111 / 980) loss: 2.125961
# (Iteration 121 / 980) loss: 2.124972
# (Iteration 131 / 980) loss: 2.089661
# (Iteration 141 / 980) loss: 2.095102
# (Epoch 3 / 20) train acc: 0.477000; val_acc: 0.436000
# (Iteration 151 / 980) loss: 1.917003
# (Iteration 161 / 980) loss: 1.972027
# (Iteration 171 / 980) loss: 1.954642
# (Iteration 181 / 980) loss: 1.902087
# (Iteration 191 / 980) loss: 1.928410
# (Epoch 4 / 20) train acc: 0.445000; val_acc: 0.455000
# (Iteration 201 / 980) loss: 1.885491
# (Iteration 211 / 980) loss: 1.894844
# (Iteration 221 / 980) loss: 1.834288
# (Iteration 231 / 980) loss: 1.844183
# (Iteration 241 / 980) loss: 1.860520
# (Epoch 5 / 20) train acc: 0.475000; val_acc: 0.457000
# (Iteration 251 / 980) loss: 1.878709
# (Iteration 261 / 980) loss: 1.926817
# (Iteration 271 / 980) loss: 1.897319
# (Iteration 281 / 980) loss: 1.857591
# (Iteration 291 / 980) loss: 1.839898
# (Epoch 6 / 20) train acc: 0.503000; val_acc: 0.450000
# (Iteration 301 / 980) loss: 1.829226
# (Iteration 311 / 980) loss: 1.769139
# (Iteration 321 / 980) loss: 1.792135
# (Iteration 331 / 980) loss: 1.805320
# (Iteration 341 / 980) loss: 1.783732
# (Epoch 7 / 20) train acc: 0.455000; val_acc: 0.453000
# (Iteration 351 / 980) loss: 1.774143
# (Iteration 361 / 980) loss: 1.802817
# (Iteration 371 / 980) loss: 1.795546
# (Iteration 381 / 980) loss: 1.737191
# (Iteration 391 / 980) loss: 1.811560
# (Epoch 8 / 20) train acc: 0.488000; val_acc: 0.459000
# (Iteration 401 / 980) loss: 1.767150
# (Iteration 411 / 980) loss: 1.782602
# (Iteration 421 / 980) loss: 1.817078
# (Iteration 431 / 980) loss: 1.733125
# (Iteration 441 / 980) loss: 1.791082
# (Epoch 9 / 20) train acc: 0.524000; val_acc: 0.471000
# (Iteration 451 / 980) loss: 1.705286
# (Iteration 461 / 980) loss: 1.695272
# (Iteration 471 / 980) loss: 1.742001
# (Iteration 481 / 980) loss: 1.806314
# (Epoch 10 / 20) train acc: 0.487000; val_acc: 0.469000
# (Iteration 491 / 980) loss: 1.705767
# (Iteration 501 / 980) loss: 1.719579
# (Iteration 511 / 980) loss: 1.784429
# (Iteration 521 / 980) loss: 1.762133
# (Iteration 531 / 980) loss: 1.718191
# (Epoch 11 / 20) train acc: 0.448000; val_acc: 0.460000
# (Iteration 541 / 980) loss: 1.772208
# (Iteration 551 / 980) loss: 1.677031
# (Iteration 561 / 980) loss: 1.718781
# (Iteration 571 / 980) loss: 1.709279
# (Iteration 581 / 980) loss: 1.656192
# (Epoch 12 / 20) train acc: 0.497000; val_acc: 0.462000
# (Iteration 591 / 980) loss: 1.697021
# (Iteration 601 / 980) loss: 1.630383
# (Iteration 611 / 980) loss: 1.763954
# (Iteration 621 / 980) loss: 1.743315
# (Iteration 631 / 980) loss: 1.736775
# (Epoch 13 / 20) train acc: 0.495000; val_acc: 0.492000
# (Iteration 641 / 980) loss: 1.679061
# (Iteration 651 / 980) loss: 1.701094
# (Iteration 661 / 980) loss: 1.617310
# (Iteration 671 / 980) loss: 1.712481
# (Iteration 681 / 980) loss: 1.691448
# (Epoch 14 / 20) train acc: 0.531000; val_acc: 0.474000
# (Iteration 691 / 980) loss: 1.615993
# (Iteration 701 / 980) loss: 1.580549
# (Iteration 711 / 980) loss: 1.723709
# (Iteration 721 / 980) loss: 1.713537
# (Iteration 731 / 980) loss: 1.748284
# (Epoch 15 / 20) train acc: 0.524000; val_acc: 0.475000
# (Iteration 741 / 980) loss: 1.606002
# (Iteration 751 / 980) loss: 1.668554
# (Iteration 761 / 980) loss: 1.608741
# (Iteration 771 / 980) loss: 1.618820
# (Iteration 781 / 980) loss: 1.713632
# (Epoch 16 / 20) train acc: 0.452000; val_acc: 0.483000
# (Iteration 791 / 980) loss: 1.655043
# (Iteration 801 / 980) loss: 1.646040
# (Iteration 811 / 980) loss: 1.622328
# (Iteration 821 / 980) loss: 1.694017
# (Iteration 831 / 980) loss: 1.699514
# (Epoch 17 / 20) train acc: 0.480000; val_acc: 0.498000
# (Iteration 841 / 980) loss: 1.672608
# (Iteration 851 / 980) loss: 1.700204
# (Iteration 861 / 980) loss: 1.631482
# (Iteration 871 / 980) loss: 1.707349
# (Iteration 881 / 980) loss: 1.725488
# (Epoch 18 / 20) train acc: 0.498000; val_acc: 0.468000
# (Iteration 891 / 980) loss: 1.658551
# (Iteration 901 / 980) loss: 1.681458
# (Iteration 911 / 980) loss: 1.647828
# (Iteration 921 / 980) loss: 1.652289
# (Iteration 931 / 980) loss: 1.668297
# (Epoch 19 / 20) train acc: 0.491000; val_acc: 0.477000
# (Iteration 941 / 980) loss: 1.677015
# (Iteration 951 / 980) loss: 1.687129
# (Iteration 961 / 980) loss: 1.686695
# (Iteration 971 / 980) loss: 1.673079
# (Epoch 20 / 20) train acc: 0.516000; val_acc: 0.491000
# 0.498
# round 11 / 100
# (Iteration 1 / 980) loss: 91.602989
# ...
# (Iteration 791 / 980) loss: 1.889205
# (Iteration 801 / 980) loss: 1.952634
# (Iteration 811 / 980) loss: 1.949113
# (Iteration 821 / 980) loss: 1.963240
# (Iteration 831 / 980) loss: 1.928437
# (Epoch 17 / 20) train acc: 0.415000; val_acc: 0.420000
# (Iteration 841 / 980) loss: 1.901127
# (Iteration 851 / 980) loss: 1.923014
# (Iteration 861 / 980) loss: 1.911079
# (Iteration 871 / 980) loss: 1.876548
# (Iteration 881 / 980) loss: 1.972054
# (Epoch 18 / 20) train acc: 0.412000; val_acc: 0.410000
# (Iteration 891 / 980) loss: 1.892934
# (Iteration 901 / 980) loss: 1.903162
# (Iteration 911 / 980) loss: 1.931445
# (Iteration 921 / 980) loss: 1.963946
# (Iteration 931 / 980) loss: 1.932208
# (Epoch 19 / 20) train acc: 0.406000; val_acc: 0.408000
# (Iteration 941 / 980) loss: 1.893144
# (Iteration 951 / 980) loss: 1.915422
# (Iteration 961 / 980) loss: 1.947568
# (Iteration 971 / 980) loss: 1.936497
# (Epoch 20 / 20) train acc: 0.403000; val_acc: 0.395000
# 0.424
# round 82 / 100
# (Iteration 1 / 980) loss: 58.692945
# (Epoch 0 / 20) train acc: 0.044000; val_acc: 0.046000
# (Iteration 11 / 980) loss: 40.632933
# (Iteration 21 / 980) loss: 29.126257
# (Iteration 31 / 980) loss: 20.582938
# (Iteration 41 / 980) loss: 14.683671
# (Epoch 1 / 20) train acc: 0.417000; val_acc: 0.394000
# (Iteration 51 / 980) loss: 10.670299
# (Iteration 61 / 980) loss: 8.062306
# (Iteration 71 / 980) loss: 6.296306
# (Iteration 81 / 980) loss: 5.129172
# (Iteration 91 / 980) loss: 4.330366
# (Epoch 2 / 20) train acc: 0.438000; val_acc: 0.420000
# (Iteration 101 / 980) loss: 3.753018
# (Iteration 111 / 980) loss: 3.307306
# (Iteration 121 / 980) loss: 3.035651
# (Iteration 131 / 980) loss: 2.845995
# (Iteration 141 / 980) loss: 2.729447
# (Epoch 3 / 20) train acc: 0.419000; val_acc: 0.419000
# (Iteration 151 / 980) loss: 2.599122
# (Iteration 161 / 980) loss: 2.518376
# (Iteration 171 / 980) loss: 2.401319
# (Iteration 181 / 980) loss: 2.330979
# (Iteration 191 / 980) loss: 2.322673
# (Epoch 4 / 20) train acc: 0.441000; val_acc: 0.442000
# (Iteration 201 / 980) loss: 2.302709
# (Iteration 211 / 980) loss: 2.256796
# (Iteration 221 / 980) loss: 2.279484
# (Iteration 231 / 980) loss: 2.166520
# (Iteration 241 / 980) loss: 2.199828
# (Epoch 5 / 20) train acc: 0.430000; val_acc: 0.437000
# (Iteration 251 / 980) loss: 2.172507
# (Iteration 261 / 980) loss: 2.117029
# (Iteration 271 / 980) loss: 2.098799
# (Iteration 281 / 980) loss: 2.172302
# (Iteration 291 / 980) loss: 2.095267
# (Epoch 6 / 20) train acc: 0.437000; val_acc: 0.445000
# (Iteration 301 / 980) loss: 2.085369
# (Iteration 311 / 980) loss: 2.067569
# (Iteration 321 / 980) loss: 2.078958
# (Iteration 331 / 980) loss: 2.080705
# (Iteration 341 / 980) loss: 2.074469
# (Epoch 7 / 20) train acc: 0.434000; val_acc: 0.420000
# (Iteration 351 / 980) loss: 2.024994
# (Iteration 361 / 980) loss: 2.034747
# (Iteration 371 / 980) loss: 2.039493
# (Iteration 381 / 980) loss: 2.067693
# (Iteration 391 / 980) loss: 2.035552
# (Epoch 8 / 20) train acc: 0.434000; val_acc: 0.446000
# (Iteration 401 / 980) loss: 1.948195
# (Iteration 411 / 980) loss: 2.038784
# (Iteration 421 / 980) loss: 2.028458
# (Iteration 431 / 980) loss: 1.985454
# (Iteration 441 / 980) loss: 2.008318
# (Epoch 9 / 20) train acc: 0.429000; val_acc: 0.452000
# (Iteration 451 / 980) loss: 2.009167
# (Iteration 461 / 980) loss: 2.001236
# (Iteration 471 / 980) loss: 1.977200
# (Iteration 481 / 980) loss: 1.971329
# (Epoch 10 / 20) train acc: 0.428000; val_acc: 0.453000
# (Iteration 491 / 980) loss: 1.974848
# (Iteration 501 / 980) loss: 1.934782
# (Iteration 511 / 980) loss: 1.973778
# (Iteration 521 / 980) loss: 2.054912
# (Iteration 531 / 980) loss: 2.037279
# (Epoch 11 / 20) train acc: 0.469000; val_acc: 0.443000
# (Iteration 541 / 980) loss: 1.978429
# (Iteration 551 / 980) loss: 2.058326
# (Iteration 561 / 980) loss: 1.954488
# (Iteration 571 / 980) loss: 1.964564
# (Iteration 581 / 980) loss: 1.935684
# (Epoch 12 / 20) train acc: 0.428000; val_acc: 0.433000
# (Iteration 591 / 980) loss: 1.984320
# (Iteration 601 / 980) loss: 2.006440
# (Iteration 611 / 980) loss: 1.971049
# (Iteration 621 / 980) loss: 1.960660
# (Iteration 631 / 980) loss: 2.005168
# (Epoch 13 / 20) train acc: 0.451000; val_acc: 0.432000
# (Iteration 641 / 980) loss: 1.954532
# (Iteration 651 / 980) loss: 1.972683
# (Iteration 661 / 980) loss: 1.992119
# (Iteration 671 / 980) loss: 1.935907
# (Iteration 681 / 980) loss: 1.928887
# (Epoch 14 / 20) train acc: 0.405000; val_acc: 0.459000
# (Iteration 691 / 980) loss: 2.010034
# (Iteration 701 / 980) loss: 1.951617
# (Iteration 711 / 980) loss: 1.989867
# (Iteration 721 / 980) loss: 1.955199
# (Iteration 731 / 980) loss: 1.961641
# (Epoch 15 / 20) train acc: 0.441000; val_acc: 0.451000
# (Iteration 741 / 980) loss: 1.994179
# (Iteration 751 / 980) loss: 1.892233
# (Iteration 761 / 980) loss: 1.936418
# (Iteration 771 / 980) loss: 1.943244
# (Iteration 781 / 980) loss: 1.990281
# (Epoch 16 / 20) train acc: 0.454000; val_acc: 0.450000
# (Iteration 791 / 980) loss: 1.949021
# (Iteration 801 / 980) loss: 1.923072
# (Iteration 811 / 980) loss: 2.049057
# (Iteration 821 / 980) loss: 1.959566
# (Iteration 831 / 980) loss: 1.955229
# (Epoch 17 / 20) train acc: 0.464000; val_acc: 0.457000
# (Iteration 841 / 980) loss: 1.959138
# (Iteration 851 / 980) loss: 1.991348
# (Iteration 861 / 980) loss: 2.017912
# (Iteration 871 / 980) loss: 1.983195
# (Iteration 881 / 980) loss: 1.952432
# (Epoch 18 / 20) train acc: 0.434000; val_acc: 0.442000
# (Iteration 891 / 980) loss: 1.968590
# (Iteration 901 / 980) loss: 2.012939
# (Iteration 911 / 980) loss: 1.901354
# (Iteration 921 / 980) loss: 1.952069
# (Iteration 931 / 980) loss: 1.897638
# (Epoch 19 / 20) train acc: 0.450000; val_acc: 0.455000
# (Iteration 941 / 980) loss: 1.917601
# (Iteration 951 / 980) loss: 1.955175
# (Iteration 961 / 980) loss: 1.909786
# (Iteration 971 / 980) loss: 2.011776
# (Epoch 20 / 20) train acc: 0.432000; val_acc: 0.435000
# 0.459
# round 83 / 100
# (Iteration 1 / 980) loss: 178.954407
# (Epoch 0 / 20) train acc: 0.006000; val_acc: 0.011000
# (Iteration 11 / 980) loss: 151.128107
# (Iteration 21 / 980) loss: 129.912800
# (Iteration 31 / 980) loss: 111.501235
# (Iteration 41 / 980) loss: 95.673208
# (Epoch 1 / 20) train acc: 0.342000; val_acc: 0.311000
# (Iteration 51 / 980) loss: 82.207997
# (Iteration 61 / 980) loss: 70.790384
# (Iteration 71 / 980) loss: 61.086159
# (Iteration 81 / 980) loss: 52.821421
# (Iteration 91 / 980) loss: 45.655160
# (Epoch 2 / 20) train acc: 0.384000; val_acc: 0.361000
# (Iteration 101 / 980) loss: 39.643399
# (Iteration 111 / 980) loss: 34.487146
# (Iteration 121 / 980) loss: 30.061562
# (Iteration 131 / 980) loss: 26.168563
# (Iteration 141 / 980) loss: 22.915534
# (Epoch 3 / 20) train acc: 0.353000; val_acc: 0.376000
# (Iteration 151 / 980) loss: 20.168148
# (Iteration 161 / 980) loss: 17.803148
# (Iteration 171 / 980) loss: 15.718119
# (Iteration 181 / 980) loss: 13.910723
# (Iteration 191 / 980) loss: 12.385660
# (Epoch 4 / 20) train acc: 0.374000; val_acc: 0.369000
# (Iteration 201 / 980) loss: 11.024487
# (Iteration 211 / 980) loss: 9.898722
# (Iteration 221 / 980) loss: 8.904795
# (Iteration 231 / 980) loss: 8.069674
# (Iteration 241 / 980) loss: 7.318952
# (Epoch 5 / 20) train acc: 0.383000; val_acc: 0.393000
# (Iteration 251 / 980) loss: 6.710501
# (Iteration 261 / 980) loss: 6.151526
# (Iteration 271 / 980) loss: 5.672801
# (Iteration 281 / 980) loss: 5.317300
# (Iteration 291 / 980) loss: 4.890937
# (Epoch 6 / 20) train acc: 0.357000; val_acc: 0.373000
# (Iteration 301 / 980) loss: 4.631613
# (Iteration 311 / 980) loss: 4.361355
# (Iteration 321 / 980) loss: 4.124455
# (Iteration 331 / 980) loss: 3.904054
# (Iteration 341 / 980) loss: 3.739709
# (Epoch 7 / 20) train acc: 0.368000; val_acc: 0.342000
# (Iteration 351 / 980) loss: 3.619289
# (Iteration 361 / 980) loss: 3.473318
# (Iteration 371 / 980) loss: 3.335120
# (Iteration 381 / 980) loss: 3.267416
# (Iteration 391 / 980) loss: 3.153457
# (Epoch 8 / 20) train acc: 0.358000; val_acc: 0.355000
# (Iteration 401 / 980) loss: 3.048572
# (Iteration 411 / 980) loss: 2.990387
# (Iteration 421 / 980) loss: 2.975570
# (Iteration 431 / 980) loss: 2.907979
# (Iteration 441 / 980) loss: 2.849507
# (Epoch 9 / 20) train acc: 0.359000; val_acc: 0.351000
# (Iteration 451 / 980) loss: 2.828018
# (Iteration 461 / 980) loss: 2.770950
# (Iteration 471 / 980) loss: 2.790685
# (Iteration 481 / 980) loss: 2.713344
# (Epoch 10 / 20) train acc: 0.343000; val_acc: 0.344000
# (Iteration 491 / 980) loss: 2.708258
# (Iteration 501 / 980) loss: 2.673882
# (Iteration 511 / 980) loss: 2.652517
# (Iteration 521 / 980) loss: 2.655509
# (Iteration 531 / 980) loss: 2.625968
# (Epoch 11 / 20) train acc: 0.341000; val_acc: 0.346000
# (Iteration 541 / 980) loss: 2.602779
# (Iteration 551 / 980) loss: 2.596704
# (Iteration 561 / 980) loss: 2.623975
# (Iteration 571 / 980) loss: 2.591135
# (Iteration 581 / 980) loss: 2.577434
# (Epoch 12 / 20) train acc: 0.351000; val_acc: 0.358000
# (Iteration 591 / 980) loss: 2.597442
# (Iteration 601 / 980) loss: 2.559424
# (Iteration 611 / 980) loss: 2.532555
# (Iteration 621 / 980) loss: 2.551093
# (Iteration 631 / 980) loss: 2.555077
# (Epoch 13 / 20) train acc: 0.344000; val_acc: 0.358000
# (Iteration 641 / 980) loss: 2.558944
# (Iteration 651 / 980) loss: 2.540171
# (Iteration 661 / 980) loss: 2.521034
# (Iteration 671 / 980) loss: 2.541681
# (Iteration 681 / 980) loss: 2.508366
# (Epoch 14 / 20) train acc: 0.329000; val_acc: 0.344000
# (Iteration 691 / 980) loss: 2.523044
# (Iteration 701 / 980) loss: 2.532328
# (Iteration 711 / 980) loss: 2.502222
# (Iteration 721 / 980) loss: 2.490382
# (Iteration 731 / 980) loss: 2.536022
# (Epoch 15 / 20) train acc: 0.321000; val_acc: 0.329000
# (Iteration 741 / 980) loss: 2.526296
# (Iteration 751 / 980) loss: 2.494711
# (Iteration 761 / 980) loss: 2.495486
# (Iteration 771 / 980) loss: 2.494124
# (Iteration 781 / 980) loss: 2.502441
# (Epoch 16 / 20) train acc: 0.333000; val_acc: 0.318000
# (Iteration 791 / 980) loss: 2.515712
# (Iteration 801 / 980) loss: 2.527136
# (Iteration 811 / 980) loss: 2.499358
# (Iteration 821 / 980) loss: 2.502111
# (Iteration 831 / 980) loss: 2.497756
# (Epoch 17 / 20) train acc: 0.335000; val_acc: 0.331000
# (Iteration 841 / 980) loss: 2.504744
# (Iteration 851 / 980) loss: 2.503434
# (Iteration 861 / 980) loss: 2.467205
# (Iteration 871 / 980) loss: 2.474085
# (Iteration 881 / 980) loss: 2.484519
# (Epoch 18 / 20) train acc: 0.337000; val_acc: 0.322000
# (Iteration 891 / 980) loss: 2.480015
# (Iteration 901 / 980) loss: 2.519359
# (Iteration 911 / 980) loss: 2.503036
# (Iteration 921 / 980) loss: 2.517712
# (Iteration 931 / 980) loss: 2.462288
# (Epoch 19 / 20) train acc: 0.305000; val_acc: 0.315000
# (Iteration 941 / 980) loss: 2.445865
# (Iteration 951 / 980) loss: 2.470283
# (Iteration 961 / 980) loss: 2.466763
# (Iteration 971 / 980) loss: 2.451083
# (Epoch 20 / 20) train acc: 0.358000; val_acc: 0.322000
# 0.393
# round 84 / 100
# (Iteration 1 / 980) loss: 13.914584
# (Epoch 0 / 20) train acc: 0.005000; val_acc: 0.007000
# (Iteration 11 / 980) loss: 10.262408
# (Iteration 21 / 980) loss: 8.834162
# (Iteration 31 / 980) loss: 8.318344
# (Iteration 41 / 980) loss: 7.740379
# (Epoch 1 / 20) train acc: 0.261000; val_acc: 0.262000
# (Iteration 51 / 980) loss: 7.430511
# (Iteration 61 / 980) loss: 7.107770
# (Iteration 71 / 980) loss: 6.860560
# (Iteration 81 / 980) loss: 6.791260
# (Iteration 91 / 980) loss: 6.738190
# (Epoch 2 / 20) train acc: 0.355000; val_acc: 0.314000
# (Iteration 101 / 980) loss: 6.634655
# (Iteration 111 / 980) loss: 6.547848
# (Iteration 121 / 980) loss: 6.482852
# (Iteration 131 / 980) loss: 6.508155
# (Iteration 141 / 980) loss: 6.334704
# (Epoch 3 / 20) train acc: 0.378000; val_acc: 0.362000
# (Iteration 151 / 980) loss: 6.329310
# (Iteration 161 / 980) loss: 6.272649
# (Iteration 171 / 980) loss: 6.240921
# (Iteration 181 / 980) loss: 6.154731
# (Iteration 191 / 980) loss: 6.131870
# (Epoch 4 / 20) train acc: 0.389000; val_acc: 0.379000
# (Iteration 201 / 980) loss: 6.093998
# (Iteration 211 / 980) loss: 6.006443
# (Iteration 221 / 980) loss: 6.006582
# (Iteration 231 / 980) loss: 5.943817
# (Iteration 241 / 980) loss: 5.844659
# (Epoch 5 / 20) train acc: 0.416000; val_acc: 0.403000
# (Iteration 251 / 980) loss: 5.803800
# (Iteration 261 / 980) loss: 5.740551
# (Iteration 271 / 980) loss: 5.753561
# (Iteration 281 / 980) loss: 5.683677
# (Iteration 291 / 980) loss: 5.670622
# (Epoch 6 / 20) train acc: 0.414000; val_acc: 0.404000
# (Iteration 301 / 980) loss: 5.653869
# (Iteration 311 / 980) loss: 5.502960
# (Iteration 321 / 980) loss: 5.488029
# (Iteration 331 / 980) loss: 5.447428
# (Iteration 341 / 980) loss: 5.393246
# (Epoch 7 / 20) train acc: 0.461000; val_acc: 0.406000
# (Iteration 351 / 980) loss: 5.372218
# (Iteration 361 / 980) loss: 5.343434
# (Iteration 371 / 980) loss: 5.291762
# (Iteration 381 / 980) loss: 5.231084
# (Iteration 391 / 980) loss: 5.202917
# (Epoch 8 / 20) train acc: 0.423000; val_acc: 0.424000
# (Iteration 401 / 980) loss: 5.180735
# (Iteration 411 / 980) loss: 5.138050
# (Iteration 421 / 980) loss: 5.111961
# (Iteration 431 / 980) loss: 5.022970
# (Iteration 441 / 980) loss: 5.016506
# (Epoch 9 / 20) train acc: 0.501000; val_acc: 0.434000
# (Iteration 451 / 980) loss: 4.983920
# (Iteration 461 / 980) loss: 4.963264
# (Iteration 471 / 980) loss: 4.913790
# (Iteration 481 / 980) loss: 4.817029
# (Epoch 10 / 20) train acc: 0.470000; val_acc: 0.441000
# (Iteration 491 / 980) loss: 4.830566
# (Iteration 501 / 980) loss: 4.761569
# (Iteration 511 / 980) loss: 4.811047
# (Iteration 521 / 980) loss: 4.585539
# (Iteration 531 / 980) loss: 4.703796
# (Epoch 11 / 20) train acc: 0.480000; val_acc: 0.457000
# (Iteration 541 / 980) loss: 4.632292
# (Iteration 551 / 980) loss: 4.572232
# (Iteration 561 / 980) loss: 4.529268
# (Iteration 571 / 980) loss: 4.533288
# (Iteration 581 / 980) loss: 4.493927
# (Epoch 12 / 20) train acc: 0.503000; val_acc: 0.447000
# (Iteration 591 / 980) loss: 4.423354
# (Iteration 601 / 980) loss: 4.419931
# (Iteration 611 / 980) loss: 4.382974
# (Iteration 621 / 980) loss: 4.337021
# (Iteration 631 / 980) loss: 4.304532
# (Epoch 13 / 20) train acc: 0.487000; val_acc: 0.454000
# (Iteration 641 / 980) loss: 4.287408
# (Iteration 651 / 980) loss: 4.232040
# (Iteration 661 / 980) loss: 4.247095
# (Iteration 671 / 980) loss: 4.149770
# (Iteration 681 / 980) loss: 4.158021
# (Epoch 14 / 20) train acc: 0.524000; val_acc: 0.460000
# (Iteration 691 / 980) loss: 4.119658
# (Iteration 701 / 980) loss: 4.055758
# (Iteration 711 / 980) loss: 4.015864
# (Iteration 721 / 980) loss: 4.045215
# (Iteration 731 / 980) loss: 4.010122
# (Epoch 15 / 20) train acc: 0.511000; val_acc: 0.466000
# (Iteration 741 / 980) loss: 3.924904
# (Iteration 751 / 980) loss: 3.957744
# (Iteration 761 / 980) loss: 3.823148
# (Iteration 771 / 980) loss: 3.879413
# (Iteration 781 / 980) loss: 3.876426
# (Epoch 16 / 20) train acc: 0.520000; val_acc: 0.464000
# (Iteration 791 / 980) loss: 3.783387
# (Iteration 801 / 980) loss: 3.784107
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-7de57c07c926> in <module>()
#      25                   verbose=True)
#      26   solvers[update_rule] = solver
# ---> 27   solver.train()
#      28   if solver.best_val_acc > best_acc:
#      29     best_acc = solver.best_val_acc
#
# /home/yusn/Desktop/cs231n/assignment2/cs231n/solver.py in train(self)
#     225
#     226     for t in xrange(num_iterations):
# --> 227       self._step()
#     228
#     229       # Maybe print training loss
#
# /home/yusn/Desktop/cs231n/assignment2/cs231n/solver.py in _step(self)
#     163
#     164     # Compute loss and gradient
# --> 165     loss, grads = self.model.loss(X_batch, y_batch)
#     166     self.loss_history.append(loss)
#     167
#
# /home/yusn/Desktop/cs231n/assignment2/cs231n/classifiers/fc_net.py in loss(self, X, y)
#     262     # of 0.5 to simplify the expression for the gradient.                      #
#     263     ############################################################################
# --> 264     loss, dscores = softmax_loss(scores, y)
#     265     # reg loss
#     266     for i in range(self.num_layers-2):
#
# /home/yusn/Desktop/cs231n/assignment2/cs231n/layers.pyc in softmax_loss(x, y)
#     549   - dx: Gradient of the loss with respect to x
#     550   """
# --> 551   probs = np.exp(x - np.max(x, axis=1, keepdims=True))
#     552   probs /= np.sum(probs, axis=1, keepdims=True)
#     553   N = x.shape[0]
#
# KeyboardInterrupt:

# %%
model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2,reg=0.0297468942265)
solver = Solver(model, data,
                  num_epochs=30, batch_size=3000,
                  update_rule= 'adam',
                  optim_config={
                    'learning_rate': 0.000844664246013
                  },
                  verbose=True)
solver._reset()
solver.train()
best_model = model

plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()
# Out:
# (Iteration 1 / 480) loss: 19.802571
# (Epoch 0 / 30) train acc: 0.077000; val_acc: 0.083000
# (Iteration 11 / 480) loss: 13.815883
# (Epoch 1 / 30) train acc: 0.295000; val_acc: 0.286000
# (Iteration 21 / 480) loss: 12.058549
# (Iteration 31 / 480) loss: 10.413364
# (Epoch 2 / 30) train acc: 0.401000; val_acc: 0.361000
# (Iteration 41 / 480) loss: 8.978497
# (Epoch 3 / 30) train acc: 0.407000; val_acc: 0.423000
# (Iteration 51 / 480) loss: 7.758014
# (Iteration 61 / 480) loss: 6.637459
# (Epoch 4 / 30) train acc: 0.449000; val_acc: 0.433000
# (Iteration 71 / 480) loss: 5.813414
# (Epoch 5 / 30) train acc: 0.460000; val_acc: 0.455000
# (Iteration 81 / 480) loss: 5.065958
# (Iteration 91 / 480) loss: 4.525278
# (Epoch 6 / 30) train acc: 0.460000; val_acc: 0.458000
# (Iteration 101 / 480) loss: 4.028601
# (Iteration 111 / 480) loss: 3.558450
# (Epoch 7 / 30) train acc: 0.474000; val_acc: 0.452000
# (Iteration 121 / 480) loss: 3.274733
# (Epoch 8 / 30) train acc: 0.518000; val_acc: 0.473000
# (Iteration 131 / 480) loss: 3.023114
# (Iteration 141 / 480) loss: 2.830258
# (Epoch 9 / 30) train acc: 0.509000; val_acc: 0.469000
# (Iteration 151 / 480) loss: 2.656456
# (Epoch 10 / 30) train acc: 0.538000; val_acc: 0.479000
# (Iteration 161 / 480) loss: 2.526736
# (Iteration 171 / 480) loss: 2.416073
# (Epoch 11 / 30) train acc: 0.491000; val_acc: 0.480000
# (Iteration 181 / 480) loss: 2.271128
# (Iteration 191 / 480) loss: 2.203794
# (Epoch 12 / 30) train acc: 0.541000; val_acc: 0.496000
# (Iteration 201 / 480) loss: 2.134660
# (Epoch 13 / 30) train acc: 0.541000; val_acc: 0.499000
# (Iteration 211 / 480) loss: 2.102060
# (Iteration 221 / 480) loss: 2.041440
# (Epoch 14 / 30) train acc: 0.550000; val_acc: 0.499000
# (Iteration 231 / 480) loss: 1.990616
# (Epoch 15 / 30) train acc: 0.580000; val_acc: 0.517000
# (Iteration 241 / 480) loss: 1.970461
# (Iteration 251 / 480) loss: 1.890912
# (Epoch 16 / 30) train acc: 0.574000; val_acc: 0.509000
# (Iteration 261 / 480) loss: 1.883103
# (Iteration 271 / 480) loss: 1.862324
# (Epoch 17 / 30) train acc: 0.547000; val_acc: 0.511000
# (Iteration 281 / 480) loss: 1.822355
# (Epoch 18 / 30) train acc: 0.516000; val_acc: 0.491000
# (Iteration 291 / 480) loss: 1.816300
# (Iteration 301 / 480) loss: 1.768251
# (Epoch 19 / 30) train acc: 0.581000; val_acc: 0.516000
# (Iteration 311 / 480) loss: 1.739634
# (Epoch 20 / 30) train acc: 0.577000; val_acc: 0.514000
# (Iteration 321 / 480) loss: 1.740376
# (Iteration 331 / 480) loss: 1.698962
# (Epoch 21 / 30) train acc: 0.560000; val_acc: 0.523000
# (Iteration 341 / 480) loss: 1.681740
# (Iteration 351 / 480) loss: 1.701269
# (Epoch 22 / 30) train acc: 0.586000; val_acc: 0.513000
# (Iteration 361 / 480) loss: 1.640228
# (Epoch 23 / 30) train acc: 0.591000; val_acc: 0.521000
# (Iteration 371 / 480) loss: 1.648544
# (Iteration 381 / 480) loss: 1.595866
# (Epoch 24 / 30) train acc: 0.634000; val_acc: 0.511000
# (Iteration 391 / 480) loss: 1.655396
# (Epoch 25 / 30) train acc: 0.588000; val_acc: 0.514000
# (Iteration 401 / 480) loss: 1.644241
# (Iteration 411 / 480) loss: 1.683202
# (Epoch 26 / 30) train acc: 0.574000; val_acc: 0.525000
# (Iteration 421 / 480) loss: 1.595924
# (Iteration 431 / 480) loss: 1.558697
# (Epoch 27 / 30) train acc: 0.598000; val_acc: 0.510000
# (Iteration 441 / 480) loss: 1.589727
# (Epoch 28 / 30) train acc: 0.635000; val_acc: 0.523000
# (Iteration 451 / 480) loss: 1.531057
# (Iteration 461 / 480) loss: 1.561042
# (Epoch 29 / 30) train acc: 0.598000; val_acc: 0.511000
# (Iteration 471 / 480) loss: 1.603348
# (Epoch 30 / 30) train acc: 0.605000; val_acc: 0.513000

# %% [markdown]
# # Test you model
# Run your best model on the validation and test sets. You should achieve above 50% accuracy on the validation set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print 'Validation set accuracy: ', (y_val_pred == data['y_val']).mean()
print 'Test set accuracy: ', (y_test_pred == data['y_test']).mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-fa8b8c74e753> in <module>()
# ----> 1 y_test_pred = np.argmax(best_model.loss(data.X_test), axis=1)
#       2 y_val_pred = np.argmax(best_model.loss(data.X_val), axis=1)
#       3 print 'Validation set accuracy: ', (y_val_pred == data.y_val).mean()
#       4 print 'Test set accuracy: ', (y_test_pred == data.y_test).mean()
#
# AttributeError: 'dict' object has no attribute 'X_test'

# %%
print     best_acc,best_rate,best_reg,best_model
# 0.542 0.000844664246013 0.0297468942265
# Out:
# 0.542 0.000844664246013 0.0297468942265 <cs231n.classifiers.fc_net.FullyConnectedNet object at 0x7f6d14c28a10>
